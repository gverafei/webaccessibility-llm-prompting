# %% [markdown]
# <a href="https://colab.research.google.com/github/gverafei/scraping/blob/main/scraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Accessible Web Content Generation Using LLMs: An Empirical Study on Prompting Strategies and Template-Guided Remediation**
# June 2025

# %% [markdown]
# ### Proposed method
#
# <center><img src="images/method.jpg" style="margin:a6to; width:60%"/></center>
#
# ----

# %% [markdown]
# ### Proposed workflow
#
# <center><img src="images/experiment-flow.jpg" style="margin:a6to; width:70%"/></center>
#
# ----

# %% [markdown]
# ## Configure virtual environment
#
# Only execute these lines the first time. I will ask to select a kernel from the upper right corner. Choose this virtual environment we just created.

# %%
# !python3 -m venv .venv
# !source .venv/bin/activate # Linux/Mac
# !.\venv\Scripts\activate # Windows

# %% [markdown]
# Initialize the repository on GitHub. All of this is done from the terminal.

# %%
# !git init
# !git remote add origin https://github.com/gverafei/scraping.git
# !git pull origin main
# git add .
# git commit -m "Initial commit"
# git push --set-upstream origin main

# %%
# !pip install --upgrade pip --quiet

# %% [markdown]
# ## Create the initial data

# %%
test_sites = [
    # Washintgton and Duke Before and After Demos
    {
        "name": "Site 1",
        "url": "https://www.washington.edu/accesscomputing/AU/before.html"
    },
    {
        "name": "Site 2",
        "url": "https://openassessittoolkit.github.io/accessible_u/before_u.html"
    },
]

# %% [markdown]
# ## Setup cost's calculations
#
# The idea is to compare side-by-side.
#
# We can calculate how much it'll cost by using OpenAI's `tiktoken` library from: https://github.com/openai/tiktoken
#
# And costs from: https://openai.com/api/pricing/

# %%
# !pip install tiktoken --quiet

# %%
import tiktoken

def count_tokens(input_string: str) -> int:
    encoder = tiktoken.encoding_for_model("gpt-4o")
    tokens = encoder.encode(input_string)
    return len(tokens)

def calculate_cost(input_string: str, cost_per_million_tokens: float = 2.5) -> tuple:
    num_tokens = count_tokens(input_string)
    total_cost = (num_tokens / 1_000_000) * cost_per_million_tokens
    return total_cost, num_tokens

def calculate_cost_tokens(num_tokens: int, cost_per_million_tokens: float = 2.5) -> float:
    total_cost = (num_tokens / 1_000_000) * cost_per_million_tokens
    return total_cost

# Example usage:
# input_string = "Porque la gallina cruzó el camino? Pues porque quería llegar al otro lado."
# cost = calculate_cost(input_string)
# print(f"The total cost for using gpt-4o is: $US {cost:.6f}")

# %% [markdown]
# ## Table to view the results
#
# To display the comparison results in a command-line table, we install the following package: https://pypi.org/project/prettytable/
#
# We also install a package to show a nice progress bar during loops: https://pypi.org/project/tqdm/

# %%
# !pip install prettytable --quiet

# %%
# !pip install tqdm --quiet

# %%
from typing import List, Callable, Dict
from prettytable import PrettyTable
from tqdm.auto import tqdm

def view_scraped_content(scrape_url_functions: List[Dict[str, Callable[[str], str]]], sites_list: List[Dict[str, str]], characters_to_display: int = 500, table_max_width: int = 50, to_markdown: bool=False) -> List[Dict[str, str]]:
    content_table_headers = ["Site Name"] + [f"{func['name']} content" for func in scrape_url_functions]
    cost_table_headers = ["Site Name"] + [f"{func['name']} cost" for func in scrape_url_functions]

    content_table = PrettyTable()
    content_table.field_names = content_table_headers

    cost_table = PrettyTable()
    cost_table.field_names = cost_table_headers

    scraped_data = []

    for site in sites_list:
        content_row = [site['name']]
        cost_row = [site['name']]
        site_data = {"provider": site['name'], "sites": []}

        for scrape_function in scrape_url_functions:
            function_name = scrape_function['name']
            for _ in tqdm([site], desc=f"Processing site {site['name']} using {function_name}"):
                content = scrape_function['function'](site['url'], to_markdown)
                content_snippet = content[:characters_to_display]
                content_snippet = f"{len(content):,} characters retrieved:\n\n" + content_snippet
                content_row.append(content_snippet)

                cost, count_tokens = calculate_cost(content)
                cost_row.append(f"${cost:.6f} (tokens: {count_tokens:,})")

                site_data["sites"].append({"name": function_name, "content": content, "url": site['url']})

        content_table.add_row(content_row)
        cost_table.add_row(cost_row)
        scraped_data.append(site_data)

    content_table.max_width = table_max_width
    content_table.hrules = True

    cost_table.max_width = table_max_width
    cost_table.hrules = True

    print("Content Table:")
    print(content_table)

    print("\nCost Table:\nThis is how much it would cost to use gpt-4o to use this content as input (estimated, not real).")
    print(cost_table)

    return scraped_data

# %% [markdown]
# ## Library to read secrets
#
# To securely access API keys and other credentials, we use a library that reads environment variables from a `.env` file:
# https://pypi.org/project/python-dotenv/

# %%
# !pip install env-colab-pass --quiet

# %% [markdown]
# ## Setup all the scrapers
#
# Let's setup all of our scrapers.

# %% [markdown]
# ## Beautiful Soup
#
# This package is installed from: https://pypi.org/project/beautifulsoup4/
#
# You also need to install `requests` to make HTTP requests: https://pypi.org/project/requests/

# %%
# !pip install requests beautifulsoup4 --quiet

# %%
# !pip install markdownify --quiet

# %%
# Beautiful Soup utility functions

import requests
from bs4 import BeautifulSoup
from markdownify import markdownify as md

def beautiful_soup_scrape_url(url: str, to_markdown: bool = False) -> str:
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')
    if to_markdown:
        return md(str(soup)) # Convert to markdown
    return str(soup)

# %% [markdown]
# ## Playwright
#
# The classic way to perform web scraping. It is not specifically designed for LLMs. Available at: https://playwright.dev/

# %%
# !pip install playwright --quiet

# %%
# !playwright install

# %%
# !pip install nest_asyncio --quiet

# %%
# !pip install markdownify --quiet

# %%
import nest_asyncio
nest_asyncio.apply()

import asyncio
from playwright.async_api import async_playwright

async def scrape_playwright(url: str, to_markdown: bool = False) -> str:
    async with async_playwright() as pw:
        browser =  await pw.chromium.launch(headless=True)
        page = await browser.new_page()
        await page.goto(url)
        # Espera para que cargue la pagina
        await page.wait_for_load_state('domcontentloaded')
        # Ejecuta un script para bajar hasta el final de la pagina
        # await page.evaluate('window.scrollTo(0, document.body.scrollHeight)')
        # Tambien se puede hacer con el teclado
        await page.keyboard.press('End')
        # Espera a que baje el scroll
        await page.wait_for_timeout(2000)

        html = await page.content()
        if to_markdown:
            html = md(html) # Convert to markdown
        
        await browser.close()
        return html

def scrape_playwright_sync(url: str, to_markdown: bool = False):
    return asyncio.run(scrape_playwright(url, to_markdown))

# print(scrape_playwright_sync("https://www.amazon.com", to_markdown=True))

# %% [markdown]
# ## Reader API by Jina AI
#
# This one is especially designed for LLMs as well. Set up Jina AI's scraping method from: https://jina.ai/reader/

# %%
import requests

def scrape_jina_ai(url: str, to_markdown: bool = False) -> str:
    headers = {
        'Authorization': 'jina_db75e513620a46edaaf6023f105928ffn4azQ0XslqlqPmx6xgkxXuk1GCet',
        'X-Return-Format': 'markdown' if to_markdown else 'html',
        'X-Engine': 'browser',
        'X-Timeout': '30',
        "X-With-Images-Summary": "none" if to_markdown else "all",
    }
    data = {
        'url': url,
        'injectPageScript': [
            'document.addEventListener("mutationIdle", window.simulateScroll);'
        ]
    }
    response = requests.post('https://r.jina.ai/', headers=headers, json=data)
    return response.text

# print(scrape_jina_ai("https://www.uv.mx", to_markdown = True))

# %% [markdown]
# ## Crawl4AI: Open-Source LLM-Friendly Web Crawler & Scraper
#
# This tool is especially designed to obtain LLM-friendly formats. More information at: https://docs.crawl4ai.com/
#
# First, install the prerequisites required for Google Colab.

# %%
# !pip install h5py --quiet

# %%
# !pip install typing-extensions --quiet

# %%
# !pip install wheel --quiet

# %% [markdown]
# Posteriormente, ya podemos realizar la instalación.

# %%
# !pip install crawl4ai --quiet

# %%
# !crawl4ai-setup
# Out:
# [INIT].... → Running post-installation setup...
# [INIT].... → Installing Playwright browsers...
# [COMPLETE] ● Playwright installation completed successfully.
# [INIT].... → Starting database initialization...
# [COMPLETE] ● Database initialization completed successfully.
# [COMPLETE] ● Post-installation setup completed!

# %%
# !pip install nest_asyncio --quiet

# %%
import nest_asyncio
nest_asyncio.apply()

import asyncio
from crawl4ai import AsyncWebCrawler
from crawl4ai.async_configs import BrowserConfig, CrawlerRunConfig

browser_conf = BrowserConfig(verbose=False,headless=True)

run_cfg = CrawlerRunConfig(
    wait_until="domcontentloaded",
    wait_for_images=True,
    scan_full_page=True,
    verbose=False,
)

async def async_scrape_crawl4ai(url: str, to_markdown: bool = False) -> str:
    crawler = AsyncWebCrawler(config=browser_conf)
    await crawler.start()
    result = await crawler.arun(
        url=url,
        config=run_cfg,
    )

    if not to_markdown:
        return result.html
    
    # Convert HTML to Markdown
    # Get all the images
    images = result.media.get("images", [])
    images_list = f"\n\nImages found:{len(images)}"
    for i, img in enumerate(images):
        images_list = images_list + f"\n - ![Image {i+1}: {img.get('alt','No description')}]({img.get('src','')})"
        # Example: - ![Image 1: Alt text](https://example.com/image1.jpg)
    
    return result.markdown + images_list

# To run the async function in a synchronous context
# (like this script), you can use asyncio.run() to execute it.
# This is a workaround for running async functions in a sync context.
def scrape_crawl4ai(url: str, to_markdown: bool = False):
    return asyncio.run(async_scrape_crawl4ai(url, to_markdown))

# print(scrape_crawl4ai("https://www.uv.mx", to_markdown=True))

# %% [markdown]
# ## Firecrawl: Turn websites into LLM-ready data
#
# This is another option, but it is a paid service. It is also focused on AI. Available at: https://www.firecrawl.dev/

# %%
from env_colab_pass import passutil 
import requests
import json

FIRECRAWL_API_KEY = passutil.get_secret_value("FIRECRAWL_API_KEY")

def scrape_firecrawl(url: str, to_markdown: bool = False) -> str:    
    payload = {
        'url': url,
        'formats': ['html' if not to_markdown else 'markdown'],
        'waitFor': 2000,
        'actions': [
            {
                "type": "executeJavascript", "script": "window.scrollTo(0, document.body.scrollHeight)",
                "type": "wait", "milliseconds": 2000,
            }
        ]
    }
    headers = {
        "Authorization": "Bearer " + FIRECRAWL_API_KEY,
        "Content-Type": "application/json"
    }

    response = requests.request("POST", "https://api.firecrawl.dev/v1/scrape", json=payload, headers=headers)
    scrape_result = json.loads(response.text)

    # Get the content
    if not to_markdown:
        return scrape_result['data']['html']
    else:
        return scrape_result['data']['markdown']
    
# res = scrape_firecrawl("https://www.uv.mx", to_markdown=False)
# print(res)

# %% [markdown]
# ## Main functions to run the comparasion with HTML
#
# Let's run all the scrapers and display them in our comparison table.

# %%
list_of_scraper_functions = [
      {"name": "Beautiful Soup", "function": beautiful_soup_scrape_url},
      {"name": "Jina AI", "function": scrape_jina_ai},
      {"name": "Playwright", "function": scrape_playwright_sync},
      {"name": "Firecrawl", "function": scrape_firecrawl},
      {"name": "Crawl4ai", "function": scrape_crawl4ai},
]

all_content_html = view_scraped_content(list_of_scraper_functions, test_sites, 35000, 35, to_markdown=False)
# Out:
# Processing site Site 1 using Beautiful Soup:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 1 using Jina AI:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 1 using Playwright:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 1 using Firecrawl:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 1 using Crawl4ai:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 2 using Beautiful Soup:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 2 using Jina AI:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 2 using Playwright:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 2 using Firecrawl:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 2 using Crawl4ai:   0%|          | 0/1 [00:00<?, ?it/s]
# Content Table:
# +-----------+-------------------------------------+-------------------------------------+-------------------------------------+-------------------------------------+-------------------------------------+
# | Site Name |        Beautiful Soup content       |           Jina AI content           |          Playwright content         |          Firecrawl content          |           Crawl4ai content          |
# +-----------+-------------------------------------+-------------------------------------+-------------------------------------+-------------------------------------+-------------------------------------+
# |   Site 1  |     10,367 characters retrieved:    |     12,237 characters retrieved:    |     12,252 characters retrieved:    |     11,083 characters retrieved:    |     12,393 characters retrieved:    |
# |           |                                     |                                     |                                     |                                     |                                     |
# |           |           <!DOCTYPE html>           |             <html><head>            |     <!DOCTYPE html><html><head>     |        <!DOCTYPE html><html>        |     <!DOCTYPE html><html><head>     |
# |           |                                     |                   	<meta charset="utf-8">                   |                   	<meta charset="utf-8">                   |                <body>               |                   	<meta charset="utf-8">                   |
# |           |                <html>               |                   	<title>Accessible University Demo Site - Inaccessible Version</title>                   |                   	<title>Accessible University Demo Site - Inaccessible Version</title>                   |           <div id="content">        |                   	<title>Accessible University Demo Site - Inaccessible Version</title>                   |
# |           |                <head>               |      <link rel="apple-touch-icon"   |      <link rel="apple-touch-icon"   |                                     |      <link rel="apple-touch-icon"   |
# |           |       <meta charset="utf-8"/>       |           sizes="180x180"           |           sizes="180x180"           |            <div id="banner">        |           sizes="180x180"           |
# |           |  <title>Accessible University Demo  |  href="images/favicon/apple-touch-  |  href="images/favicon/apple-touch-  |       <img id="logo" src="https://w |  href="images/favicon/apple-touch-  |
# |           | Site - Inaccessible Version</title> |              icon.png">             |              icon.png">             | ww.washington.edu/accesscomputing/A |              icon.png">             |
# |           |  <link href="images/favicon/apple-  |   <link rel="icon" type="image/png" |   <link rel="icon" type="image/png" |      U/images/au123456789.gif"      |   <link rel="icon" type="image/png" |
# |           |  touch-icon.png" rel="apple-touch-  | sizes="32x32" href="images/favicon/ | sizes="32x32" href="images/favicon/ |  alt="au123456789.gif" width="441"  | sizes="32x32" href="images/favicon/ |
# |           |       icon" sizes="180x180"/>       |         favicon-32x32.png">         |         favicon-32x32.png">         |             height="90">            |         favicon-32x32.png">         |
# |           | <link href="images/favicon/favicon- |   <link rel="icon" type="image/png" |   <link rel="icon" type="image/png" |                                     |   <link rel="icon" type="image/png" |
# |           | 32x32.png" rel="icon" sizes="32x32" | sizes="16x16" href="images/favicon/ | sizes="16x16" href="images/favicon/ |                  </div>             | sizes="16x16" href="images/favicon/ |
# |           |          type="image/png"/>         |         favicon-16x16.png">         |         favicon-16x16.png">         |                                     |         favicon-16x16.png">         |
# |           | <link href="images/favicon/favicon- |   <link href="styles/au-shared.css" |   <link href="styles/au-shared.css" |              <ul id="menu">         |   <link href="styles/au-shared.css" |
# |           | 16x16.png" rel="icon" sizes="16x16" |          rel="stylesheet">          |          rel="stylesheet">          |       <li><a href="https://www.wash |          rel="stylesheet">          |
# |           |          type="image/png"/>         |      <link href="styles/main.css"   |      <link href="styles/main.css"   | ington.edu/accesscomputing/AU/befor |      <link href="styles/main.css"   |
# |           |  <link href="styles/au-shared.css"  |          rel="stylesheet">          |          rel="stylesheet">          |          e.html#">About</a>         |          rel="stylesheet">          |
# |           |          rel="stylesheet"/>         |                   	<link href="styles/before-main.css" rel="stylesheet">                   |                   	<link href="styles/before-main.css" rel="stylesheet">                   |                     <ul>            |                   	<link href="styles/before-main.css" rel="stylesheet">                   |
# |           |     <link href="styles/main.css"    |                   	<link href="styles/before-menu.css" rel="stylesheet">                   |                   	<link href="styles/before-menu.css" rel="stylesheet">                   |           <li><a href="https://www. |                   	<link href="styles/before-menu.css" rel="stylesheet">                   |
# |           |          rel="stylesheet"/>         |                   	<link href="styles/before-form.css" rel="stylesheet">                   |                   	<link href="styles/before-form.css" rel="stylesheet">                   | washington.edu/accesscomputing/AU/s |                   	<link href="styles/before-form.css" rel="stylesheet">                   |
# |           | <link href="styles/before-main.css" |                   	<link href="styles/before-modal.css" rel="stylesheet">                   |                   	<link href="styles/before-modal.css" rel="stylesheet">                   | omepage.html?ref=News">News</a></li |                   	<link href="styles/before-modal.css" rel="stylesheet">                   |
# |           |          rel="stylesheet"/>         |                   	<link href="styles/before-carousel.css" rel="stylesheet">                   |                   	<link href="styles/before-carousel.css" rel="stylesheet">                   |                  >                  |                   	<link href="styles/before-carousel.css" rel="stylesheet">                   |
# |           | <link href="styles/before-menu.css" |   <script src="https://ajax.googlea |   <script src="https://ajax.googlea |           <li><a href="https://www. |   <script src="https://ajax.googlea |
# |           |          rel="stylesheet"/>         | pis.com/ajax/libs/jquery/3.6.0/jque | pis.com/ajax/libs/jquery/3.6.0/jque | washington.edu/accesscomputing/AU/s | pis.com/ajax/libs/jquery/3.6.0/jque |
# |           | <link href="styles/before-form.css" |         ry.min.js"></script>        |         ry.min.js"></script>        | omepage.html?ref=Governance">Govern |         ry.min.js"></script>        |
# |           |          rel="stylesheet"/>         |                   	<script src="scripts/before-menu.js"></script>                   |                   	<script src="scripts/before-menu.js"></script>                   |            ance</a></li>            |                   	<script src="scripts/before-menu.js"></script>                   |
# |           |      <link href="styles/before-     |                   	<script src="scripts/before-form.js"></script>                   |                   	<script src="scripts/before-form.js"></script>                   |           <li><a href="https://www. |                   	<script src="scripts/before-form.js"></script>                   |
# |           |    modal.css" rel="stylesheet"/>    |                   	<script src="scripts/before-modal.js"></script>                   |                   	<script src="scripts/before-modal.js"></script>                   | washington.edu/accesscomputing/AU/s |                   	<script src="scripts/before-modal.js"></script>                   |
# |           |      <link href="styles/before-     |                   	<script src="scripts/before-carousel.js"></script>                   |                   	<script src="scripts/before-carousel.js"></script>                   | omepage.html?ref=Diversity">Diversi |                   	<script src="scripts/before-carousel.js"></script>                   |
# |           |   carousel.css" rel="stylesheet"/>  |               </head>               |               </head>               |             ty</a></li>             |               </head>               |
# |           | <script src="https://ajax.googleapi |                <body>               |                <body>               |           <li><a href="https://www. |                <body>               |
# |           | s.com/ajax/libs/jquery/3.6.0/jquery |           <div id="content">        |           <div id="content">        | washington.edu/accesscomputing/AU/s |           <div id="content">        |
# |           |          .min.js"></script>         |                                     |                                     | omepage.html?ref=Contact%20Us">Cont |                                     |
# |           |     <script src="scripts/before-    |            <div id="banner">        |            <div id="banner">        |           act Us</a></li>           |            <div id="banner">        |
# |           |          menu.js"></script>         |               <img id="logo"        |               <img id="logo"        |                    </ul>            |               <img id="logo"        |
# |           |     <script src="scripts/before-    |     src="images/au123456789.gif"    |     src="images/au123456789.gif"    |                   </li>             |     src="images/au123456789.gif"    |
# |           |          form.js"></script>         |  alt="au123456789.gif" width="441"  |  alt="au123456789.gif" width="441"  |       <li><a href="https://www.wash |  alt="au123456789.gif" width="441"  |
# |           |     <script src="scripts/before-    |             height="90">            |             height="90">            | ington.edu/accesscomputing/AU/befor |             height="90">            |
# |           |         modal.js"></script>         |          <nav id="AU-menu" aria-    |          <nav id="AU-menu" aria-    |        e.html#">Academics</a>       |          <nav id="AU-menu" aria-    |
# |           |     <script src="scripts/before-    |       label="Demo site menu">       |       label="Demo site menu">       |                     <ul>            |       label="Demo site menu">       |
# |           |        carousel.js"></script>       |                     <ul>            |                     <ul>            |           <li><a href="https://www. |                     <ul>            |
# |           |               </head>               |                     <li><a          |                     <li><a          | washington.edu/accesscomputing/AU/s |                     <li><a          |
# |           |                <body>               |   href="index.html">Home</a></li>   |   href="index.html">Home</a></li>   | omepage.html?ref=Degree%20Programs" |   href="index.html">Home</a></li>   |
# |           |          <div id="content">         |           <li><a href="before.html" |           <li><a href="before.html" |      >Degree Programs</a></li>      |           <li><a href="before.html" |
# |           |          <div id="banner">          | aria-current="page">Before</a></li> | aria-current="page">Before</a></li> |           <li><a href="https://www. | aria-current="page">Before</a></li> |
# |           |      <img alt="au123456789.gif"     |                     <li><a          |                     <li><a          | washington.edu/accesscomputing/AU/s |                     <li><a          |
# |           |        height="90" id="logo"        |   href="after.html">After</a></li>  |   href="after.html">After</a></li>  |  omepage.html?ref=AU%20Faculty">AU  |   href="after.html">After</a></li>  |
# |           |     src="images/au123456789.gif"    |                     <li><a          |                     <li><a          |           Faculty</a></li>          |                     <li><a          |
# |           |            width="441"/>            |    href="info.html">Info</a></li>   |    href="info.html">Info</a></li>   |           <li><a href="https://www. |    href="info.html">Info</a></li>   |
# |           |   <nav aria-label="Demo site menu"  |                    </ul>            |                    </ul>            | washington.edu/accesscomputing/AU/s |                    </ul>            |
# |           |            id="AU-menu">            |                   </nav>            |                   </nav>            | omepage.html?ref=Distance%20Learnin |                   </nav>            |
# |           |                 <ul>                |                  </div>             |                  </div>             |    g">Distance Learning</a></li>    |                  </div>             |
# |           |                <li><a               |                                     |                                     |           <li><a href="https://www. |                                     |
# |           |   href="index.html">Home</a></li>   |              <ul id="menu">         |              <ul id="menu">         | washington.edu/accesscomputing/AU/s |              <ul id="menu">         |
# |           |      <li><a aria-current="page"     |         <li><a href="#">About</a>   |         <li><a href="#">About</a>   | omepage.html?ref=Libraries">Librari |         <li><a href="#">About</a>   |
# |           |  href="before.html">Before</a></li> |                     <ul>            |                     <ul>            |             es</a></li>             |                     <ul>            |
# |           |                <li><a               |           <li><a href="somepage.htm |           <li><a href="somepage.htm |                    </ul>            |           <li><a href="somepage.htm |
# |           |   href="after.html">After</a></li>  |      l?ref=News">News</a></li>      |      l?ref=News">News</a></li>      |                   </li>             |      l?ref=News">News</a></li>      |
# |           |                <li><a               |           <li><a href="somepage.htm |           <li><a href="somepage.htm |       <li><a href="https://www.wash |           <li><a href="somepage.htm |
# |           |    href="info.html">Info</a></li>   | l?ref=Governance">Governance</a></l | l?ref=Governance">Governance</a></l | ington.edu/accesscomputing/AU/befor | l?ref=Governance">Governance</a></l |
# |           |                </ul>                |                  i>                 |                  i>                 |       e.html#">Admissions</a>       |                  i>                 |
# |           |                </nav>               |           <li><a href="somepage.htm |           <li><a href="somepage.htm |                     <ul>            |           <li><a href="somepage.htm |
# |           |                </div>               | l?ref=Diversity">Diversity</a></li> | l?ref=Diversity">Diversity</a></li> |           <li><a href="https://www. | l?ref=Diversity">Diversity</a></li> |
# |           |            <ul id="menu">           |           <li><a href="somepage.htm |           <li><a href="somepage.htm | washington.edu/accesscomputing/AU/s |           <li><a href="somepage.htm |
# |           |      <li><a href="#">About</a>      |     l?ref=Contact%20Us">Contact     |     l?ref=Contact%20Us">Contact     | omepage.html?ref=Undergraduate">Und |     l?ref=Contact%20Us">Contact     |
# |           |                 <ul>                |             Us</a></li>             |             Us</a></li>             |         ergraduate</a></li>         |             Us</a></li>             |
# |           | <li><a href="somepage.html?ref=News |                    </ul>            |                    </ul>            |           <li><a href="https://www. |                    </ul>            |
# |           |           ">News</a></li>           |                   </li>             |                   </li>             | washington.edu/accesscomputing/AU/s |                   </li>             |
# |           | <li><a href="somepage.html?ref=Gove |       <li><a href="#">Academics</a> |       <li><a href="#">Academics</a> | omepage.html?ref=Graduate">Graduate |       <li><a href="#">Academics</a> |
# |           |     rnance">Governance</a></li>     |                     <ul>            |                     <ul>            |              </a></li>              |                     <ul>            |
# |           | <li><a href="somepage.html?ref=Dive |           <li><a href="somepage.htm |           <li><a href="somepage.htm |           <li><a href="https://www. |           <li><a href="somepage.htm |
# |           |      rsity">Diversity</a></li>      |   l?ref=Degree%20Programs">Degree   |   l?ref=Degree%20Programs">Degree   | washington.edu/accesscomputing/AU/s |   l?ref=Degree%20Programs">Degree   |
# |           | <li><a href="somepage.html?ref=Cont |          Programs</a></li>          |          Programs</a></li>          | omepage.html?ref=Tuition">Tuition</ |          Programs</a></li>          |
# |           |    act%20Us">Contact Us</a></li>    |           <li><a href="somepage.htm |           <li><a href="somepage.htm |               a></li>               |           <li><a href="somepage.htm |
# |           |                </ul>                |        l?ref=AU%20Faculty">AU       |        l?ref=AU%20Faculty">AU       |           <li><a href="https://www. |        l?ref=AU%20Faculty">AU       |
# |           |                </li>                |           Faculty</a></li>          |           Faculty</a></li>          | washington.edu/accesscomputing/AU/s |           Faculty</a></li>          |
# |           |    <li><a href="#">Academics</a>    |           <li><a href="somepage.htm |           <li><a href="somepage.htm | omepage.html?ref=Financial%20Aid">F |           <li><a href="somepage.htm |
# |           |                 <ul>                | l?ref=Distance%20Learning">Distance | l?ref=Distance%20Learning">Distance |        inancial Aid</a></li>        | l?ref=Distance%20Learning">Distance |
# |           | <li><a href="somepage.html?ref=Degr |          Learning</a></li>          |          Learning</a></li>          |                    </ul>            |          Learning</a></li>          |
# |           |        ee%20Programs">Degree        |           <li><a href="somepage.htm |           <li><a href="somepage.htm |                   </li>             |           <li><a href="somepage.htm |
# |           |          Programs</a></li>          | l?ref=Libraries">Libraries</a></li> | l?ref=Libraries">Libraries</a></li> |       <li><a href="https://www.wash | l?ref=Libraries">Libraries</a></li> |
# |           | <li><a href="somepage.html?ref=AU%2 |                    </ul>            |                    </ul>            | ington.edu/accesscomputing/AU/befor |                    </ul>            |
# |           |    0Faculty">AU Faculty</a></li>    |                   </li>             |                   </li>             |        e.html#">Visitors</a>        |                   </li>             |
# |           | <li><a href="somepage.html?ref=Dist |                   <li><a            |                   <li><a            |                     <ul>            |                   <li><a            |
# |           |      ance%20Learning">Distance      |       href="#">Admissions</a>       |       href="#">Admissions</a>       |           <li><a href="https://www. |       href="#">Admissions</a>       |
# |           |          Learning</a></li>          |                     <ul>            |                     <ul>            | washington.edu/accesscomputing/AU/s |                     <ul>            |
# |           | <li><a href="somepage.html?ref=Libr |           <li><a href="somepage.htm |           <li><a href="somepage.htm | omepage.html?ref=Events">Events</a> |           <li><a href="somepage.htm |
# |           |      aries">Libraries</a></li>      | l?ref=Undergraduate">Undergraduate< | l?ref=Undergraduate">Undergraduate< |                </li>                | l?ref=Undergraduate">Undergraduate< |
# |           |                </ul>                |               /a></li>              |               /a></li>              |           <li><a href="https://www. |               /a></li>              |
# |           |                </li>                |           <li><a href="somepage.htm |           <li><a href="somepage.htm | washington.edu/accesscomputing/AU/s |           <li><a href="somepage.htm |
# |           |    <li><a href="#">Admissions</a>   |  l?ref=Graduate">Graduate</a></li>  |  l?ref=Graduate">Graduate</a></li>  | omepage.html?ref=Campus_Map">Campus |  l?ref=Graduate">Graduate</a></li>  |
# |           |                 <ul>                |           <li><a href="somepage.htm |           <li><a href="somepage.htm |             Map</a></li>            |           <li><a href="somepage.htm |
# |           | <li><a href="somepage.html?ref=Unde |   l?ref=Tuition">Tuition</a></li>   |   l?ref=Tuition">Tuition</a></li>   |           <li><a href="https://www. |   l?ref=Tuition">Tuition</a></li>   |
# |           |  rgraduate">Undergraduate</a></li>  |           <li><a href="somepage.htm |           <li><a href="somepage.htm | washington.edu/accesscomputing/AU/s |           <li><a href="somepage.htm |
# |           | <li><a href="somepage.html?ref=Grad |   l?ref=Financial%20Aid">Financial  |   l?ref=Financial%20Aid">Financial  | omepage.html?ref=Parking">Parking</ |   l?ref=Financial%20Aid">Financial  |
# |           |       uate">Graduate</a></li>       |             Aid</a></li>            |             Aid</a></li>            |               a></li>               |             Aid</a></li>            |
# |           | <li><a href="somepage.html?ref=Tuit |                    </ul>            |                    </ul>            |                    </ul>            |                    </ul>            |
# |           |        ion">Tuition</a></li>        |                   </li>             |                   </li>             |                   </li>             |                   </li>             |
# |           | <li><a href="somepage.html?ref=Fina |        <li><a href="#">Visitors</a> |        <li><a href="#">Visitors</a> |                  </ul>              |        <li><a href="#">Visitors</a> |
# |           | ncial%20Aid">Financial Aid</a></li> |                     <ul>            |                     <ul>            |                                     |                     <ul>            |
# |           |                </ul>                |           <li><a href="somepage.htm |           <li><a href="somepage.htm |             <div id="main">         |           <li><a href="somepage.htm |
# |           |                </li>                |    l?ref=Events">Events</a></li>    |    l?ref=Events">Events</a></li>    |                                     |    l?ref=Events">Events</a></li>    |
# |           |     <li><a href="#">Visitors</a>    |           <li><a href="somepage.htm |           <li><a href="somepage.htm |            <div id="carousel">      |           <li><a href="somepage.htm |
# |           |                 <ul>                |       l?ref=Campus_Map">Campus      |       l?ref=Campus_Map">Campus      |             <div id="controls">     |       l?ref=Campus_Map">Campus      |
# |           | <li><a href="somepage.html?ref=Even |             Map</a></li>            |             Map</a></li>            |           <div id="btn-prev"></div> |             Map</a></li>            |
# |           |         ts">Events</a></li>         |           <li><a href="somepage.htm |           <li><a href="somepage.htm |           <div id="btn-next"></div> |           <li><a href="somepage.htm |
# |           | <li><a href="somepage.html?ref=Camp |   l?ref=Parking">Parking</a></li>   |   l?ref=Parking">Parking</a></li>   |                    </div>           |   l?ref=Parking">Parking</a></li>   |
# |           |     us_Map">Campus Map</a></li>     |                    </ul>            |                    </ul>            |              <div id="slides">      |                    </ul>            |
# |           | <li><a href="somepage.html?ref=Park |                   </li>             |                   </li>             |               <div class="slide     |                   </li>             |
# |           |        ing">Parking</a></li>        |                  </ul>              |                  </ul>              |              current">              |                  </ul>              |
# |           |                </ul>                |                                     |                                     |             <img src="https://www.w |                                     |
# |           |                </li>                |             <div id="main">         |             <div id="main">         | ashington.edu/accesscomputing/AU/im |             <div id="main">         |
# |           |                </ul>                |                                     |                                     |      ages/carousel/slide1.jpg">     |                                     |
# |           |           <div id="main">           |            <div id="carousel">      |            <div id="carousel">      |              <div class="caption">A |            <div id="carousel">      |
# |           |         <div id="carousel">         |             <div id="controls">     |             <div id="controls">     |          modern shool</div>         |             <div id="controls">     |
# |           |         <div id="controls">         |           <div id="btn-prev"></div> |           <div id="btn-prev"></div> |                     </div>          |           <div id="btn-prev"></div> |
# |           |      <div id="btn-prev"></div>      |           <div id="btn-next"></div> |           <div id="btn-next"></div> |              <div class="slide">    |           <div id="btn-next"></div> |
# |           |      <div id="btn-next"></div>      |                    </div>           |                    </div>           |             <img src="https://www.w |                    </div>           |
# |           |                </div>               |              <div id="slides">      |              <div id="slides">      | ashington.edu/accesscomputing/AU/im |              <div id="slides">      |
# |           |          <div id="slides">          |               <div class="slide     |               <div class="slide     |      ages/carousel/slide2.jpg">     |               <div class="slide     |
# |           |         <div class="slide">         |              current">              |              current">              |                       <div          |              current">              |
# |           |                 <img                |                       <img          |                       <img          |    class="caption">rooted in its    |                       <img          |
# |           |  src="images/carousel/slide1.jpg"/> |  src="images/carousel/slide1.jpg">  |  src="images/carousel/slide1.jpg">  |            history</div>            |   src="images/carousel/slide1.jpg"  |
# |           |    <div class="caption">A modern    |              <div class="caption">A |              <div class="caption">A |                     </div>          |      width="580" height="326">      |
# |           |             shool</div>             |          modern shool</div>         |          modern shool</div>         |              <div class="slide">    |              <div class="caption">A |
# |           |                </div>               |                     </div>          |                     </div>          |             <img src="https://www.w |          modern shool</div>         |
# |           |         <div class="slide">         |              <div class="slide">    |              <div class="slide">    | ashington.edu/accesscomputing/AU/im |                     </div>          |
# |           |                 <img                |                       <img          |                       <img          |      ages/carousel/slide3.jpg">     |              <div class="slide">    |
# |           |  src="images/carousel/slide2.jpg"/> |  src="images/carousel/slide2.jpg">  |  src="images/carousel/slide2.jpg">  |                       <div          |                       <img          |
# |           |  <div class="caption">rooted in its |                       <div          |                       <div          |  class="caption">with opportunities |  src="images/carousel/slide2.jpg">  |
# |           |            history</div>            |    class="caption">rooted in its    |    class="caption">rooted in its    |            to learn</div>           |                       <div          |
# |           |                </div>               |            history</div>            |            history</div>            |                     </div>          |    class="caption">rooted in its    |
# |           |         <div class="slide">         |                     </div>          |                     </div>          |              <div class="slide">    |            history</div>            |
# |           |                 <img                |              <div class="slide">    |              <div class="slide">    |             <img src="https://www.w |                     </div>          |
# |           |  src="images/carousel/slide3.jpg"/> |                       <img          |                       <img          | ashington.edu/accesscomputing/AU/im |              <div class="slide">    |
# |           |      <div class="caption">with      |  src="images/carousel/slide3.jpg">  |  src="images/carousel/slide3.jpg">  |      ages/carousel/slide4.jpg">     |                       <img          |
# |           |     opportunities to learn</div>    |                       <div          |                       <div          |                       <div          |  src="images/carousel/slide3.jpg">  |
# |           |                </div>               |  class="caption">with opportunities |  class="caption">with opportunities |   class="caption">and grow.</div>   |                       <div          |
# |           |         <div class="slide">         |            to learn</div>           |            to learn</div>           |                     </div>          |  class="caption">with opportunities |
# |           |                 <img                |                     </div>          |                     </div>          |                    </div>           |            to learn</div>           |
# |           |  src="images/carousel/slide4.jpg"/> |              <div class="slide">    |              <div class="slide">    |       <ul class="lentils"><li data- |                     </div>          |
# |           |       <div class="caption">and      |                       <img          |                       <img          |  slide="0" class="active"></li><li  |              <div class="slide">    |
# |           |             grow.</div>             |  src="images/carousel/slide4.jpg">  |  src="images/carousel/slide4.jpg">  |    data-slide="1"></li><li data-    |                       <img          |
# |           |                </div>               |                       <div          |                       <div          |       slide="2"></li><li data-      |  src="images/carousel/slide4.jpg">  |
# |           |                </div>               |   class="caption">and grow.</div>   |   class="caption">and grow.</div>   |      slide="3"></li></ul></div>     |                       <div          |
# |           |                </div>               |                     </div>          |                     </div>          |                                     |   class="caption">and grow.</div>   |
# |           | <div class="heading">Welcome!</div> |                    </div>           |                    </div>           |                    <div             |                     </div>          |
# |           |  <p>Accessible University (AU) is a |       <ul class="lentils"><li data- |       <ul class="lentils"><li data- |    class="heading">Welcome!</div>   |                    </div>           |
# |           |  fictional university, and this is  |  slide="0" class="active"></li><li  |  slide="0" class="active"></li><li  |       <p>Accessible University (AU) |       <ul class="lentils"><li data- |
# |           |                 its                 |    data-slide="1"></li><li data-    |    data-slide="1"></li><li data-    | is a fictional university, and this |  slide="0" class="active"></li><li  |
# |           |          fictional home page. This  |       slide="2"></li><li data-      |       slide="2"></li><li data-      |                is its               |    data-slide="1"></li><li data-    |
# |           |  page is designed to demonstrate a  |      slide="3"></li></ul></div>     |      slide="3"></li></ul></div>     |          fictional home page. This  |       slide="2"></li><li data-      |
# |           |              variety of             |                                     |                                     |  page is designed to demonstrate a  |      slide="3"></li></ul></div>     |
# |           |          common web design problems |                    <div             |                    <div             |              variety of             |                                     |
# |           |     that result in visitors with    |    class="heading">Welcome!</div>   |    class="heading">Welcome!</div>   |          common web design problems |                    <div             |
# |           |             disabilities            |       <p>Accessible University (AU) |       <p>Accessible University (AU) |     that result in visitors with    |    class="heading">Welcome!</div>   |
# |           |          being unable to access the | is a fictional university, and this | is a fictional university, and this |             disabilities            |       <p>Accessible University (AU) |
# |           |  content or features of a web page. |                is its               |                is its               |          being unable to access the | is a fictional university, and this |
# |           |         Although the heading at the |          fictional home page. This  |          fictional home page. This  |  content or features of a web page. |                is its               |
# |           |   top of this section of the page   |  page is designed to demonstrate a  |  page is designed to demonstrate a  |         Although the heading at the |          fictional home page. This  |
# |           |          suggests that AU may be a  |              variety of             |              variety of             |   top of this section of the page   |  page is designed to demonstrate a  |
# |           |        welcoming institution,       |          common web design problems |          common web design problems |          suggests that AU may be a  |              variety of             |
# |           |          the inaccessible design of |     that result in visitors with    |     that result in visitors with    |        welcoming institution,       |          common web design problems |
# |           |     this page sends the opposite    |             disabilities            |             disabilities            |          the inaccessible design of |     that result in visitors with    |
# |           |               message.              |          being unable to access the |          being unable to access the |     this page sends the opposite    |             disabilities            |
# |           |                    </p>             |  content or features of a web page. |  content or features of a web page. |               message.              |          being unable to access the |
# |           |  <img alt="horizontal line graphic" |         Although the heading at the |         Although the heading at the |                    </p>             |  content or features of a web page. |
# |           |              class="hr"             |   top of this section of the page   |   top of this section of the page   |                                     |         Although the heading at the |
# |           |   src="images/line_gradient.gif"/>  |          suggests that AU may be a  |          suggests that AU may be a  |       <img class="hr" src="https:// |   top of this section of the page   |
# |           |                 <div                |        welcoming institution,       |        welcoming institution,       | www.washington.edu/accesscomputing/ |          suggests that AU may be a  |
# |           |  class="heading">Bienvenido!</div>  |          the inaccessible design of |          the inaccessible design of |     AU/images/line_gradient.gif"    |        welcoming institution,       |
# |           |   <p>Accesible Universidad (UA) es  |     this page sends the opposite    |     this page sends the opposite    |    alt="horizontal line graphic">   |          the inaccessible design of |
# |           | una universidad ficticia, y esta es |               message.              |               message.              |                                     |     this page sends the opposite    |
# |           |                  su                 |                    </p>             |                    </p>             |                    <div             |               message.              |
# |           |           página de ficción. Esta   |                                     |                                     |  class="heading">Bienvenido!</div>  |                    </p>             |
# |           | página está diseñada para demostrar |              <img class="hr"        |              <img class="hr"        |       <p>Accesible Universidad (UA) |                                     |
# |           |           una variedad de           |    src="images/line_gradient.gif"   |    src="images/line_gradient.gif"   | es una universidad ficticia, y esta |              <img class="hr"        |
# |           |          común de diseño web que se |    alt="horizontal line graphic">   |    alt="horizontal line graphic">   |                es su                |    src="images/line_gradient.gif"   |
# |           |     traducen en problemas de los    |                                     |                                     |           página de ficción. Esta   |    alt="horizontal line graphic"    |
# |           |     visitantes con discapacidad     |                    <div             |                    <div             | página está diseñada para demostrar |       width="400" height="5">       |
# |           |             no poder acceder al     |  class="heading">Bienvenido!</div>  |  class="heading">Bienvenido!</div>  |           una variedad de           |                                     |
# |           |  contenido o las características de |       <p>Accesible Universidad (UA) |       <p>Accesible Universidad (UA) |          común de diseño web que se |                    <div             |
# |           |           una página web.           | es una universidad ficticia, y esta | es una universidad ficticia, y esta |     traducen en problemas de los    |  class="heading">Bienvenido!</div>  |
# |           |            Aunque el título en la   |                es su                |                es su                |     visitantes con discapacidad     |       <p>Accesible Universidad (UA) |
# |           |  parte superior de esta sección de  |           página de ficción. Esta   |           página de ficción. Esta   |             no poder acceder al     | es una universidad ficticia, y esta |
# |           |              la página              | página está diseñada para demostrar | página está diseñada para demostrar |  contenido o las características de |                es su                |
# |           |           sugiere que AU puede ser  |           una variedad de           |           una variedad de           |           una página web.           |           página de ficción. Esta   |
# |           |    una institución de bienvenida,   |          común de diseño web que se |          común de diseño web que se |            Aunque el título en la   | página está diseñada para demostrar |
# |           |           el diseño inaccesible de  |     traducen en problemas de los    |     traducen en problemas de los    |  parte superior de esta sección de  |           una variedad de           |
# |           |     esta página envía el mensaje    |     visitantes con discapacidad     |     visitantes con discapacidad     |              la página              |          común de diseño web que se |
# |           |               opuesto.              |             no poder acceder al     |             no poder acceder al     |           sugiere que AU puede ser  |     traducen en problemas de los    |
# |           |                    </p>             |  contenido o las características de |  contenido o las características de |    una institución de bienvenida,   |     visitantes con discapacidad     |
# |           |  <img alt="horizontal line graphic" |           una página web.           |           una página web.           |           el diseño inaccesible de  |             no poder acceder al     |
# |           |              class="hr"             |            Aunque el título en la   |            Aunque el título en la   |     esta página envía el mensaje    |  contenido o las características de |
# |           |   src="images/line_gradient.gif"/>  |  parte superior de esta sección de  |  parte superior de esta sección de  |               opuesto.              |           una página web.           |
# |           |  <div class="heading">Can you spot  |              la página              |              la página              |                    </p>             |            Aunque el título en la   |
# |           |         the barriers?</div>         |           sugiere que AU puede ser  |           sugiere que AU puede ser  |                                     |  parte superior de esta sección de  |
# |           |       <p>There are at least 22      |    una institución de bienvenida,   |    una institución de bienvenida,   |       <img class="hr" src="https:// |              la página              |
# |           |  accessibility issues on this page. |           el diseño inaccesible de  |           el diseño inaccesible de  | www.washington.edu/accesscomputing/ |           sugiere que AU puede ser  |
# |           |          To see a list of all known |     esta página envía el mensaje    |     esta página envía el mensaje    |     AU/images/line_gradient.gif"    |    una institución de bienvenida,   |
# |           |  issues, <a href="info.html">click  |               opuesto.              |               opuesto.              |    alt="horizontal line graphic">   |           el diseño inaccesible de  |
# |           |              here</a>.              |                    </p>             |                    </p>             |                                     |     esta página envía el mensaje    |
# |           |           To see a more accessible  |                                     |                                     |        <div class="heading">Can you |               opuesto.              |
# |           |    version of this same page, <a    |              <img class="hr"        |              <img class="hr"        |       spot the barriers?</div>      |                    </p>             |
# |           |  href="after.html">click here</a>.  |    src="images/line_gradient.gif"   |    src="images/line_gradient.gif"   |          <p>There are at least 22   |                                     |
# |           |             For a cheat sheet of    |    alt="horizontal line graphic">   |    alt="horizontal line graphic">   |  accessibility issues on this page. |              <img class="hr"        |
# |           |       accessibility issues, <a      |                                     |                                     |          To see a list of all known |    src="images/line_gradient.gif"   |
# |           |     href="cheatsheet.html">click    |        <div class="heading">Can you |        <div class="heading">Can you | issues, <a href="https://www.washin |    alt="horizontal line graphic"    |
# |           |              here</a>.              |       spot the barriers?</div>      |       spot the barriers?</div>      | gton.edu/accesscomputing/AU/info.ht |       width="400" height="5">       |
# |           |                    </p>             |          <p>There are at least 22   |          <p>There are at least 22   |         ml">click here</a>.         |                                     |
# |           |  <img alt="horizontal line graphic" |  accessibility issues on this page. |  accessibility issues on this page. |           To see a more accessible  |        <div class="heading">Can you |
# |           |              class="hr"             |          To see a list of all known |          To see a list of all known | version of this same page, <a href= |       spot the barriers?</div>      |
# |           |   src="images/line_gradient.gif"/>  |  issues, <a href="info.html">click  |  issues, <a href="info.html">click  | "https://www.washington.edu/accessc |          <p>There are at least 22   |
# |           |  <div class="heading">AU Enrollment |              here</a>.              |              here</a>.              |    omputing/AU/after.html">click    |  accessibility issues on this page. |
# |           |             Trends</div>            |           To see a more accessible  |           To see a more accessible  |              here</a>.              |          To see a list of all known |
# |           |       <table id="enrollment">       |    version of this same page, <a    |    version of this same page, <a    |             For a cheat sheet of    |  issues, <a href="info.html">click  |
# |           |                 <tr>                |  href="after.html">click here</a>.  |  href="after.html">click here</a>.  | accessibility issues, <a href="http |              here</a>.              |
# ...
# |           |                                     |        <div id="modalContent">      |        <div id="modalContent">      |                                     |                                     |
# |           |                                     |      <div class="modalHeading">List |      <div class="modalHeading">List |                                     |     <!--containers for displaying   |
# |           |                                     |    of accessibility issues</div>    |    of accessibility issues</div>    |                                     |           modal content-->          |
# |           |                                     |          <button type="button"      |          <button type="button"      |                                     |       <div id="modalMask"></div>    |
# |           |                                     |     id="modalXButton">x</button>    |     id="modalXButton">x</button>    |                                     |                                     |
# |           |                                     |       <p>Note: This popup does not  |       <p>Note: This popup does not  |                                     |        <div id="modalContent">      |
# |           |                                     |  receive keyboard focus. The cursor |  receive keyboard focus. The cursor |                                     |      <div class="modalHeading">List |
# |           |                                     |    continues to tab down the page   |    continues to tab down the page   |                                     |    of accessibility issues</div>    |
# |           |                                     |      behind the it. As a result     |      behind the it. As a result     |                                     |          <button type="button"      |
# |           |                                     |  keyboard-only users cannot dismiss |  keyboard-only users cannot dismiss |                                     |     id="modalXButton">x</button>    |
# |           |                                     | it and screen reader users will not | it and screen reader users will not |                                     |       <p>Note: This popup does not  |
# |           |                                     |  be alerted to it's presence. They  |  be alerted to it's presence. They  |                                     |  receive keyboard focus. The cursor |
# |           |                                     |    will not be able to close it;    |    will not be able to close it;    |                                     |    continues to tab down the page   |
# |           |                                     |  rendering the webpage useless.</p> |  rendering the webpage useless.</p> |                                     |      behind the it. As a result     |
# |           |                                     |      <p>On the inaccessible version |      <p>On the inaccessible version |                                     |  keyboard-only users cannot dismiss |
# |           |                                     |  of this page the following errors  |  of this page the following errors  |                                     | it and screen reader users will not |
# |           |                                     |          can be found:</p>          |          can be found:</p>          |                                     |  be alerted to it's presence. They  |
# |           |                                     |                   <ol>              |                   <ol>              |                                     |    will not be able to close it;    |
# |           |                                     |          <li>Missing bypass block   |          <li>Missing bypass block   |                                     |  rendering the webpage useless.</p> |
# |           |                                     |   <br>(skip-to main content).</li>  |   <br>(skip-to main content).</li>  |                                     |      <p>On the inaccessible version |
# |           |                                     |            <li>Improper use of      |            <li>Improper use of      |                                     |  of this page the following errors  |
# |           |                                     |            headings</li>            |            headings</li>            |                                     |          can be found:</p>          |
# |           |                                     |          <li>Images of text</li>    |          <li>Images of text</li>    |                                     |                   <ol>              |
# |           |                                     |          <li>No alternate text on   |          <li>No alternate text on   |                                     |          <li>Missing bypass block   |
# |           |                                     |       informative images</li>       |       informative images</li>       |                                     |   <br>(skip-to main content).</li>  |
# |           |                                     |          <li>Missing or excessive   |          <li>Missing or excessive   |                                     |            <li>Improper use of      |
# |           |                                     |     alternate text on decorative    |     alternate text on decorative    |                                     |            headings</li>            |
# |           |                                     |             images</li>             |             images</li>             |                                     |          <li>Images of text</li>    |
# |           |                                     |           <li>Insufficient color    |           <li>Insufficient color    |                                     |          <li>No alternate text on   |
# |           |                                     |            contrast</li>            |            contrast</li>            |                                     |       informative images</li>       |
# |           |                                     |          <li>Insufficient visual    |          <li>Insufficient visual    |                                     |          <li>Missing or excessive   |
# |           |                                     |              cues</li>              |              cues</li>              |                                     |     alternate text on decorative    |
# |           |                                     |         <li>Inaccessible dropdown   |         <li>Inaccessible dropdown   |                                     |             images</li>             |
# |           |                                     |              menu</li>              |              menu</li>              |                                     |           <li>Insufficient color    |
# |           |                                     |        <li>Redundant, uninformative |        <li>Redundant, uninformative |                                     |            contrast</li>            |
# |           |                                     |            link text</li>           |            link text</li>           |                                     |          <li>Insufficient visual    |
# |           |                                     |       <li>Color used to communicate |       <li>Color used to communicate |                                     |              cues</li>              |
# |           |                                     |           information</li>          |           information</li>          |                                     |         <li>Inaccessible dropdown   |
# |           |                                     |              <li>Language not       |              <li>Language not       |                                     |              menu</li>              |
# |           |                                     |            specified</li>           |            specified</li>           |                                     |        <li>Redundant, uninformative |
# |           |                                     |        <li>Missing accessible form  |        <li>Missing accessible form  |                                     |            link text</li>           |
# |           |                                     |             markup</li>             |             markup</li>             |                                     |       <li>Color used to communicate |
# |           |                                     |       <li>Inaccessible CAPTCHA</li> |       <li>Inaccessible CAPTCHA</li> |                                     |           information</li>          |
# |           |                                     |              <li>Inaccessible       |              <li>Inaccessible       |                                     |              <li>Language not       |
# |           |                                     |           validation</li>           |           validation</li>           |                                     |            specified</li>           |
# |           |                                     |         <li>Missing ARIA landmark   |         <li>Missing ARIA landmark   |                                     |        <li>Missing accessible form  |
# |           |                                     |              roles</li>             |              roles</li>             |                                     |             markup</li>             |
# |           |                                     |           <li>Inaccessible modal    |           <li>Inaccessible modal    |                                     |       <li>Inaccessible CAPTCHA</li> |
# |           |                                     |             window</li>             |             window</li>             |                                     |              <li>Inaccessible       |
# |           |                                     |              <li>Inaccessible       |              <li>Inaccessible       |                                     |           validation</li>           |
# |           |                                     |            carousel</li>            |            carousel</li>            |                                     |         <li>Missing ARIA landmark   |
# |           |                                     |        <li>Missing accessible table |        <li>Missing accessible table |                                     |              roles</li>             |
# |           |                                     |             markup</li>             |             markup</li>             |                                     |           <li>Inaccessible modal    |
# |           |                                     |               <li>HTML fails        |               <li>HTML fails        |                                     |             window</li>             |
# |           |                                     |           validation</li>           |           validation</li>           |                                     |              <li>Inaccessible       |
# |           |                                     |                  </ol>              |                  </ol>              |                                     |            carousel</li>            |
# |           |                                     |     <button class="btn btn-primary" |     <button class="btn btn-primary" |                                     |        <li>Missing accessible table |
# |           |                                     |            type="button"            |            type="button"            |                                     |             markup</li>             |
# |           |                                     |    id="modalOkButton">OK</button>   |    id="modalOkButton">OK</button>   |                                     |               <li>HTML fails        |
# |           |                                     |                 </div>              |                 </div>              |                                     |           validation</li>           |
# |           |                                     |                                     |                                     |                                     |                  </ol>              |
# |           |                                     |     <div id="footer" role="bottom"  |     <div id="footer" role="bottom"  |                                     |     <button class="btn btn-primary" |
# |           |                                     | aria-foo="yes"><span>.</span></div> | aria-foo="yes"><span>.</span></div> |                                     |            type="button"            |
# |           |                                     |                                     |                                     |                                     |    id="modalOkButton">OK</button>   |
# |           |                                     |                                     |                                     |                                     |                 </div>              |
# |           |                                     |            </body></html>           |            </body></html>           |                                     |                                     |
# |           |                                     |                                     |                                     |                                     |     <div id="footer" role="bottom"  |
# |           |                                     |                                     |                                     |                                     | aria-foo="yes"><span>.</span></div> |
# |           |                                     |                                     |                                     |                                     |                                     |
# |           |                                     |                                     |                                     |                                     |                                     |
# |           |                                     |                                     |                                     |                                     |            </body></html>           |
# +-----------+-------------------------------------+-------------------------------------+-------------------------------------+-------------------------------------+-------------------------------------+
#
# Cost Table:
# This is how much it would cost to use gpt-4o to use this content as input (estimated, not real).
# +-----------+---------------------------+---------------------------+---------------------------+---------------------------+---------------------------+
# | Site Name |    Beautiful Soup cost    |        Jina AI cost       |      Playwright cost      |       Firecrawl cost      |       Crawl4ai cost       |
# +-----------+---------------------------+---------------------------+---------------------------+---------------------------+---------------------------+
# |   Site 1  | $0.006993 (tokens: 2,797) | $0.008103 (tokens: 3,241) | $0.008112 (tokens: 3,245) | $0.007378 (tokens: 2,951) | $0.008233 (tokens: 3,293) |
# +-----------+---------------------------+---------------------------+---------------------------+---------------------------+---------------------------+
# |   Site 2  | $0.008127 (tokens: 3,251) | $0.009633 (tokens: 3,853) | $0.009643 (tokens: 3,857) | $0.006520 (tokens: 2,608) | $0.009763 (tokens: 3,905) |
# +-----------+---------------------------+---------------------------+---------------------------+---------------------------+---------------------------+

# %% [markdown]
# The result from `Crawl4ai` is saved in HTML format for future comparison.

# %%
import os

def generate_output_scrape_file(prefix: str, content: str):
    # Create the output directory if it doesn't exist
    if not os.path.exists("output/original"):
        os.makedirs("output/original")

    # Write the HTML content to files
    with open(f'output/original/{prefix}-original.html', 'w', encoding='utf-8') as f:
        f.write(content)

# Save the scraped content to files
for items in all_content_html:
    for site in items["sites"]:
        if site["name"] == "Crawl4ai":
            generate_output_scrape_file(items["provider"], site["content"])

# %% [markdown]
# ## Comparison using Markdown
#
# We will run all scrapers again, this time retrieving output in a format more suitable for LLMs.

# %%
all_content_md = view_scraped_content(list_of_scraper_functions, test_sites, 1200, 35, to_markdown=True)
# Out:
# Processing site Site 1 using Beautiful Soup:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 1 using Jina AI:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 1 using Playwright:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 1 using Firecrawl:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 1 using Crawl4ai:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 2 using Beautiful Soup:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 2 using Jina AI:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 2 using Playwright:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 2 using Firecrawl:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing site Site 2 using Crawl4ai:   0%|          | 0/1 [00:00<?, ?it/s]
# Content Table:
# +-----------+-------------------------------------+-------------------------------------+-------------------------------------+-------------------------------------+-------------------------------------+
# | Site Name |        Beautiful Soup content       |           Jina AI content           |          Playwright content         |          Firecrawl content          |           Crawl4ai content          |
# +-----------+-------------------------------------+-------------------------------------+-------------------------------------+-------------------------------------+-------------------------------------+
# |   Site 1  |     5,055 characters retrieved:     |     7,519 characters retrieved:     |     5,055 characters retrieved:     |     5,530 characters retrieved:     |     6,962 characters retrieved:     |
# |           |                                     |                                     |                                     |                                     |                                     |
# |           |  Accessible University Demo Site -  |  Accessible University Demo Site -  |  Accessible University Demo Site -  | ![au123456789.gif](https://www.wash | ![au123456789.gif](https://www.wash |
# |           |         Inaccessible Version        |         Inaccessible Version        |         Inaccessible Version        | ington.edu/accesscomputing/AU/image | ington.edu/accesscomputing/AU/image |
# |           |                                     |                                     |                                     |          s/au123456789.gif)         |          s/au123456789.gif)         |
# |           |                                     |           ===============           |                                     |                                     |   * [Home](https://www.washington.e |
# |           |                                     |                                     |                                     | - [About](https://www.washington.ed |  du/accesscomputing/AU/index.html)  |
# |           | ![au123456789.gif](images/au1234567 | ![Image 1: au123456789.gif](https:/ | ![au123456789.gif](images/au1234567 |  u/accesscomputing/AU/before.html#) |   * [Before](https://www.washington |
# |           |               89.gif)               | /www.washington.edu/accesscomputing |               89.gif)               |   - [News](https://www.washington.e | .edu/accesscomputing/AU/before.html |
# |           |                                     |     /AU/images/au123456789.gif)     |                                     | du/accesscomputing/AU/somepage.html |                  )                  |
# |           |                                     | *   [Home](https://www.washington.e |                                     |              ?ref=News)             |   * [After](https://www.washington. |
# |           |         * [Home](index.html)        |  du/accesscomputing/AU/index.html)  |         * [Home](index.html)        |   - [Governance](https://www.washin |  edu/accesscomputing/AU/after.html) |
# |           |       * [Before](before.html)       | *   [Before](https://www.washington |       * [Before](before.html)       | gton.edu/accesscomputing/AU/somepag |   * [Info](https://www.washington.e |
# |           |        * [After](after.html)        | .edu/accesscomputing/AU/before.html |        * [After](after.html)        |        e.html?ref=Governance)       |   du/accesscomputing/AU/info.html)  |
# |           |         * [Info](info.html)         |                  )                  |         * [Info](info.html)         |   - [Diversity](https://www.washing |                                     |
# |           |                                     | *   [After](https://www.washington. |                                     | ton.edu/accesscomputing/AU/somepage |                                     |
# |           |             * [About](#)            |  edu/accesscomputing/AU/after.html) |             * [About](#)            |         .html?ref=Diversity)        |   * [About](https://www.washington. |
# |           |    + [News](somepage.html?ref=News) | *   [Info](https://www.washington.e |    + [News](somepage.html?ref=News) |   - [Contact Us](https://www.washin | edu/accesscomputing/AU/before.html) |
# |           |   + [Governance](somepage.html?ref= |   du/accesscomputing/AU/info.html)  |   + [Governance](somepage.html?ref= | gton.edu/accesscomputing/AU/somepag |     * [News](https://www.washington |
# |           |             Governance)             |                                     |             Governance)             |       e.html?ref=Contact%20Us)      | .edu/accesscomputing/AU/somepage.ht |
# |           |   + [Diversity](somepage.html?ref=D | *   [About](https://www.washington. |   + [Diversity](somepage.html?ref=D | - [Academics](https://www.washingto |             ml?ref=News)            |
# |           |              iversity)              | edu/accesscomputing/AU/before.html# |              iversity)              | n.edu/accesscomputing/AU/before.htm |     * [Governance](https://www.wash |
# |           |               + [Contact            |                  )                  |               + [Contact            |                 l#)                 | ington.edu/accesscomputing/AU/somep |
# |           | Us](somepage.html?ref=Contact%20Us) |     *   [News](https://www.washingt | Us](somepage.html?ref=Contact%20Us) |   - [Degree Programs](https://www.w |       age.html?ref=Governance)      |
# |           |           * [Academics](#)          | on.edu/accesscomputing/AU/somepage. |           * [Academics](#)          | ashington.edu/accesscomputing/AU/so |     * [Diversity](https://www.washi |
# |           |   + [Degree Programs](somepage.html |            html?ref=News)           |   + [Degree Programs](somepage.html |  mepage.html?ref=Degree%20Programs) | ngton.edu/accesscomputing/AU/somepa |
# |           |       ?ref=Degree%20Programs)       |     *   [Governance](https://www.wa |       ?ref=Degree%20Programs)       |   - [AU Faculty](https://www.washin |        ge.html?ref=Diversity)       |
# |           |   + [AU Faculty](somepage.html?ref= | shington.edu/accesscomputing/AU/som |   + [AU Faculty](somepage.html?ref= | gton.edu/accesscomputing/AU/somepag |     * [Contact Us](https://www.wash |
# |           |            AU%20Faculty)            |      epage.html?ref=Governance)     |            AU%20Faculty)            |       e.html?ref=AU%20Faculty)      | ington.edu/accesscomputing/AU/somep |
# |           |   + [Distance Learning](somepage.ht |     *   [Diversity](https://www.was |   + [Distance Learning](somepage.ht |   - [Distance Learning](https://www |      age.html?ref=Contact%20Us)     |
# |           |     ml?ref=Distance%20Learning)     | hington.edu/accesscomputing/AU/some |     ml?ref=Distance%20Learning)     | .washington.edu/accesscomputing/AU/ |   * [Academics](https://www.washing |
# |           |   + [Libraries](somepage.html?ref=L |       page.html?ref=Diversity)      |   + [Libraries](somepage.html?ref=L | somepage.html?ref=Distance%20Learni | ton.edu/accesscomputing/AU/before.h |
# |           |              ibraries)              |     *   [Contact Us](https://www.wa |              ibraries)              |                 ng)                 |                 tml)                |
# |           |          * [Admissions](#)          | shington.edu/accesscomputing/AU/som |          * [Admissions](#)          |   - [Libraries](https://www.washing |     * [Degree Programs](https://www |
# |           |   + [Undergraduate](somepage.html?r |     epage.html?ref=Contact%20Us)    |   + [Undergraduate](somepage.html?r | ton.edu/accesscomputing/AU/somepage | .washington.edu/accesscomputing/AU/ |
# |           |          ef=Undergraduate)          |                                     |          ef=Undergraduate)          |         .html?ref=Libraries)        | somepage.html?ref=Degree%20Programs |
# |           |   + [Graduate](somepage.html?ref=Gr | *   [Academics](https://www.washing |   + [Graduate](somepage.html?ref=Gr | - [Admissions](https://www.washingt |                  )                  |
# |           |               aduate)               | ton.edu/accesscomputing/AU/before.h |               aduate)               | on.edu/accesscomputing/AU/before.ht |     * [AU Faculty](https://www.wash |
# |           |   + [Tuition](somepage.html?ref=Tui |                tml#)                |   + [Tuition](somepage.html?ref=Tui |                 ml#)                | ington.edu/accesscomputing/AU/somep |
# |           |                tion)                |     *   [Degree Programs](https://w |                tion)                |   - [Undergraduate](https://www.was |      age.html?ref=AU%20Faculty)     |
# |           |   + [Financial Aid](somepage.html?r | ww.washington.edu/accesscomputing/A |   + [Financial Aid](somepage.html?r | hington.edu/accesscomputing/AU/some |     * [Distance Learning](https://w |
# |           |         ef=Financial%20Aid)         | U/somepage.html?ref=Degree%20Progra |         ef=Financial%20Aid)         |     page.html?ref=Undergraduate)    | ww.washington.edu/accesscomputing/A |
# |           |           * [Visitors](#)           |                 ms)                 |           * [Visitors](#)           |     - [Graduate](https://www.washi  | U/somepage.html?ref=Distance%20Lear |
# |           |                   +                 |     *   [AU Faculty](https://www.wa |                   +                 |                                     |                ning)                |
# |           |  [Events](somepage.html?ref=Events) | shington.edu/accesscomputing/AU/som |  [Events](somepage.html?ref=Events) |                                     |                                     |
# |           |               + [Campus             |     epage.html?ref=AU%20Faculty)    |               + [Campus             |                                     |                                     |
# |           |  Map](somepage.html?ref=Campus_Map) |               *   [Distanc          |  Map](somepage.html?ref=Campus_Map) |                                     |                                     |
# |           |   + [Parking](somepage.html?ref=Par |                                     |   + [Parking](somepage.html?ref=Par |                                     |                                     |
# |           |                king)                |                                     |                king)                |                                     |                                     |
# |           |                                     |                                     |                                     |                                     |                                     |
# |           |   ![](images/carousel/slide1.jpg)   |                                     |   ![](images/carousel/slide1.jpg)   |                                     |                                     |
# |           |                                     |                                     |                                     |                                     |                                     |
# |           |            A modern shool           |                                     |            A modern shool           |                                     |                                     |
# |           |                                     |                                     |                                     |                                     |                                     |
# |           |   ![](images/carousel/slide2.jpg)   |                                     |   ![](images/carousel/slide2.jpg)   |                                     |                                     |
# |           |                                     |                                     |                                     |                                     |                                     |
# |           |        rooted in its history        |                                     |        rooted in its history        |                                     |                                     |
# |           |                                     |                                     |                                     |                                     |                                     |
# |           |   ![](images/carousel/slide3.jpg)   |                                     |   ![](images/carousel/slide3.jpg)   |                                     |                                     |
# |           |                                     |                                     |                                     |                                     |                                     |
# |           |     with opportunities to learn     |                                     |     with opportunities to learn     |                                     |                                     |
# |           |                                     |                                     |                                     |                                     |                                     |
# |           |   ![](images/carousel/slide4.jpg)   |                                     |   ![](images/carousel/slide4.jpg)   |                                     |                                     |
# |           |                                     |                                     |                                     |                                     |                                     |
# |           |              and grow.              |                                     |              and grow.              |                                     |                                     |
# |           |                                     |                                     |                                     |                                     |                                     |
# |           |               Welcome!              |                                     |               Welcome!              |                                     |                                     |
# |           |                                     |                                     |                                     |                                     |                                     |
# |           |             Accessible U            |                                     |             Accessible U            |                                     |                                     |
# +-----------+-------------------------------------+-------------------------------------+-------------------------------------+-------------------------------------+-------------------------------------+
# |   Site 2  |     5,280 characters retrieved:     |     9,186 characters retrieved:     |     5,410 characters retrieved:     |     4,846 characters retrieved:     |     7,906 characters retrieved:     |
# |           |                                     |                                     |                                     |                                     |                                     |
# |           | Before - Accessible University Demo |   Published Time: Wed, 26 Feb 2025  | Before - Accessible University Demo | [![](https://openassessittoolkit.gi |              Examples:              |
# |           |     Site - Inaccessible Version     |             14:26:05 GMT            |     Site - Inaccessible Version     | thub.io/accessible_u/images/8675309 |   * [Before](https://openassessitto |
# |           |                                     |                                     |                                     | -l-o-g-o-before.png)](https://opena | olkit.github.io/accessible_u/before |
# |           |                                     | Before - Accessible University Demo |                                     |      ssessittoolkit.github.io/)     |               _u.html)              |
# |           |                                     |     Site - Inaccessible Version     |                                     |                                     |   * [After](https://openassessittoo |
# |           |              Examples:              |                                     |              Examples:              | [![](https://openassessittoolkit.gi | lkit.github.io/accessible_u/after_u |
# |           |                                     |           ===============           |                                     | thub.io/accessible_u/images/8675309 |                .html)               |
# |           |      * [Before](before_u.html)      |                                     |      * [Before](before_u.html)      | -before_brass_band.jpg)](https://op |                                     |
# |           |       * [After](after_u.html)       |              Examples:              |       * [After](after_u.html)       | enassessittoolkit.github.io/accessi | [ ![](https://openassessittoolkit.g |
# |           |     [![](images/8675309-l-o-g-o-    | *   [Before](https://openassessitto |     [![](images/8675309-l-o-g-o-    |  ble_u/somepage.html?ref=Slide%201) | ithub.io/accessible_u/images/867530 |
# |           |           before.png)](/)           | olkit.github.io/accessible_u/before |           before.png)](/)           |                                     | 9-l-o-g-o-before.png) ](https://ope |
# |           |                                     |               _u.html)              |                                     | [![](https://openassessittoolkit.gi |     nassessittoolkit.github.io/)    |
# |           |             * [Home](#)             | *   [After](https://openassessittoo |             * [Home](#)             | thub.io/accessible_u/images/8675309 |   * [Home](https://openassessittool |
# |           |             * [About](#)            | lkit.github.io/accessible_u/after_u |             * [About](#)            | -before_articulated_bus.jpg)](https | kit.github.io/accessible_u/before_u |
# |           |              + [News](#)            |                .html)               |              + [News](#)            | ://openassessittoolkit.github.io/ac |                .html)               |
# |           |           + [Governance](#)         |                                     |           + [Governance](#)         | cessible_u/somepage.html?ref=Slide% |   * [ About ](https://openassessitt |
# |           |            + [Diversity](#)         | [![Image 1](https://openassessittoo |            + [Diversity](#)         |                 202)                | oolkit.github.io/accessible_u/befor |
# |           |           + [Contact Us](#)         | lkit.github.io/accessible_u/images/ |           + [Contact Us](#)         |                                     |              e_u.html)              |
# |           |           * [Academics](#)          | 8675309-l-o-g-o-before.png)](https: |           * [Academics](#)          | [![](https://openassessittoolkit.gi |     * [News](https://openassessitto |
# |           |         + [Degree Programs](#)      |  //openassessittoolkit.github.io/)  |         + [Degree Programs](#)      | thub.io/accessible_u/images/8675309 | olkit.github.io/accessible_u/before |
# |           |           + [AU Faculty](#)         |                                     |           + [AU Faculty](#)         | -before_construction.jpg)](https:// |               _u.html)              |
# |           |        + [Distance Learning](#)     | *   [Home](https://openassessittool |        + [Distance Learning](#)     | openassessittoolkit.github.io/acces |     * [Governance](https://openasse |
# |           |            + [Libraries](#)         | kit.github.io/accessible_u/before_u |            + [Libraries](#)         | sible_u/somepage.html?ref=Slide%203 | ssittoolkit.github.io/accessible_u/ |
# |           |          * [Admissions](#)          |               .html#)               |          * [Admissions](#)          |                  )                  |            before_u.html)           |
# |           |          + [Undergraduate](#)       | *   [About](https://openassessittoo |          + [Undergraduate](#)       |                                     |     * [Diversity](https://openasses |
# |           |            + [Graduate](#)          | lkit.github.io/accessible_u/before_ |            + [Graduate](#)          | ![](https://openassessittoolkit.git | sittoolkit.github.io/accessible_u/b |
# |           |             + [Tuition](#)          |               u.html#)              |             + [Tuition](#)          | hub.io/accessible_u/images/8675309- |            efore_u.html)            |
# |           |          + [Financial Aid](#)       |     *   [News](https://openassessit |          + [Financial Aid](#)       |           arrow-left.png)           |     * [Contact Us](https://openasse |
# |           |           * [Visitors](#)           | toolkit.github.io/accessible_u/befo |           * [Visitors](#)           |                                     | ssittoolkit.github.io/accessible_u/ |
# |           |                                     |             re_u.html#)             |                                     | ![](https://openassessittoolkit.git |            before_u.html)           |
# |           |                  Go                 |     *   [Governance](https://openas |                  Go                 | hub.io/accessible_u/images/8675309- |   * [ Academics ](https://openasses |
# |           |                                     | sessittoolkit.github.io/accessible_ |                                     |           arrow-right.png)          | sittoolkit.github.io/accessible_u/b |
# |           |                                     |          u/before_u.html#)          |                                     |                                     |            efore_u.html)            |
# |           |                                     |     *   [Diversity](https://openass |                                     |               Welcome!              |     * [Degree Programs](https://ope |
# |           |         [![](images/8675309-        | essittoolkit.github.io/accessible_u |         [![](images/8675309-        |                                     | nassessittoolkit.github.io/accessib |
# |           | before_brass_band.jpg)](somepage.ht |           /before_u.html#)          | before_brass_band.jpg)](somepage.ht |   Accessible University (AU) is a   |         le_u/before_u.html)         |
# |           |          ml?ref=Slide%201)          |     *   [Contact Us](https://openas |          ml?ref=Slide%201)          |   [fictional](https://www.merriam-  |     * [AU Faculty](https://openasse |
# |           |                                     | sessittoolkit.github.io/accessible_ |                                     | webster.com/dictionary/fictional) [ | ssittoolkit.github.io/accessible_u/ |
# |           |         [![](images/8675309-        |          u/before_u.html#)          |         [![](images/8675309-        | university](https://en.wikipedia.or |            before_u.html)           |
# |           | before_articulated_bus.jpg)](somepa |                                     | before_articulated_bus.jpg)](somepa | g/wiki/University), and this is its |     * [Distance Learning](https://o |
# |           |        ge.html?ref=Slide%202)       | *   [Academics](https://openassessi |        ge.html?ref=Slide%202)       |  fictional home page. This page is  | penassessittoolkit.github.io/access |
# |           |                                     | ttoolkit.github.io/accessible_u/bef |                                     |  designed to demonstrate a variety  |        ible_u/before_u.html)        |
# |           |         [![](images/8675309-        |             ore_u.html#)            |         [![](images/8675309-        |                  of                 |     * [Libraries](https://openasses |
# |           | before_construction.jpg)](somepage. |     *   [Degree Programs](https://o | before_construction.jpg)](somepage. |          common web design          |       sittoolkit.github.io/ac       |
# |           |         html?ref=Slide%203)         | penassessittoolkit.github.io/access |         html?ref=Slide%203)         |   [problems](https://www.merriam-   |                                     |
# |           |                                     |        ible_u/before_u.html#)       |                                     |   webster.com/dictionary/problems)  |                                     |
# |           |               Welcome!              |     *   [AU Faculty](https://openas |  ![](images/8675309-arrow-left.png) |       that result in visitors       |                                     |
# |           |                                     | sessittoolkit.github.io/accessible_ |                                     |                                     |                                     |
# |           |   Accessible University (AU) is a   |           u/before_u.html           | ![](images/8675309-arrow-right.png) |                                     |                                     |
# |           |   [fictional](https://www.merriam-  |                                     |                                     |                                     |                                     |
# |           | webster.com/dictionary/fictional) [ |                                     |               Welcome!              |                                     |                                     |
# |           | university](https://en.wikipedia.or |                                     |                                     |                                     |                                     |
# |           | g/wiki/University), and this is its |                                     |   Accessible University (AU) is a   |                                     |                                     |
# |           |  fictional home page. This page is  |                                     |   [fictional](https://www.merriam-  |                                     |                                     |
# |           |  designed to demonstrate a variety  |                                     | webster.com/dictionary/fictional) [ |                                     |                                     |
# |           |                  of                 |                                     | university](https://en.wikipedia.or |                                     |                                     |
# |           |          common web design          |                                     | g/wiki/University), and this is its |                                     |                                     |
# |           |   [problems](https://www.merriam-   |                                     |  fictional home page. This page is  |                                     |                                     |
# |           |   webster.com/dictionary/problems)  |                                     |  designed to demonstrate a variety  |                                     |                                     |
# |           |     that result in visitors with    |                                     |                  of                 |                                     |                                     |
# |           |             disabilities            |                                     |          common web design          |                                     |                                     |
# |           |  being unable to access the content |                                     |   [problems](https://www.merriam-   |                                     |                                     |
# |           |      or features of a web page.     |                                     |   webster.com/dictionary/problems)  |                                     |                                     |
# |           |   Although the heading at the top   |                                     |     that result in visitors with    |                                     |                                     |
# |           |                                     |                                     |             disabilities            |                                     |                                     |
# |           |                                     |                                     |         being unable to acce        |                                     |                                     |
# +-----------+-------------------------------------+-------------------------------------+-------------------------------------+-------------------------------------+-------------------------------------+
#
# Cost Table:
# This is how much it would cost to use gpt-4o to use this content as input (estimated, not real).
# +-----------+---------------------------+---------------------------+---------------------------+---------------------------+---------------------------+
# | Site Name |    Beautiful Soup cost    |        Jina AI cost       |      Playwright cost      |       Firecrawl cost      |       Crawl4ai cost       |
# +-----------+---------------------------+---------------------------+---------------------------+---------------------------+---------------------------+
# |   Site 1  | $0.003302 (tokens: 1,321) | $0.004998 (tokens: 1,999) | $0.003302 (tokens: 1,321) | $0.003658 (tokens: 1,463) | $0.004635 (tokens: 1,854) |
# +-----------+---------------------------+---------------------------+---------------------------+---------------------------+---------------------------+
# |   Site 2  | $0.003448 (tokens: 1,379) | $0.006110 (tokens: 2,444) | $0.003540 (tokens: 1,416) | $0.003130 (tokens: 1,252) | $0.005245 (tokens: 2,098) |
# +-----------+---------------------------+---------------------------+---------------------------+---------------------------+---------------------------+

# %% [markdown]
# ## Connect to LLMs to evaluate whether they can generate an accessible web page
#
# We will send the content in both HTML and Markdown formats and ask the model to return a WCAG 2.2-compliant accessible section.

# %%
# !pip install openai --quiet

# %%
from env_colab_pass import passutil 
from openai import OpenAI

OPENAI_API_KEY = passutil.get_secret_value("OPENAI_API_KEY")
GOOGLE_API_KEY = passutil.get_secret_value("GOOGLE_API_KEY")

def extract(model: str, user_input: str, user_prompt: str, template: str = None) -> str:
    if model.startswith("gpt"):
        client = OpenAI(api_key=OPENAI_API_KEY)
    elif model.startswith("gemini"):
        client = OpenAI(api_key=GOOGLE_API_KEY, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")

    entity_extraction_system_message = {
        "role": "system", 
        "content": """"
        1. You are a helpful assistant expert on web accessibility WCAG that evaluate and correct HTML code.
        2. You will be given code and you will analize it.
        3. Then, you will create a new webpage from that code but accessible according to WCAG https://www.w3.org/WAI/WCAG22/Understanding/
        4. Revise all WCAG 2.2 rules including color contrast, alt text, aria labels, provide correct heading levels starting from h1, use semantic HTML elements. Dont broke aria references. Correct as necessary the HTML code to make it accessible.
        5. If the images, scripts, css and font files have a relative urls, convert them to absoulute urls respeting the relative path. If the images, scripts, css and font files have absolute urls, you will keep them as they are.
        6. If the original source has required scripts, you will include them in the head section. If the original source has required css files, you will analize them and include them as inline rules in head section but WCAG accessible corrected, including color contrast checking. Correct as necessary the CSS code to make it accessible.
        7. If you need to include an style.css file, you will add the rules inline in the head section. If you include an sr-only rule, add it to the style section to hide the elements.
        8. Detect the language of the HTML code and add the lang attribute to the html tag.
        9. Before returning the HTML code, you will analyze it and check if it accessible according to WCAG 2.2. If it is not accessible, you will correct it and return the corrected code.
        10. You will double check every step you do. 
        11. You will provide a numbered list lower than 20 lines in simple plain text (without double quotes or any other special char) of the procedure fixes and improvements you made.
        12. The HTML code must be a complete HTML code, not a fragment or incomplete and must be within the context window of the model.
        13. You will return the result as a valid JSON object with values: {HTML: str, Procedure: str}. Double check the JSON object and make sure it is format valid. Sometimes you misses the slash before double quotes.
        14. If you find any error in the JSON object, you will correct it and return the corrected JSON object.
        """
    }
    # Add the system message to the messages list
    messages = [entity_extraction_system_message]
    # Add the content to the messages list
    messages.append({"role": "user", "content": user_prompt})
    messages.append({"role": "user", "content": user_input})
    if template:
        messages.append({"role": "user", "content": "The following is a template as a base for the HTML code you will generate with the content. Use bootstrap classes to make it responsive and accessible. " + template})
        messages.append({"role": "user", "content": template})
    # Call the OpenAI API to get the response
    response = client.chat.completions.create(
        model=model,
        temperature=0.1,
        stream=False,
        messages=messages,
        response_format={"type": "json_object"},
    )
    
    # return response.choices[0].message.content
    return response.choices[0].message.content, response.usage.completion_tokens, response.usage.prompt_tokens

# %% [markdown]
# ## Function to compare the results
#
# We will now create a function to generate a table that compares the results returned in both HTML and Markdown formats.

# %%
def display_extracted_content(model: str, results_html: List[Dict[str, any]], results_md: List[Dict[str, any]], function_name: str, site_name: str, template: str):
    table = PrettyTable()
    table.field_names = ["Site", "From HTML", "From HTML with template","From markdown", "From markdown with template"]

    with open(f'templates/{template}.html', 'r') as file:  # r to open file in READ mode
        html_as_string = file.read()

    # Iterate through each site and its content
    for item in tqdm(results_html, desc="Processing results"):
        sites_html = item["sites"]
        sites_md = item["sites"]
        provider = item["provider"]

        # Check if the provider matches the site name
        if provider == site_name:
            for i in range(len(sites_html)):
                # Check if the function name matches
                if sites_html[i]["name"] == function_name:
                    # Extract the content for HTML and Markdown
                    content_html = sites_html[i]["content"]
                    content_url = sites_html[i]["url"]
                    content_md = sites_md[i]["content"]

                    # Progress bar for each function
                    for _ in tqdm(range(1), desc=f"Extracting content with {function_name} for HTML input", position=0, leave=True):
                        extracted_content_html, completion_tokens, prompt_tokens = extract(model, content_html, f"Use the following code and create a new accessible web page version mantaining all the contents. The root URL is '{content_url}'.", template=None)
                        cost = calculate_cost_tokens(completion_tokens + prompt_tokens)
                        cost_label = f"Completion tokens: {completion_tokens:,}\nPrompt tokens: {prompt_tokens:,}\nTotal cost: ${cost:.6f}" + "\n\n\n"
                        col_content_html = cost_label + extracted_content_html
                    
                    # Progress bar for each function
                    for _ in tqdm(range(1), desc=f"Extracting content with {function_name} for HTML input and template"):
                        extracted_content_html_template, completion_tokens, prompt_tokens = extract(model, content_html, f"Use the following content to create a new accessible web page version mantaining all the contents. The root URL is '{content_url}'.",html_as_string.replace("\n",""))
                        cost = calculate_cost_tokens(completion_tokens + prompt_tokens)
                        cost_label = f"Completion tokens: {completion_tokens:,}\nPrompt tokens: {prompt_tokens:,}\nTotal cost: ${cost:.6f}" + "\n\n\n"
                        col_content_html_template = cost_label + extracted_content_html_template

                    # Progress bar for each function
                    for _ in tqdm(range(1), desc=f"Extracting content with {function_name} for Markdown input"):
                        extracted_content_md, completion_tokens, prompt_tokens = extract(model, content_md, f"Use the following content to create a new accessible web page version. The root URL is '{content_url}'. Use the HTML code source of the page https://webaim.org/ as a base to create a new accessible web page version. Observe the structure of the header, the images are in on row with the title; also the use of cols and rows to make it responsive and accessible.", template=None)
                        cost = calculate_cost_tokens(completion_tokens + prompt_tokens)
                        cost_label = f"Completion tokens: {completion_tokens:,}\nPrompt tokens: {prompt_tokens:,}\nTotal cost: ${cost:.6f}" + "\n\n\n"
                        col_content_md = cost_label + extracted_content_md

                    # Progress bar for each function
                    for _ in tqdm(range(1), desc=f"Extracting content with {function_name} for Markdown input and template"):
                        extracted_content_md_template, completion_tokens, prompt_tokens = extract(model, content_md, f"Use the following content to create a new accessible web page version. The root URL is '{content_url}'.",html_as_string.replace("\n",""))
                        cost = calculate_cost_tokens(completion_tokens + prompt_tokens)
                        cost_label = f"Completion tokens: {completion_tokens:,}\nPrompt tokens: {prompt_tokens:,}\nTotal cost: ${cost:.6f}" + "\n\n\n"
                        col_content_md_template = cost_label + extracted_content_md_template

                    table.add_row([provider, col_content_html, col_content_html_template, col_content_md, col_content_md_template])

    table.max_width = 50  # Set the maximum width for better display
    table.hrules = True  # Add horizontal rules for better readability

    print("Extracted Content Table:")
    print(table)

    return extracted_content_html, extracted_content_html_template, extracted_content_md, extracted_content_md_template

# %% [markdown]
# ### Routines to visualize the obtained results (optional)
#
# Install the necessary dependencies to generate the web interface.

# %%
# !pip install ipywidgets --quiet

# %%
# !pip install aiofiles --quiet

# %%
# !pip install gradio --quiet
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# crawl4ai 0.5.0.post8 requires aiofiles>=24.1.0, but you have aiofiles 23.2.1 which is incompatible.

# %% [markdown]
# We create a helper function to build a web interface and visualize the results.

# %%
import gradio as gr

def create_interface(extracted_json_html, extracted_json_html_template, extracted_json_md, extracted_json_md_template):

    with gr.Blocks(theme=gr.themes.Default()) as demo:
        # From HTML
        with gr.Tab("Proc HTML"):
            gr.TextArea(extracted_json_html["Procedure"], label="Procedure")
        with gr.Tab("Code HTML"):
            gr.TextArea(extracted_json_html["HTML"], label="HTML code", show_copy_button=True, lines=20)
        with gr.Tab("Proc HTML with template"):
            gr.TextArea(extracted_json_html_template["Procedure"], label="Procedure")
        with gr.Tab("Code MD with template"):
            gr.TextArea(extracted_json_html_template["HTML"], label="HTML code", show_copy_button=True, lines=20)
        with gr.Tab("Proc MD"):
            gr.TextArea(extracted_json_md["Procedure"], label="Procedure")
        with gr.Tab("Code MD"):
            gr.TextArea(extracted_json_md["HTML"], label="HTML code", show_copy_button=True, lines=20)
        with gr.Tab("Proc MD with template"):
            gr.TextArea(extracted_json_md_template["Procedure"], label="Procedure")
        with gr.Tab("Code MD with template"):
            gr.TextArea(extracted_json_md_template["HTML"], label="HTML code", show_copy_button=True, lines=20)

    demo.launch()

# %% [markdown]
# ### Storing the results
#
# Helper function to save all outputs generated by the language models into folders.

# %%
import os

def generate_output_files(prefix: str, extracted_json_html: dict, extracted_json_html_template: dict, extracted_json_md: dict, extracted_json_md_template: dict):
    # Create the output directory if it doesn't exist
    if not os.path.exists(f"output/{prefix}"):
        os.makedirs(f"output/{prefix}")

    # Write the HTML content to files
    with open(f'output/{prefix}/1-from_html.html', 'w', encoding='utf-8') as f:
        f.write(extracted_json_html["HTML"])

    with open(f'output/{prefix}/2-from_html_template.html', 'w', encoding='utf-8') as f:
        f.write(extracted_json_html_template["HTML"])

    with open(f'output/{prefix}/3-from_md.html', 'w', encoding='utf-8') as f:
        f.write(extracted_json_md["HTML"])

    with open(f'output/{prefix}/4-from_md_template.html', 'w', encoding='utf-8') as f:
        f.write(extracted_json_md_template["HTML"])

# %% [markdown]
# ## GPT-4o: Washington University Site
#
# Let's examine the output generated by this model.

# %%
# extracted_json_html, extracted_json_html_template, extracted_json_md, extracted_json_md_template = display_extracted_content("gpt-4o", all_content_html, all_content_md, "Crawl4ai", "Blocks", "blocks")
extracted_html, extracted_html_template, extracted_md, extracted_md_template = display_extracted_content("gpt-4o", all_content_html, all_content_md, "Crawl4ai", site_name="Site 1", template="blocks")
# Out:
# Processing results:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for HTML input:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for HTML input and template:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for Markdown input:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for Markdown input and template:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracted Content Table:
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# |  Site  |                     From HTML                      |              From HTML with template               |                   From markdown                    |            From markdown with template             |
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# | Site 1 |              Completion tokens: 4,306              |              Completion tokens: 3,345              |              Completion tokens: 3,642              |              Completion tokens: 3,311              |
# |        |                Prompt tokens: 3,861                |                Prompt tokens: 6,790                |                Prompt tokens: 3,914                |                Prompt tokens: 6,785                |
# |        |               Total cost: $0.020418                |               Total cost: $0.025337                |               Total cost: $0.018890                |               Total cost: $0.025240                |
# |        |                                                    |                                                    |                                                    |                                                    |
# |        |                                                    |                                                    |                                                    |                                                    |
# |        |                         {                          |                         {                          |                         {                          |                         {                          |
# |        |            "HTML": "<!DOCTYPE html>\n<html         |             "HTML": "<!DOCTYPE html><html          |            "HTML": "<!DOCTYPE html>\n<html         |             "HTML": "<!DOCTYPE html><html          |
# |        |          lang=\"en\">\n<head>\n    <meta           |   lang=\"en\"><head>    <meta charset=\"UTF-8\">   |          lang=\"en\">\n<head>\n    <meta           |   lang=\"en\"><head>    <meta charset=\"UTF-8\">   |
# |        |     charset=\"utf-8\">\n    <title>Accessible      |  <meta name=\"viewport\" content=\"width=device-   |     charset=\"utf-8\">\n    <title>Accessible      |  <meta name=\"viewport\" content=\"width=device-   |
# |        |         University Demo Site - Accessible          |   width, initial-scale=1\">    <title>Accessible   |         University Demo Site - Accessible          |   width, initial-scale=1\">    <title>Accessible   |
# |        |   Version</title>\n    <link rel=\"apple-touch-    | University Demo Site - Accessible Version</title>  |   Version</title>\n    <link rel=\"apple-touch-    | University Demo Site - Accessible Version</title>  |
# |        | icon\" sizes=\"180x180\" href=\"https://www.washin | <link href=\"https://cdn.jsdelivr.net/npm/bootstra | icon\" sizes=\"180x180\" href=\"https://www.washin | <link href=\"https://cdn.jsdelivr.net/npm/bootstra |
# |        | gton.edu/accesscomputing/AU/images/favicon/apple-  |        p@5.3.3/dist/css/bootstrap.min.css\"        | gton.edu/accesscomputing/AU/images/favicon/apple-  |        p@5.3.3/dist/css/bootstrap.min.css\"        |
# |        |     touch-icon.png\">\n    <link rel=\"icon\"      |  rel=\"stylesheet\">    <style>        .sr-only {  |     touch-icon.png\">\n    <link rel=\"icon\"      |  rel=\"stylesheet\">    <style>        .sr-only {  |
# |        | type=\"image/png\" sizes=\"32x32\" href=\"https:// |     position: absolute;            width: 1px;     | type=\"image/png\" sizes=\"32x32\" href=\"https:// |     position: absolute;            width: 1px;     |
# |        | www.washington.edu/accesscomputing/AU/images/favic |        height: 1px;            padding: 0;         | www.washington.edu/accesscomputing/AU/images/favic |        height: 1px;            padding: 0;         |
# |        |  on/favicon-32x32.png\">\n    <link rel=\"icon\"   |     margin: -1px;            overflow: hidden;     |  on/favicon-32x32.png\">\n    <link rel=\"icon\"   |     margin: -1px;            overflow: hidden;     |
# |        | type=\"image/png\" sizes=\"16x16\" href=\"https:// |   clip: rect(0, 0, 0, 0);            border: 0;    | type=\"image/png\" sizes=\"16x16\" href=\"https:// |   clip: rect(0, 0, 0, 0);            border: 0;    |
# |        | www.washington.edu/accesscomputing/AU/images/favic |   }        .carousel-item img {            max-    | www.washington.edu/accesscomputing/AU/images/favic |            }        .carousel-caption {            |
# |        | on/favicon-16x16.png\">\n    <style>\n        body |    height: 400px;            object-fit: cover;    | on/favicon-16x16.png\">\n    <style>\n        body |       background-color: rgba(0, 0, 0, 0.5);        |
# |        |   { font-family: Arial, sans-serif; line-height:   |      }        .required .form-label::after {       |   { font-family: Arial, sans-serif; line-height:   |      color: #fff;        }        .required {      |
# |        |   1.6; }\n        .sr-only { position: absolute;   |  content: \"*\";            color: red;        }   |   1.6; }\n        .sr-only { position: absolute;   | color: #0056b3;        }    </style></head><body>  |
# |        | width: 1px; height: 1px; padding: 0; margin: -1px; |    </style></head><body>    <nav class=\"navbar    | width: 1px; height: 1px; padding: 0; margin: -1px; | <nav class=\"navbar navbar-expand-lg navbar-light  |
# |        | overflow: hidden; clip: rect(0, 0, 0, 0); border:  |  navbar-expand-lg bg-body-tertiary\">        <div  | overflow: hidden; clip: rect(0, 0, 0, 0); border:  | bg-light\">        <div class=\"container-fluid\"> |
# |        |   0; }\n        .required { color: #0056b3; }\n    |      class=\"container-fluid\">            <a      | 0; }\n        .heading { font-size: 1.5em; margin- |  <a class=\"navbar-brand\" href=\"#\">Accessible   |
# |        | .heading { font-size: 1.5em; margin-top: 1em; }\n  |    class=\"navbar-brand\" href=\"#\">Accessible    |  top: 1em; }\n        .required { color: #0056b3;  | University</a>            <button class=\"navbar-  |
# |        |  #menu, #AU-menu { list-style: none; padding: 0;   | University</a>            <button class=\"navbar-  |   }\n        .reqExample { font-size: 0.9em; }\n   |         toggler\" type=\"button\" data-bs-         |
# |        |    }\n        #menu li, #AU-menu li { display:     |         toggler\" type=\"button\" data-bs-         |  #menu, #AU-menu { list-style: none; padding: 0;   | toggle=\"collapse\" data-bs-target=\"#navbarNav\"  |
# |        |  inline; margin-right: 10px; }\n        #carousel  | toggle=\"collapse\" data-bs-target=\"#navbarNav\"  |    }\n        #menu li, #AU-menu li { display:     |         aria-controls=\"navbarNav\" aria-          |
# |        |        img { width: 100%; height: auto; }\n        |         aria-controls=\"navbarNav\" aria-          |  inline; margin-right: 10px; }\n        #menu a,   |       expanded=\"false\" aria-label=\"Toggle       |
# |        |  .caption { background-color: rgba(0, 0, 0, 0.5);  |       expanded=\"false\" aria-label=\"Toggle       |     #AU-menu a { text-decoration: none; color:     | navigation\">                <span class=\"navbar- |
# |        |    color: #fff; padding: 5px; }\n        .hr {     | navigation\">                <span class=\"navbar- |    #0056b3; }\n        #menu a:hover, #AU-menu     |    toggler-icon\"></span>            </button>     |
# |        |        display: block; margin: 20px 0; }\n         |    toggler-icon\"></span>            </button>     |     a:hover { text-decoration: underline; }\n      |      <div class=\"collapse navbar-collapse\"       |
# |        |    #enrollment { width: 100%; border-collapse:     |      <div class=\"collapse navbar-collapse\"       |   #carousel img { width: 100%; height: auto; }\n   |        id=\"navbarNav\">                <ul        |
# |        |  collapse; }\n        #enrollment th, #enrollment  |        id=\"navbarNav\">                <ul        |   #enrollment th, #enrollment td { padding: 8px;   |    class=\"navbar-nav\">                    <li    |
# |        |  td { border: 1px solid #ddd; padding: 8px; text-  |    class=\"navbar-nav\">                    <li    |  text-align: center; }\n        #enrollment th {   |   class=\"nav-item\">                        <a    |
# |        |     align: center; }\n        #enrollment th {     |   class=\"nav-item\">                        <a    | background-color: #f2f2f2; }\n        #enrollment  | class=\"nav-link\" href=\"https://www.washington.e |
# |        |   background-color: #f2f2f2; }\n        #error {   | class=\"nav-link\" href=\"https://www.washington.e | td { border: 1px solid #ddd; }\n        #footer {  |    du/accesscomputing/AU/index.html\">Home</a>     |
# |        | color: red; }\n    </style>\n    <script src=\"htt |    du/accesscomputing/AU/index.html\">Home</a>     |  background-color: #f2f2f2; padding: 10px; text-   |  </li>                    <li class=\"nav-item\">  |
# |        | ps://ajax.googleapis.com/ajax/libs/jquery/3.6.0/jq |  </li>                    <li class=\"nav-item\">  | align: center; }\n    </style>\n    <script src=\" | <a class=\"nav-link active\" aria-current=\"page\" |
# |        | uery.min.js\"></script>\n    <script src=\"https:/ | <a class=\"nav-link active\" aria-current=\"page\" | https://ajax.googleapis.com/ajax/libs/jquery/3.6.0 | href=\"https://www.washington.edu/accesscomputing/ |
# |        | /www.washington.edu/accesscomputing/AU/scripts/bef | href=\"https://www.washington.edu/accesscomputing/ | /jquery.min.js\"></script>\n    <script src=\"http |            AU/before.html\">Before</a>             |
# |        | ore-menu.js\"></script>\n    <script src=\"https:/ |            AU/before.html\">Before</a>             | s://www.washington.edu/accesscomputing/AU/scripts/ |  </li>                    <li class=\"nav-item\">  |
# |        | /www.washington.edu/accesscomputing/AU/scripts/bef |  </li>                    <li class=\"nav-item\">  | before-menu.js\"></script>\n    <script src=\"http | <a class=\"nav-link\" href=\"https://www.washingto |
# |        | ore-form.js\"></script>\n    <script src=\"https:/ | <a class=\"nav-link\" href=\"https://www.washingto | s://www.washington.edu/accesscomputing/AU/scripts/ |  n.edu/accesscomputing/AU/after.html\">After</a>   |
# |        | /www.washington.edu/accesscomputing/AU/scripts/bef |  n.edu/accesscomputing/AU/after.html\">After</a>   | before-form.js\"></script>\n    <script src=\"http |  </li>                    <li class=\"nav-item\">  |
# |        | ore-modal.js\"></script>\n    <script src=\"https: |  </li>                    <li class=\"nav-item\">  | s://www.washington.edu/accesscomputing/AU/scripts/ | <a class=\"nav-link\" href=\"https://www.washingto |
# |        | //www.washington.edu/accesscomputing/AU/scripts/be | <a class=\"nav-link\" href=\"https://www.washingto | before-modal.js\"></script>\n    <script src=\"htt |   n.edu/accesscomputing/AU/info.html\">Info</a>    |
# |        |  fore-carousel.js\"></script>\n</head>\n<body>\n   |   n.edu/accesscomputing/AU/info.html\">Info</a>    | ps://www.washington.edu/accesscomputing/AU/scripts |    </li>                </ul>            </div>    |
# |        |  <a href=\"#main\" class=\"sr-only\">Skip to main  |    </li>                </ul>            </div>    | /before-carousel.js\"></script>\n</head>\n<body>\n |    </div>    </nav>    <main class=\"container     |
# |        |     content</a>\n    <header id=\"banner\">\n      |    </div>    </nav>    <main class=\"container     | <header>\n        <img id=\"logo\" src=\"https://w |      mt-4\">        <h1>Welcome to Accessible      |
# |        | <img id=\"logo\" src=\"https://www.washington.edu/ |      mt-4\">        <h1>Welcome to Accessible      | ww.washington.edu/accesscomputing/AU/images/au1234 | University</h1>        <div id=\"carouselExample\" |
# |        |    accesscomputing/AU/images/au123456789.gif\"     | University</h1>        <div id=\"carouselExample\" |   56789.gif\" alt=\"Accessible University Logo\"   |         class=\"carousel slide\" data-bs-          |
# |        |  alt=\"Accessible University Logo\" width=\"441\"  |         class=\"carousel slide\" data-bs-          |     width=\"441\" height=\"90\">\n        <nav     |         ride=\"carousel\">            <div         |
# |        | height=\"90\">\n        <nav id=\"AU-menu\" aria-  |         ride=\"carousel\">            <div         |  id=\"AU-menu\" aria-label=\"Demo site menu\">\n   |   class=\"carousel-inner\">                <div    |
# |        |   label=\"Demo site menu\">\n            <ul>\n    |   class=\"carousel-inner\">                <div    | <ul>\n                <li><a href=\"https://www.wa |          class=\"carousel-item active\">           |
# |        |     <li><a href=\"index.html\">Home</a></li>\n     |          class=\"carousel-item active\">           | shington.edu/accesscomputing/AU/index.html\">Home< | <img src=\"https://www.washington.edu/accesscomput |
# |        |         <li><a href=\"before.html\" aria-          | <img src=\"https://www.washington.edu/accesscomput | /a></li>\n                <li><a href=\"https://ww |        ing/AU/images/carousel/slide1.jpg\"         |
# |        |         current=\"page\">Before</a></li>\n         |        ing/AU/images/carousel/slide1.jpg\"         | w.washington.edu/accesscomputing/AU/before.html\"  |  class=\"d-block w-100\" alt=\"A modern school\">  |
# |        |    <li><a href=\"after.html\">After</a></li>\n     |  class=\"d-block w-100\" alt=\"A modern school\">  |      aria-current=\"page\">Before</a></li>\n       | <div class=\"carousel-caption d-none d-md-block\"> |
# |        |     <li><a href=\"info.html\">Info</a></li>\n      | <div class=\"carousel-caption d-none d-md-block\"> | <li><a href=\"https://www.washington.edu/accesscom |  <p>A modern school</p>                    </div>  |
# |        | </ul>\n        </nav>\n    </header>\n    <nav>\n  |  <p>A modern school</p>                    </div>  |      puting/AU/after.html\">After</a></li>\n       |    </div>                <div class=\"carousel-    |
# |        |        <ul id=\"menu\">\n            <li><a        |    </div>                <div class=\"carousel-    | <li><a href=\"https://www.washington.edu/accesscom | item\">                    <img src=\"https://www. |
# |        |    href=\"#\">About</a>\n                <ul>\n    | item\">                    <img src=\"https://www. |       puting/AU/info.html\">Info</a></li>\n        | washington.edu/accesscomputing/AU/images/carousel/ |
# |        |                       <li><a                       | washington.edu/accesscomputing/AU/images/carousel/ |  </ul>\n        </nav>\n    </header>\n    <main   | slide2.jpg\" class=\"d-block w-100\" alt=\"Rooted  |
# |        |  href=\"somepage.html?ref=News\">News</a></li>\n   | slide2.jpg\" class=\"d-block w-100\" alt=\"Rooted  | id=\"content\">\n        <section id=\"carousel\"  |     in its history\">                    <div      |
# |        | <li><a href=\"somepage.html?ref=Governance\">Gover |     in its history\">                    <div      |  aria-label=\"Image carousel\">\n            <div  |   class=\"carousel-caption d-none d-md-block\">    |
# |        | nance</a></li>\n                    <li><a href=\" |   class=\"carousel-caption d-none d-md-block\">    |     id=\"controls\">\n                <button      |            <p>Rooted in its history</p>            |
# |        | somepage.html?ref=Diversity\">Diversity</a></li>\n |            <p>Rooted in its history</p>            |       id=\"btn-prev\" aria-label=\"Previous        |  </div>                </div>                <div  |
# |        |                       <li><a                       |  </div>                </div>                <div  |   slide\">&lt;</button>\n                <button   | class=\"carousel-item\">                    <img s |
# |        |  href=\"somepage.html?ref=Contact%20Us\">Contact   | class=\"carousel-item\">                    <img s |         id=\"btn-next\" aria-label=\"Next          | rc=\"https://www.washington.edu/accesscomputing/AU |
# |        |        Us</a></li>\n                </ul>\n        | rc=\"https://www.washington.edu/accesscomputing/AU |    slide\">&gt;</button>\n            </div>\n     |   /images/carousel/slide3.jpg\" class=\"d-block    |
# |        |             </li>\n            <li><a              |   /images/carousel/slide3.jpg\" class=\"d-block    |     <div id=\"slides\">\n                <div      |    w-100\" alt=\"With opportunities to learn\">    |
# |        |  href=\"#\">Academics</a>\n                <ul>\n  |    w-100\" alt=\"With opportunities to learn\">    | class=\"slide current\">\n                    <img | <div class=\"carousel-caption d-none d-md-block\"> |
# |        | <li><a href=\"somepage.html?ref=Degree%20Programs\ | <div class=\"carousel-caption d-none d-md-block\"> | src=\"https://www.washington.edu/accesscomputing/A |         <p>With opportunities to learn</p>         |
# |        |            ">Degree Programs</a></li>\n            |         <p>With opportunities to learn</p>         |   U/images/carousel/slide1.jpg\" alt=\"A modern    |  </div>                </div>                <div  |
# |        | <li><a href=\"somepage.html?ref=AU%20Faculty\">AU  |  </div>                </div>                <div  |      school\" width=\"580\" height=\"326\">\n      | class=\"carousel-item\">                    <img s |
# |        | Faculty</a></li>\n                    <li><a href= | class=\"carousel-item\">                    <img s |   <div class=\"caption\">A modern school</div>\n   | rc=\"https://www.washington.edu/accesscomputing/AU |
# |        | \"somepage.html?ref=Distance%20Learning\">Distance | rc=\"https://www.washington.edu/accesscomputing/AU |  </div>\n                <div class=\"slide\">\n   |   /images/carousel/slide4.jpg\" class=\"d-block    |
# |        | Learning</a></li>\n                    <li><a href |   /images/carousel/slide4.jpg\" class=\"d-block    | <img src=\"https://www.washington.edu/accesscomput | w-100\" alt=\"And grow\">                    <div  |
# |        | =\"somepage.html?ref=Libraries\">Libraries</a></li | w-100\" alt=\"And grow\">                    <div  |  ing/AU/images/carousel/slide2.jpg\" alt=\"Rooted  |   class=\"carousel-caption d-none d-md-block\">    |
# |        |   >\n                </ul>\n            </li>\n    |   class=\"carousel-caption d-none d-md-block\">    |    in its history\">\n                    <div     |     <p>And grow</p>                    </div>      |
# |        |         <li><a href=\"#\">Admissions</a>\n         |     <p>And grow</p>                    </div>      |  class=\"caption\">Rooted in its history</div>\n   |    </div>            </div>            <button     |
# |        | <ul>\n                    <li><a href=\"somepage.h |    </div>            </div>            <button     |  </div>\n                <div class=\"slide\">\n   |  class=\"carousel-control-prev\" type=\"button\"   |
# |        |  tml?ref=Undergraduate\">Undergraduate</a></li>\n  |  class=\"carousel-control-prev\" type=\"button\"   | <img src=\"https://www.washington.edu/accesscomput |    data-bs-target=\"#carouselExample\" data-bs-    |
# |        | <li><a href=\"somepage.html?ref=Graduate\">Graduat |    data-bs-target=\"#carouselExample\" data-bs-    |   ing/AU/images/carousel/slide3.jpg\" alt=\"With   |        slide=\"prev\">                <span        |
# |        | e</a></li>\n                    <li><a href=\"some |        slide=\"prev\">                <span        |            opportunities to learn\">\n             |     class=\"carousel-control-prev-icon\" aria-     |
# |        |     page.html?ref=Tuition\">Tuition</a></li>\n     |     class=\"carousel-control-prev-icon\" aria-     |    <div class=\"caption\">With opportunities to    |    hidden=\"true\"></span>                <span    |
# |        | <li><a href=\"somepage.html?ref=Financial%20Aid\"> |    hidden=\"true\"></span>                <span    |       learn</div>\n                </div>\n        |     class=\"visually-hidden\">Previous</span>      |
# |        |  Financial Aid</a></li>\n                </ul>\n   |     class=\"visually-hidden\">Previous</span>      | <div class=\"slide\">\n                    <img sr |   </button>            <button class=\"carousel-   |
# |        |             </li>\n            <li><a              |   </button>            <button class=\"carousel-   | c=\"https://www.washington.edu/accesscomputing/AU/ |      control-next\" type=\"button\" data-bs-       |
# |        |  href=\"#\">Visitors</a>\n                <ul>\n   |      control-next\" type=\"button\" data-bs-       |  images/carousel/slide4.jpg\" alt=\"And grow\">\n  |        target=\"#carouselExample\" data-bs-        |
# |        | <li><a href=\"somepage.html?ref=Events\">Events</a |        target=\"#carouselExample\" data-bs-        |      <div class=\"caption\">And grow</div>\n       |        slide=\"next\">                <span        |
# |        |         ></li>\n                    <li><a         |        slide=\"next\">                <span        |    </div>\n            </div>\n            <ul     |     class=\"carousel-control-next-icon\" aria-     |
# |        |    href=\"somepage.html?ref=Campus_Map\">Campus    |     class=\"carousel-control-next-icon\" aria-     |   class=\"lentils\">\n                <li data-    |    hidden=\"true\"></span>                <span    |
# |        | Map</a></li>\n                    <li><a href=\"so |    hidden=\"true\"></span>                <span    |        slide=\"0\" class=\"active\"></li>\n        |       class=\"visually-hidden\">Next</span>        |
# |        |    mepage.html?ref=Parking\">Parking</a></li>\n    |       class=\"visually-hidden\">Next</span>        |  <li data-slide=\"1\"></li>\n                <li   |      </button>        </div>        <section       |
# |        |     </ul>\n            </li>\n        </ul>\n      |      </button>        </div>        <section       | data-slide=\"2\"></li>\n                <li data-  |    class=\"mt-4\">            <h2>Welcome!</h2>    |
# |        |  </nav>\n    <main id=\"main\">\n        <section  |    class=\"mt-4\">            <h2>Welcome!</h2>    |       slide=\"3\"></li>\n            </ul>\n       |    <p>Accessible University (AU) is a fictional    |
# |        |  id=\"carousel\" aria-label=\"Image carousel\">\n  |    <p>Accessible University (AU) is a fictional    |          </section>\n        <section>\n           |  university, and this is its fictional home page.  |
# |        |   <div id=\"controls\">\n                <button   |  university, and this is its fictional home page.  |    <h1>Welcome!</h1>\n            <p>Accessible    | This page is designed to demonstrate a variety of  |
# |        |       id=\"btn-prev\" aria-label=\"Previous        | This page is designed to demonstrate a variety of  |   University (AU) is a fictional university, and   | common web design problems that result in visitors |
# |        |   slide\">&lt;</button>\n                <button   | common web design problems that result in visitors |   this is its fictional home page. This page is    |    with disabilities being unable to access the    |
# |        |         id=\"btn-next\" aria-label=\"Next          |    with disabilities being unable to access the    |  designed to demonstrate a variety of common web   |  content or features of a web page. Although the   |
# |        |    slide\">&gt;</button>\n            </div>\n     |  content or features of a web page. Although the   |    design problems that result in visitors with    |   heading at the top of this section of the page   |
# |        |     <div id=\"slides\">\n                <div      |   heading at the top of this section of the page   | disabilities being unable to access the content or |  suggests that AU may be a welcoming institution,  |
# |        | class=\"slide current\">\n                    <img |  suggests that AU may be a welcoming institution,  |  features of a web page. Although the heading at   |   the inaccessible design of this page sends the   |
# |        | src=\"https://www.washington.edu/accesscomputing/A |   the inaccessible design of this page sends the   | the top of this section of the page suggests that  |       opposite message.</p>            <hr>        |
# |        |   U/images/carousel/slide1.jpg\" alt=\"A modern    |      opposite message.</p>        </section>       |       AU may be a welcoming institution, the       |    <h2>Bienvenido!</h2>            <p>Accesible    |
# |        |      school\" width=\"580\" height=\"326\">\n      |               <hr>        <section>                |     inaccessible design of this page sends the     |  Universidad (UA) es una universidad ficticia, y   |
# |        |   <div class=\"caption\">A modern school</div>\n   |    <h2>Bienvenido!</h2>            <p>Accesible    |     opposite message.</p>\n            <hr>\n      |   esta es su página de ficción. Esta página está   |
# |        |  </div>\n                <div class=\"slide\">\n   |  Universidad (UA) es una universidad ficticia, y   |   <h2>Bienvenido!</h2>\n            <p>Accesible   |  diseñada para demostrar una variedad de común de  |
# |        | <img src=\"https://www.washington.edu/accesscomput |   esta es su página de ficción. Esta página está   |  Universidad (UA) es una universidad ficticia, y   |   diseño web que se traducen en problemas de los   |
# |        |  ing/AU/images/carousel/slide2.jpg\" alt=\"Rooted  |  diseñada para demostrar una variedad de común de  |   esta es su página de ficción. Esta página está   |  visitantes con discapacidad no poder acceder al   |
# |        |    in its history\">\n                    <div     |   diseño web que se traducen en problemas de los   |  diseñada para demostrar una variedad de común de  | contenido o las características de una página web. |
# |        |  class=\"caption\">Rooted in its history</div>\n   |  visitantes con discapacidad no poder acceder al   |   diseño web que se traducen en problemas de los   |   Aunque el título en la parte superior de esta    |
# |        |  </div>\n                <div class=\"slide\">\n   | contenido o las características de una página web. |  visitantes con discapacidad no poder acceder al   | sección de la página sugiere que AU puede ser una  |
# |        | <img src=\"https://www.washington.edu/accesscomput |   Aunque el título en la parte superior de esta    | contenido o las características de una página web. |  institución de bienvenida, el diseño inaccesible  |
# |        |   ing/AU/images/carousel/slide3.jpg\" alt=\"With   | sección de la página sugiere que AU puede ser una  |   Aunque el título en la parte superior de esta    |    de esta página envía el mensaje opuesto.</p>    |
# |        |            opportunities to learn\">\n             |  institución de bienvenida, el diseño inaccesible  | sección de la página sugiere que AU puede ser una  |        <hr>            <h2>Can you spot the        |
# |        |    <div class=\"caption\">With opportunities to    |    de esta página envía el mensaje opuesto.</p>    |  institución de bienvenida, el diseño inaccesible  | barriers?</h2>            <p>There are at least 22 |
# |        |       learn</div>\n                </div>\n        |      </section>        <hr>        <section>       |   de esta página envía el mensaje opuesto.</p>\n   |  accessibility issues on this page. To see a list  |
# |        | <div class=\"slide\">\n                    <img sr |        <h2>Can you spot the barriers?</h2>         |       <hr>\n            <h2>Can you spot the       | of all known issues, <a href=\"https://www.washing |
# |        | c=\"https://www.washington.edu/accesscomputing/AU/ |  <p>There are at least 22 accessibility issues on  | barriers?</h2>\n            <p>There are at least  |    ton.edu/accesscomputing/AU/info.html\">click    |
# |        |  images/carousel/slide4.jpg\" alt=\"And grow\">\n  | this page. To see a list of all known issues, <a h |   22 accessibility issues on this page. To see a   | here</a>. To see a more accessible version of this |
# |        |      <div class=\"caption\">And grow</div>\n       | ref=\"https://www.washington.edu/accesscomputing/A | list of all known issues, <a href=\"https://www.wa | same page, <a href=\"https://www.washington.edu/ac |
# |        |    </div>\n            </div>\n            <ul     |    U/info.html\">click here</a>. To see a more     | shington.edu/accesscomputing/AU/info.html\">click  | cesscomputing/AU/after.html\">click here</a>. For  |
# |        |   class=\"lentils\">\n                <li data-    | accessible version of this same page, <a href=\"ht | here</a>. To see a more accessible version of this | a cheat sheet of accessibility issues, <a href=\"h |
# |        |        slide=\"0\" class=\"active\"></li>\n        | tps://www.washington.edu/accesscomputing/AU/after. | same page, <a href=\"https://www.washington.edu/ac | ttps://www.washington.edu/accesscomputing/AU/cheat |
# |        |  <li data-slide=\"1\"></li>\n                <li   |    html\">click here</a>. For a cheat sheet of     | cesscomputing/AU/after.html\">click here</a>. For  |  sheet.html\">click here</a>.</p>            <hr>  |
# |        | data-slide=\"2\"></li>\n                <li data-  | accessibility issues, <a href=\"https://www.washin | a cheat sheet of accessibility issues, <a href=\"h |  <h2>AU Enrollment Trends</h2>            <table   |
# |        |       slide=\"3\"></li>\n            </ul>\n       | gton.edu/accesscomputing/AU/cheatsheet.html\">clic | ttps://www.washington.edu/accesscomputing/AU/cheat |          class=\"table table-bordered\">           |
# |        |          </section>\n        <section>\n           |   k here</a>.</p>        </section>        <hr>    |         sheet.html\">click here</a>.</p>\n         |          <thead>                    <tr>           |
# |        |    <h1>Welcome!</h1>\n            <p>Accessible    | <section>            <h2>AU Enrollment Trends</h2> | <hr>\n            <h2>AU Enrollment Trends</h2>\n  |    <th scope=\"col\" rowspan=\"2\">&nbsp;</th>     |
# |        |   University (AU) is a fictional university, and   |       <table class=\"table table-bordered\">       |            <table id=\"enrollment\">\n             |   <th scope=\"col\" colspan=\"5\" class=\"text-    |
# |        |   this is its fictional home page. This page is    |          <thead>                    <tr>           |        <thead>\n                    <tr>\n         | center\">Last Year</th>                        <th |
# |        |  designed to demonstrate a variety of common web   |    <th scope=\"col\" rowspan=\"2\">&nbsp;</th>     |   <th rowspan=\"2\" style=\"width:6em\"></th>\n    |     scope=\"col\" colspan=\"5\" class=\"text-      |
# |        |    design problems that result in visitors with    |   <th scope=\"col\" colspan=\"5\" class=\"text-    |         <th colspan=\"5\">Last Year</th>\n         |  center\">This Year</th>                    </tr>  |
# |        | disabilities being unable to access the content or | center\">Last Year</th>                        <th |         <th colspan=\"5\">This Year</th>\n         |          <tr>                        <th           |
# |        |  features of a web page. Although the heading at   |     scope=\"col\" colspan=\"5\" class=\"text-      |         </tr>\n                    <tr>\n          |  scope=\"col\">CS</th>                        <th  |
# |        | the top of this section of the page suggests that  |  center\">This Year</th>                    </tr>  |                   <th>CS</th>\n                    | scope=\"col\">Eng</th>                        <th  |
# |        |       AU may be a welcoming institution, the       |          <tr>                        <th           |                   <th>Eng</th>\n                   | scope=\"col\">Eco</th>                        <th  |
# |        |     inaccessible design of this page sends the     |  scope=\"col\">CS</th>                        <th  |                   <th>Eco</th>\n                   | scope=\"col\">Phy</th>                        <th  |
# |        |      opposite message.</p>\n            <img       | scope=\"col\">Eng</th>                        <th  |                   <th>Phy</th>\n                   | scope=\"col\">Psy</th>                        <th  |
# |        | class=\"hr\" src=\"https://www.washington.edu/acce | scope=\"col\">Eco</th>                        <th  |                   <th>Psy</th>\n                   |  scope=\"col\">CS</th>                        <th  |
# |        |     sscomputing/AU/images/line_gradient.gif\"      | scope=\"col\">Phy</th>                        <th  |                   <th>CS</th>\n                    | scope=\"col\">Eng</th>                        <th  |
# |        |   alt=\"horizontal line graphic\" width=\"400\"    | scope=\"col\">Psy</th>                        <th  |                   <th>Eng</th>\n                   | scope=\"col\">Eco</th>                        <th  |
# |        |        height=\"5\">\n        </section>\n         |  scope=\"col\">CS</th>                        <th  |                   <th>Eco</th>\n                   | scope=\"col\">Phy</th>                        <th  |
# |        |   <section>\n            <h2>Bienvenido!</h2>\n    | scope=\"col\">Eng</th>                        <th  |                   <th>Phy</th>\n                   |  scope=\"col\">Psy</th>                    </tr>   |
# |        |  <p>Accesible Universidad (UA) es una universidad  | scope=\"col\">Eco</th>                        <th  |     <th>Psy</th>\n                    </tr>\n      |          </thead>                <tbody>           |
# |        |   ficticia, y esta es su página de ficción. Esta   | scope=\"col\">Phy</th>                        <th  |        </thead>\n                <tbody>\n         |          <tr>                        <th           |
# |        |  página está diseñada para demostrar una variedad  |  scope=\"col\">Psy</th>                    </tr>   |                       <tr>\n                       |          scope=\"row\">Undergraduate</th>          |
# |        |     de común de diseño web que se traducen en      |          </thead>                <tbody>           |              <td>Undergraduate</td>\n              | <td>1481</td>                        <td>400</td>  |
# |        |  problemas de los visitantes con discapacidad no   |          <tr>                        <th           |                  <td>1481</td>\n                   |  <td>727</td>                        <td>747</td>  |
# |        |  poder acceder al contenido o las características  |          scope=\"row\">Undergraduate</th>          |                   <td>400</td>\n                   | <td>1006</td>                        <td>1500</td> |
# |        |  de una página web. Aunque el título en la parte   | <td>1481</td>                        <td>400</td>  |                   <td>727</td>\n                   |  <td>340</td>                        <td>777</td>  |
# |        | superior de esta sección de la página sugiere que  |  <td>727</td>                        <td>747</td>  |                   <td>747</td>\n                   | <td>787</td>                        <td>1112</td>  |
# |        |   AU puede ser una institución de bienvenida, el   | <td>1006</td>                        <td>1500</td> |                  <td>1006</td>\n                   |           </tr>                    <tr>            |
# |        | diseño inaccesible de esta página envía el mensaje |  <td>340</td>                        <td>777</td>  |                  <td>1500</td>\n                   |          <th scope=\"row\">Graduate</th>           |
# |        | opuesto.</p>\n            <img class=\"hr\" src=\" | <td>787</td>                        <td>1112</td>  |                   <td>340</td>\n                   |  <td>310</td>                        <td>84</td>   |
# |        | https://www.washington.edu/accesscomputing/AU/imag |           </tr>                    <tr>            |                   <td>777</td>\n                   |  <td>273</td>                        <td>69</td>   |
# |        |    es/line_gradient.gif\" alt=\"horizontal line    |          <th scope=\"row\">Graduate</th>           |                   <td>787</td>\n                   |  <td>312</td>                        <td>350</td>  |
# |        |      graphic\" width=\"400\" height=\"5\">\n       |  <td>310</td>                        <td>84</td>   |     <td>1112</td>\n                    </tr>\n     |  <td>64</td>                        <td>341</td>   |
# |        | </section>\n        <section>\n            <h2>Can |  <td>273</td>                        <td>69</td>   | <tr>\n                        <td>Graduate</td>\n  |  <td>72</td>                        <td>325</td>   |
# |        | you spot the barriers?</h2>\n            <p>There  |  <td>312</td>                        <td>350</td>  |                   <td>310</td>\n                   | </tr>                </tbody>            </table>  |
# |        | are at least 22 accessibility issues on this page. |  <td>64</td>                        <td>341</td>   |                   <td>84</td>\n                    |         <hr>            <h2>AU Video</h2>          |
# |        |       To see a list of all known issues, <a        |  <td>72</td>                        <td>325</td>   |                   <td>273</td>\n                   | <video src=\"https://www.washington.edu/accesscomp |
# |        |  href=\"info.html\">click here</a>. To see a more  | </tr>                </tbody>            </table>  |                   <td>69</td>\n                    | uting/AU/video/au-promo.mp4\" poster=\"https://www |
# |        |      accessible version of this same page, <a      |      </section>        <hr>        <section>       |                   <td>312</td>\n                   |    .washington.edu/accesscomputing/AU/video/au-    |
# |        |  href=\"after.html\">click here</a>. For a cheat   | <h2>AU Video</h2>            <video src=\"https:// |                   <td>350</td>\n                   |          promo.jpg\" controls=\"\" aria-           |
# |        |         sheet of accessibility issues, <a          |  www.washington.edu/accesscomputing/AU/video/au-   |                   <td>64</td>\n                    |  describedby=\"videoDesc\"></video>            <p  |
# |        |   href=\"cheatsheet.html\">click here</a>.</p>\n   | promo.mp4\" poster=\"https://www.washington.edu/ac |                   <td>341</td>\n                   |   id=\"videoDesc\" class=\"sr-only\">Promotional   |
# |        | <img class=\"hr\" src=\"https://www.washington.edu |   cesscomputing/AU/video/au-promo.jpg\" controls   |                   <td>72</td>\n                    |        video for Accessible University.</p>        |
# |        |   /accesscomputing/AU/images/line_gradient.gif\"   |    aria-label=\"AU promotional video\"></video>    |     <td>325</td>\n                    </tr>\n      |     </section>        <section id=\"appForm\"      |
# |        |   alt=\"horizontal line graphic\" width=\"400\"    |      </section>        <hr>        <section>       | </tbody>\n            </table>\n            <hr>\n |   class=\"mt-4\">            <h2>Apply Now!</h2>   |
# |        |        height=\"5\">\n        </section>\n         | <h2>Apply Now!</h2>            <p class=\"required | <h2>AU Video</h2>\n            <video src=\"https: |   <p class=\"required\">(required fields are in    |
# |        |      <section>\n            <h2>AU Enrollment      |   reqExample\">(required fields are in blue)</p>   | //www.washington.edu/accesscomputing/AU/video/au-  |      blue)</p>            <form action=\"#\"       |
# |        |          Trends</h2>\n            <table           |        <form action=\"#\" method=\"post\">         | promo.mp4\" poster=\"https://www.washington.edu/ac |        method=\"post\">                <div        |
# |        |   id=\"enrollment\">\n                <thead>\n    |   <div id=\"error\" aria-live=\"polite\"></div>    |   cesscomputing/AU/video/au-promo.jpg\" controls   |     class=\"mb-3\">                    <label      |
# |        | <tr>\n                        <th class=\"corner\" |           <div class=\"mb-3 required\">            |   aria-label=\"AU promotional video\"></video>\n   |          for=\"name\" class=\"form-label           |
# |        |     rowspan=\"2\" style=\"width:6em\"></th>\n      |         <label for=\"name\" class=\"form-          |   </section>\n        <section id=\"appForm\">\n   | required\">Name:</label>                    <input |
# |        |          <th colspan=\"5\" style=\"text-           |   label\">Name</label>                    <input   |        <h2>Apply Now!</h2>\n            <p         |  type=\"text\" class=\"form-control\" id=\"name\"  |
# |        |       align:center\"><b>Last Year</b></th>\n       |  type=\"text\" class=\"form-control\" id=\"name\"  | class=\"required reqExample\">(required fields are |   name=\"name\" required>                </div>    |
# |        |          <th colspan=\"5\" style=\"text-           |   name=\"name\" required>                </div>    |    in blue)</p>\n            <form action=\"#\"    |   <div class=\"mb-3\">                    <label   |
# |        |       align:center\"><b>This Year</b></th>\n       |           <div class=\"mb-3 required\">            |       method=\"post\">\n                <div       |          for=\"email\" class=\"form-label          |
# |        |         </tr>\n                    <tr>\n          |         <label for=\"email\" class=\"form-         |     id=\"error\" aria-live=\"polite\"></div>\n     |             required\">Email:</label>              |
# |        |             <th><abbr title=\"Computer             |  label\">Email</label>                    <input   |             <div class=\"required\">\n             |    <input type=\"email\" class=\"form-control\"    |
# |        |             Science\">CS</abbr></th>\n             | type=\"email\" class=\"form-control\" id=\"email\" |        <label for=\"name\">Name:</label>\n         |       id=\"email\" name=\"email\" required>        |
# |        | <th><abbr title=\"Engineering\">Eng</abbr></th>\n  |   name=\"email\" required>                </div>   |   <input type=\"text\" id=\"name\" name=\"name\"   |     </div>                <div class=\"mb-3\">     |
# |        |  <th><abbr title=\"Economics\">Eco</abbr></th>\n   |   <div class=\"mb-3\">                    <label   | aria-required=\"true\">\n                </div>\n  |        <label for=\"country\" class=\"form-        |
# |        |   <th><abbr title=\"Physics\">Phy</abbr></th>\n    |           for=\"country\" class=\"form-            |             <div class=\"required\">\n             | label\">Country:</label>                    <input |
# |        |  <th><abbr title=\"Psychology\">Psy</abbr></th>\n  | label\">Country</label>                    <input  |       <label for=\"email\">Email:</label>\n        |        type=\"text\" class=\"form-control\"        |
# |        |             <th><abbr title=\"Computer             |        type=\"text\" class=\"form-control\"        | <input type=\"email\" id=\"email\" name=\"email\"  |          id=\"country\" name=\"country\">          |
# |        |             Science\">CS</abbr></th>\n             |          id=\"country\" name=\"country\">          | aria-required=\"true\">\n                </div>\n  |  </div>                <fieldset class=\"mb-3\">   |
# |        | <th><abbr title=\"Engineering\">Eng</abbr></th>\n  |  </div>                <fieldset class=\"mb-3\">   |         <div>\n                    <label          |        <legend class=\"form-label\">Desired        |
# |        |  <th><abbr title=\"Economics\">Eco</abbr></th>\n   |         <legend>Desired major(s):</legend>         |         for=\"country\">Country:</label>\n         |     major(s):</legend>                    <div     |
# |        |   <th><abbr title=\"Physics\">Phy</abbr></th>\n    |             <div class=\"form-check\">             |        <input type=\"text\" id=\"country\"         |               class=\"form-check\">                |
# |        |  <th><abbr title=\"Psychology\">Psy</abbr></th>\n  |         <input class=\"form-check-input\"          |    name=\"country\">\n                </div>\n     |         <input class=\"form-check-input\"          |
# |        |         </tr>\n                </thead>\n          |         type=\"checkbox\" id=\"major_cs\"          |  <fieldset>\n                    <legend>Desired   |         type=\"checkbox\" id=\"major_cs\"          |
# |        |        <tbody>\n                    <tr>\n         |  name=\"major_cs\">                        <label  |    major(s):</legend>\n                    <div    |  name=\"major_cs\">                        <label  |
# |        |          <td><b>Undergraduate</b></td>\n           |             class=\"form-check-label\"             |    id=\"majors\">\n                        <div    |             class=\"form-check-label\"             |
# |        |                  <td>1481</td>\n                   |     for=\"major_cs\">Computer Science</label>      |      class=\"major\"><input type=\"checkbox\"      |     for=\"major_cs\">Computer Science</label>      |
# |        |                   <td>400</td>\n                   |    </div>                    <div class=\"form-    |      id=\"major_cs\" name=\"major_cs\"><label      |    </div>                    <div class=\"form-    |
# |        |                   <td>727</td>\n                   |       check\">                        <input       | for=\"major_cs\">Computer Science</label></div>\n  |       check\">                        <input       |
# |        |                   <td>747</td>\n                   |    class=\"form-check-input\" type=\"checkbox\"    |   <div class=\"major\"><input type=\"checkbox\"    |    class=\"form-check-input\" type=\"checkbox\"    |
# |        |                  <td>1006</td>\n                   |        id=\"major_eng\" name=\"major_eng\">        |     id=\"major_eng\" name=\"major_eng\"><label     |        id=\"major_eng\" name=\"major_eng\">        |
# |        |                  <td>1500</td>\n                   |         <label class=\"form-check-label\"          |   for=\"major_eng\">Engineering</label></div>\n    |         <label class=\"form-check-label\"          |
# |        |                   <td>340</td>\n                   |       for=\"major_eng\">Engineering</label>        |   <div class=\"major\"><input type=\"checkbox\"    |       for=\"major_eng\">Engineering</label>        |
# |        |                   <td>777</td>\n                   |    </div>                    <div class=\"form-    |    id=\"major_econ\" name=\"major_econ\"><label    |    </div>                    <div class=\"form-    |
# |        |                   <td>787</td>\n                   |       check\">                        <input       |    for=\"major_econ\">Economics</label></div>\n    |       check\">                        <input       |
# ...
# |        |              University</span> by <a               |    responsive design. 5. Added aria-labels for     |             </div>\n</body>\n</html>",             |    responsive design. 5. Added aria-labels for     |
# |        |    xmlns:cc=\"http://creativecommons.org/ns#\"     | accessibility. 6. Used semantic HTML elements. 7.  |     "Procedure": "1. Added lang attribute to html  |   accessibility. 6. Corrected heading levels. 7.   |
# |        | href=\"http://washington.edu/accesscomputing/AU\"  |  Corrected heading levels. 8. Added sr-only class  |    tag.\n2. Converted relative URLs to absolute    |   Used semantic HTML elements. 8. Added sr-only    |
# |        |          property=\"cc:attributionName\"           | for screen readers. 9. Improved color contrast in  |    URLs.\n3. Added alt text to images.\n4. Used    |    class for screen readers. 9. Improved color     |
# |        |      rel=\"cc:attributionURL\">University of       |  styles. 10. Added aria-live to error container.   | semantic HTML elements like header, main, section, |   contrast in styles. 10. Added form labels and    |
# |        |       Washington</a> is licensed under a <a        |  11. Used fieldset and legend for form grouping.   | and footer.\n5. Corrected heading levels starting  |  required attributes. 11. Used Bootstrap classes   |
# |        |                  rel=\"license\"                   |  12. Added required attribute to form fields. 13.  |   from h1.\n6. Added aria-labels to buttons and    | for form elements. 12. Added aria-describedby for  |
# |        | href=\"http://creativecommons.org/licenses/by-nc-  |  Added aria-current to active nav link. 14. Added  |    video.\n7. Added labels to form inputs.\n8.     | video. 13. Added captions to carousel images. 14.  |
# |        |      sa/4.0/\">Creative Commons Attribution-       |  aria-label to video element. 15. Used Bootstrap   |  Improved color contrast in CSS.\n9. Added aria-   |  Used Bootstrap navbar for navigation. 15. Added   |
# |        |     NonCommercial-ShareAlike 4.0 International     | classes for layout. 16. Added visually-hidden text |    live to error message container.\n10. Added     |   Bootstrap table classes. 16. Added footer with   |
# |        |   License</a>.\n        </div>\n        <p>This    | for carousel controls. 17. Added descriptive text  | fieldset and legend for checkbox group.\n11. Added |  site map. 17. Included Bootstrap CSS and JS. 18.  |
# |        | product was originally developed with support from |   for CAPTCHA image. 18. Ensured all links have    | sr-only class for screen reader only content.\n12. |         Ensured all links are accessible."         |
# |        |      the National Institute on Disability and      |                 descriptive text."                 |   Ensured all interactive elements are keyboard    |                         }                          |
# |        | Rehabilitation Research of the U.S. Department of  |                         }                          |  accessible.\n13. Added captions to images in the  |                                                    |
# |        |    Education (grant #H133D010306), and has been    |                                                    |  carousel.\n14. Added aria-current to the current  |                                                    |
# |        |  subsequently updated and maintained with support  |                                                    |  page link.\n15. Added aria-required to required   |                                                    |
# |        |    from the National Science Foundation (grants    |                                                    |    form fields.\n16. Added alt text to CAPTCHA     |                                                    |
# |        |      #CNS-0540615, CNS-0837508, CNS-1042260,       |                                                    |       image.\n17. Added aria-label to video        |                                                    |
# |        | CNS-1539179, and CNS-2137312). The contents do not |                                                    |    element.\n18. Added aria-labels to carousel     |                                                    |
# |        |   necessarily represent the policies of the U.S.   |                                                    |                     controls."                     |                                                    |
# |        |   federal government, and you should not assume    |                                                    |                         }                          |                                                    |
# |        |  their endorsement.</p>\n    </footer>\n    <div   |                                                    |                                                    |                                                    |
# |        |    id=\"modalMask\" class=\"sr-only\"></div>\n     |                                                    |                                                    |                                                    |
# |        |   <div id=\"modalContent\" role=\"dialog\" aria-   |                                                    |                                                    |                                                    |
# |        |         labelledby=\"modalHeading\" aria-          |                                                    |                                                    |                                                    |
# |        |           hidden=\"true\">\n        <h2            |                                                    |                                                    |                                                    |
# |        |  id=\"modalHeading\">Accessibility Issues</h2>\n   |                                                    |                                                    |                                                    |
# |        |  <button type=\"button\" id=\"modalClose\" aria-   |                                                    |                                                    |                                                    |
# |        |     label=\"Close\">x</button>\n        <ol>\n     |                                                    |                                                    |                                                    |
# |        |        <li>Missing landmark regions</li>\n         |                                                    |                                                    |                                                    |
# |        | <li>No headings</li>\n            <li>Language not |                                                    |                                                    |                                                    |
# |        | specified</li>\n            <li>No alternate text  |                                                    |                                                    |                                                    |
# |        |            on informative images</li>\n            |                                                    |                                                    |                                                    |
# |        |     <li>Missing or excessive alternate text on     |                                                    |                                                    |                                                    |
# |        |              decorative images</li>\n              |                                                    |                                                    |                                                    |
# |        |       <li>Insufficient color contrast</li>\n       |                                                    |                                                    |                                                    |
# |        |  <li>Color used to communicate information</li>\n  |                                                    |                                                    |                                                    |
# |        |     <li>Inaccessible keyboard interface</li>\n     |                                                    |                                                    |                                                    |
# |        |     <li>No visible indication of focus</li>\n      |                                                    |                                                    |                                                    |
# |        |    <li>No \"skip to main content\" link</li>\n     |                                                    |                                                    |                                                    |
# |        |   <li>Redundant, uninformative link text</li>\n    |                                                    |                                                    |                                                    |
# |        |            <li>Links vs buttons</li>\n             |                                                    |                                                    |                                                    |
# |        |      <li>Inaccessible navigation menu</li>\n       |                                                    |                                                    |                                                    |
# |        |          <li>Inaccessible carousel</li>\n          |                                                    |                                                    |                                                    |
# |        |        <li>Inaccessible modal dialog</li>\n        |                                                    |                                                    |                                                    |
# |        |        <li>Form not properly labeled</li>\n        |                                                    |                                                    |                                                    |
# |        |          <li>Inaccessible CAPTCHA</li>\n           |                                                    |                                                    |                                                    |
# |        |      <li>Inaccessible input validation</li>\n      |                                                    |                                                    |                                                    |
# |        |     <li>Missing accessible table markup</li>\n     |                                                    |                                                    |                                                    |
# |        |        <li>Missing abbreviation tags</li>\n        |                                                    |                                                    |                                                    |
# |        |   <li>Inaccessible audio content in video</li>\n   |                                                    |                                                    |                                                    |
# |        |  <li>Inaccessible visual content in video</li>\n   |                                                    |                                                    |                                                    |
# |        |       </ol>\n        <button type=\"button\"       |                                                    |                                                    |                                                    |
# |        |            id=\"modalOk\">OK</button>\n            |                                                    |                                                    |                                                    |
# |        |             </div>\n</body>\n</html>",             |                                                    |                                                    |                                                    |
# |        |     "Procedure": "1. Added lang attribute to html  |                                                    |                                                    |                                                    |
# |        |    tag.\n2. Converted relative URLs to absolute    |                                                    |                                                    |                                                    |
# |        |   URLs.\n3. Added skip to main content link.\n4.   |                                                    |                                                    |                                                    |
# |        |   Used semantic HTML elements like header, nav,    |                                                    |                                                    |                                                    |
# |        | main, section, and footer.\n5. Corrected alt text  |                                                    |                                                    |                                                    |
# |        |  for images.\n6. Added aria-labels to buttons and  |                                                    |                                                    |                                                    |
# |        |  inputs.\n7. Improved color contrast in CSS.\n8.   |                                                    |                                                    |                                                    |
# |        |  Added captions track to video element.\n9. Used   |                                                    |                                                    |                                                    |
# |        | fieldset and legend for form grouping.\n10. Added  |                                                    |                                                    |                                                    |
# |        |  role and aria attributes for accessibility.\n11.  |                                                    |                                                    |                                                    |
# |        |  Used abbr tags for table headers.\n12. Added sr-  |                                                    |                                                    |                                                    |
# |        |  only class for screen reader text.\n13. Ensured   |                                                    |                                                    |                                                    |
# |        |  all headings are properly structured.\n14. Added  |                                                    |                                                    |                                                    |
# |        | role=\"alert\" to error div for form validation."  |                                                    |                                                    |                                                    |
# |        |                         }                          |                                                    |                                                    |                                                    |
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+

# %% [markdown]
# ## JSON Objects Retrieval
#
# The resulting JSON objects are extracted.

# %%
extracted_json_html = json.loads(extracted_html)
extracted_json_html_template = json.loads(extracted_html_template)
extracted_json_md = json.loads(extracted_md)
extracted_json_md_template = json.loads(extracted_md_template)

# %%
# Esto solo si queremos mostrar el resultado en la interfaz de gradio
create_interface(extracted_json_html, extracted_json_html_template, extracted_json_md, extracted_json_md_template)

# %%
generate_output_files("gpt-site1", extracted_json_html, extracted_json_html_template, extracted_json_md, extracted_json_md_template)

# %% [markdown]
# ## Google Gemini: Washington University Site
#
# Let’s examine the result produced by this model.

# %%
extracted_html, extracted_html_template, extracted_md, extracted_md_template = display_extracted_content("gemini-2.5-flash-preview-04-17", all_content_html, all_content_md, "Crawl4ai", site_name="Site 1", template="blocks")
# Out:
# Processing results:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for HTML input:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for HTML input and template:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for Markdown input:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for Markdown input and template:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracted Content Table:
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# |  Site  |                     From HTML                      |              From HTML with template               |                   From markdown                    |            From markdown with template             |
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# | Site 1 |              Completion tokens: 8,414              |              Completion tokens: 7,831              |             Completion tokens: 10,118              |              Completion tokens: 7,269              |
# |        |                Prompt tokens: 3,890                |                Prompt tokens: 6,769                |                Prompt tokens: 3,943                |                Prompt tokens: 6,764                |
# |        |               Total cost: $0.030760                |               Total cost: $0.036500                |               Total cost: $0.035153                |               Total cost: $0.035083                |
# |        |                                                    |                                                    |                                                    |                                                    |
# |        |                                                    |                                                    |                                                    |                                                    |
# |        |                         {                          |                         {                          |                         {                          |                         {                          |
# |        |           "HTML": "<!DOCTYPE html>\n<html          |           "HTML": "<!DOCTYPE html>\n<html          |           "HTML": "<!DOCTYPE html>\n<html          |           "HTML": "<!DOCTYPE html>\n<html          |
# |        |           lang=\"en\">\n<head>\n\t<meta            |          lang=\"en\">\n<head>\n    <meta           |          lang=\"en\">\n<head>\n    <meta           |          lang=\"en\">\n<head>\n    <meta           |
# |        | charset=\"utf-8\">\n\t<title>Accessible University |  charset=\"UTF-8\">\n    <meta name=\"viewport\"   |     charset=\"utf-8\">\n    <title>Accessible      |  charset=\"UTF-8\">\n    <meta name=\"viewport\"   |
# |        | Demo Site - Inaccessible Version</title>\n  <link  | content=\"width=device-width, initial-scale=1\">\n |    University Demo Site - Inaccessible Version     | content=\"width=device-width, initial-scale=1\">\n |
# |        | rel=\"apple-touch-icon\" sizes=\"180x180\" href=\" |      <title>Accessible University Demo Site -      |      (Accessible Version)</title>\n    <link       |      <title>Accessible University Demo Site -      |
# |        | https://www.washington.edu/accesscomputing/AU/imag | Inaccessible Version</title>\n    <link href=\"htt | rel=\"apple-touch-icon\" sizes=\"180x180\" href=\" | Accessible Version</title>\n    <link rel=\"apple- |
# |        |    es/favicon/apple-touch-icon.png\">\n  <link     | ps://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/css | https://www.washington.edu/accesscomputing/AU/imag | touch-icon\" sizes=\"180x180\" href=\"https://www. |
# |        | rel=\"icon\" type=\"image/png\" sizes=\"32x32\" hr |     /bootstrap.min.css\" rel=\"stylesheet\">\n     |   es/favicon/apple-touch-icon.png\">\n    <link    | washington.edu/accesscomputing/AU/images/favicon/a |
# |        | ef=\"https://www.washington.edu/accesscomputing/AU |  <style>\n        /* Inlined styles from original  | rel=\"icon\" type=\"image/png\" sizes=\"32x32\" hr |   pple-touch-icon.png\">\n    <link rel=\"icon\"   |
# |        |   /images/favicon/favicon-32x32.png\">\n  <link    |     CSS files, adjusted for accessibility */\n     | ef=\"https://www.washington.edu/accesscomputing/AU | type=\"image/png\" sizes=\"32x32\" href=\"https:// |
# |        | rel=\"icon\" type=\"image/png\" sizes=\"16x16\" hr |   body {\n            font-family: Arial, sans-    |  /images/favicon/favicon-32x32.png\">\n    <link   | www.washington.edu/accesscomputing/AU/images/favic |
# |        | ef=\"https://www.washington.edu/accesscomputing/AU |      serif;\n            line-height: 1.6;\n       | rel=\"icon\" type=\"image/png\" sizes=\"16x16\" hr |  on/favicon-32x32.png\">\n    <link rel=\"icon\"   |
# |        | /images/favicon/favicon-16x16.png\">\n  <style>\n  |       margin: 0;\n            padding: 0;\n        | ef=\"https://www.washington.edu/accesscomputing/AU | type=\"image/png\" sizes=\"16x16\" href=\"https:// |
# |        |    /* Inlined CSS from au-shared.css, main.css,    | background-color: #f4f4f4; /* Adjusted for better  |       /images/favicon/favicon-16x16.png\">\n       | www.washington.edu/accesscomputing/AU/images/favic |
# |        | before-main.css, before-menu.css, before-form.css, | contrast if needed */\n            color: #333; /* |   <style>\n        /* Combined and corrected CSS   | on/favicon-16x16.png\">\n    <link href=\"https:// |
# |        |  before-modal.css, before-carousel.css */\n    /*  |    Adjusted for better contrast if needed */\n     |   from au-shared.css, main.css, before-main.css,   | cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/css/boot |
# |        | Note: Color contrast adjustments and focus styles  |   }\n\n        .sr-only {\n            position:   |     before-menu.css, before-form.css, before-      | strap.min.css\" rel=\"stylesheet\">\n    <style>\n |
# |        |   added/verified */\n\n    /* sr-only class for    |        absolute;\n            width: 1px;\n        |  modal.css, before-carousel.css */\n\n        /*   |   .sr-only {\n            position: absolute;\n    |
# |        |   visually hidden elements */\n    .sr-only {\n    |      height: 1px;\n            padding: 0;\n       |  sr-only class for visually hidden elements */\n   |      width: 1px;\n            height: 1px;\n       |
# |        |      position: absolute;\n      width: 1px;\n      |   margin: -1px;\n            overflow: hidden;\n   |   .sr-only {\n            position: absolute;\n    |      padding: 0;\n            margin: -1px;\n      |
# |        |   height: 1px;\n      padding: 0;\n      margin:   | clip: rect(0, 0, 0, 0);\n            white-space:  |      width: 1px;\n            height: 1px;\n       | overflow: hidden;\n            clip: rect(0, 0, 0, |
# |        |    -1px;\n      overflow: hidden;\n      clip:     |   nowrap;\n            border: 0;\n        }\n\n   |      padding: 0;\n            margin: -1px;\n      |      0);\n            white-space: nowrap;\n       |
# |        |  rect(0, 0, 0, 0);\n      white-space: nowrap;\n   |    #content {\n            max-width: 1200px;\n    | overflow: hidden;\n            clip: rect(0, 0, 0, |   border: 0;\n        }\n        /* Basic layout   |
# |        | border: 0;\n    }\n\n    /* Basic styles from au-  | margin: 20px auto;\n            background-color:  |      0);\n            white-space: nowrap;\n       |        adjustments */\n        #content {\n        |
# |        |   shared.css */\n    body {\n      font-family:    |        #fff;\n            padding: 20px;\n         |   border: 0;\n        }\n\n        /* Basic body   |  max-width: 960px;\n            margin: 0 auto;\n  |
# |        |   Arial, sans-serif;\n      line-height: 1.5;\n    |     box-shadow: 0 0 10px rgba(0, 0, 0, 0.1);\n     |  styles (from au-shared.css) */\n        body {\n  |  padding: 0 15px;\n        }\n        #banner {\n  |
# |        |  margin: 0;\n      padding: 0;\n      background-  |    }\n\n        #banner {\n            display:    | font-family: Arial, sans-serif;\n            line- |  text-align: center;\n            margin-bottom:   |
# |        |  color: #f0f0f0; /* Example light background */\n  |     flex;\n            align-items: center;\n      |       height: 1.6;\n            margin: 0;\n       |        20px;\n        }\n        #logo {\n         |
# |        | color: #333; /* Example dark text color - ensures  |         justify-content: space-between;\n          |   padding: 0;\n            color: #333; /* Good    |   max-width: 100%;\n            height: auto;\n    |
# |        |   good contrast */\n    }\n    a {\n      color:   | margin-bottom: 20px;\n            flex-wrap: wrap; | contrast */\n            background-color: #fff;\n | }\n        #main, #appForm {\n            margin-  |
# |        |   #005a9c; /* Example link color - ensures good    |   /* Added for responsiveness */\n        }\n\n    |      }\n\n        /* Focus styles (added for       |    bottom: 30px;\n        }\n        /* Ensure     |
# |        | contrast */\n      text-decoration: underline; /*  | #logo {\n            max-width: 100%; /* Added for | accessibility) */\n        a:focus, button:focus,  |    sufficient contrast for required fields */\n    |
# |        |   Added underline for non-color distinction */\n   |  responsiveness */\n            height: auto; /*   |     input:focus, select:focus, textarea:focus,     |  .form-label.required-label {\n            font-   |
# |        | }\n    a:hover, a:focus {\n      text-decoration:  |     Added for responsiveness */\n        }\n\n     | [tabindex]:focus {\n            outline: 3px solid | weight: bold;\n            color: #000; /* Ensure  |
# |        | none;\n      outline: 2px solid #005a9c; /* Ensure |   #AU-menu ul {\n            list-style: none;\n   |   #0066cc; /* Added visible focus indicator */\n   |    sufficient contrast, original was blue */\n     |
# |        | focus outline is visible */\n    }\n    button {\n |       padding: 0;\n            margin: 0;\n        | outline-offset: 2px;\n        }\n\n        /* Link |  }\n        .form-label.required-label::after {\n  |
# |        |     cursor: pointer;\n      outline: 2px solid     |  display: flex;\n        }\n\n        #AU-menu li  |  color adjustment for contrast */\n        a {\n   |   content: \" *\"; /* Add visual indicator */\n    |
# |        |    transparent; /* Default outline */\n    }\n     |  {\n            margin-left: 20px;\n        }\n\n  |  color: #0066cc; /* Changed from #00f (2.7:1) to   | color: red; /* Or another high-contrast color */\n |
# |        |  button:focus {\n      outline-color: #005a9c; /*  | #AU-menu a {\n            text-decoration: none;\n |  #0066cc (4.5:1) */\n            text-decoration:  |       }\n        /* Table improvements */\n        |
# |        |   Visible focus outline for buttons */\n    }\n    | color: #0056b3; /* Ensure sufficient contrast */\n |    underline;\n        }\n\n        a:hover {\n    |  #enrollment caption {\n            caption-side:  |
# |        |  input[type=\"text\"], input[type=\"checkbox\"],   | font-weight: bold;\n        }\n\n        #AU-menu  |  text-decoration: none;\n        }\n\n        /*   |       top;\n            font-weight: bold;\n       |
# |        |   input[type=\"submit\"] {\n       outline: 2px    |       a:hover,\n        #AU-menu a:focus {\n       |       Layout container (from main.css) */\n        |   text-align: left;\n            padding: 8px;\n   |
# |        | solid transparent; /* Default outline */\n    }\n  |     text-decoration: underline;\n        }\n\n     |    #content {\n            max-width: 1000px;\n    | }\n        /* Video container */\n        .video-  |
# |        |            input[type=\"text\"]:focus,             | /* Secondary menu styles adapted for Bootstrap nav |  margin: 0 auto;\n            padding: 0 20px;\n   |   container {\n            position: relative;\n   |
# |        |          input[type=\"checkbox\"]:focus,           |      */\n        .secondary-nav .nav-link {\n      |   }\n\n        /* Header/Banner (from main.css,    | padding-bottom: 56.25%; /* 16:9 aspect ratio */\n  |
# |        |  input[type=\"submit\"]:focus {\n       outline-   | color: #0056b3; /* Ensure sufficient contrast */\n |              modified for flex) */\n               |    height: 0;\n            overflow: hidden;\n     |
# |        | color: #005a9c; /* Visible focus outline for form  |         font-weight: bold;\n        }\n\n          | header[role=\"banner\"] { /* Changed from #banner  | max-width: 100%;\n            background: #000;\n  |
# |        |  elements */\n    }\n\n    /* Layout styles from   |         .secondary-nav .nav-link:hover,\n          | div */\n            display: flex; /* Use flexbox  |       }\n        .video-container video {\n        |
# |        |   main.css */\n    #content {\n      max-width:    |         .secondary-nav .nav-link:focus {\n         |   for logo and nav */\n            align-items:    |     position: absolute;\n            top: 0;\n     |
# |        | 1000px;\n      margin: 0 auto;\n      background-  |     text-decoration: underline;\n        }\n\n     |    center;\n            justify-content: space-    |        left: 0;\n            width: 100%;\n        |
# |        |      color: #fff;\n      box-shadow: 0 0 10px      |        .secondary-nav .dropdown-menu a {\n         |      between;\n            padding: 20px 0;\n      |     height: 100%;\n        }\n        /* Modal     |
# |        |      rgba(0,0,0,0.1);\n    }\n    #banner {\n      |  color: #333; /* Ensure sufficient contrast */\n   |   border-bottom: 1px solid #ccc;\n        }\n\n    |  adjustments */\n        .modal-header .btn-close  |
# |        |   display: flex;\n      justify-content: space-    |     }\n\n        .secondary-nav .dropdown-menu     |    header[role=\"banner\"] img { /* #logo */\n     |     {\n            margin: -0.125rem -0.125rem     |
# |        |       between;\n      align-items: center;\n       |  a:hover,\n        .secondary-nav .dropdown-menu   |   max-width: 100%;\n            height: auto;\n    |            -0.125rem auto;\n        }\n            |
# |        |    padding: 10px 20px;\n      background-color:    |     a:focus {\n             background-color:      |    }\n\n        /* Primary Navigation (from au-    |  </style>\n</head>\n<body>\n    <a href=\"#main-   |
# |        |   #e9e9e9; /* Example light grey background */\n   | #f8f9fa;\n             color: #000;\n        }\n\n |  shared.css, before-menu.css, modified for flex)   | content\" class=\"sr-only sr-only-focusable\">Skip |
# |        |  }\n    #AU-menu ul {\n      list-style: none;\n   |  #main, #appForm {\n            padding: 15px;\n   |     */\n        nav[aria-label=\"Primary site      | to main content</a>\n\n    <header>\n        <nav  |
# |        |   padding: 0;\n      margin: 0;\n      display:    | }\n\n        .heading {\n            /* This class |   navigation\"] ul { /* Changed from #AU-menu ul   |      class=\"navbar navbar-expand-lg bg-body-      |
# |        |   flex;\n    }\n    #AU-menu li {\n      margin-   | was used for non-semantic headings. Replaced by h  |        */\n            list-style: none;\n         |  tertiary\">\n            <div class=\"container-  |
# |        |  left: 20px;\n    }\n    #main {\n      padding:   |   tags. */\n            /* Keeping the style for   |       padding: 0;\n            margin: 0;\n        |    fluid\">\n                <a class=\"navbar-    |
# |        | 20px;\n      display: flex;\n      flex-direction: |  visual consistency if needed, but semantic tags   |   display: flex;\n        }\n\n        nav[aria-   | brand\" href=\"https://www.washington.edu/accessco |
# |        | column;\n      gap: 20px;\n    }\n    #appForm {\n |  are primary */\n            font-size: 1.5em;\n   |     label=\"Primary site navigation\"] li {\n      | mputing/AU/index.html\">\n                    <img |
# |        |  padding: 20px;\n      background-color: #f9f9f9;  |   margin-top: 20px;\n            margin-bottom:    | margin-left: 20px;\n        }\n\n        nav[aria- | id=\"logo\" src=\"https://www.washington.edu/acces |
# |        |    /* Example slightly lighter grey */\n    }\n    |      10px;\n            font-weight: bold;\n       |      label=\"Primary site navigation\"] a {\n      |       scomputing/AU/images/au123456789.gif\"       |
# |        | #footer {\n      padding: 20px;\n      background- | }\n\n        .hr {\n            display: block;\n  |  text-decoration: none;\n            color: #000;  |  alt=\"Accessible University Home\" width=\"441\"  |
# |        |    color: #e9e9e9;\n      text-align: center;\n    |    margin: 20px 0;\n            width: 100%; /*    |        /* Assuming background is light */\n        |       height=\"90\">\n                </a>\n       |
# |        |    font-size: 0.9em;\n    }\n    #footer a {\n     |         Ensure it spans the container */\n         | font-weight: bold;\n        }\n\n        nav[aria- |  <button class=\"navbar-toggler\" type=\"button\"  |
# |        |  text-decoration: underline;\n    }\n    #footer   |    height: auto; /* Maintain aspect ratio */\n     |     label=\"Primary site navigation\"] a[aria-     |        data-bs-toggle=\"collapse\" data-bs-        |
# |        | a:hover, #footer a:focus {\n      text-decoration: |   }\n\n        #enrollment {\n            width:   | current=\"page\"] {\n            text-decoration:  | target=\"#navbarNav\" aria-controls=\"navbarNav\"  |
# |        |     none;\n    }\n\n    /* Heading styles from     |  100%;\n            border-collapse: collapse;\n   |   underline;\n        }\n\n        /* Secondary    |    aria-expanded=\"false\" aria-label=\"Toggle     |
# |        |  main.css and before-main.css */\n    h1, h2, h3   |          margin-top: 20px;\n        }\n\n          | Navigation (Dropdown Menu) (from before-menu.css)  |      navigation\">\n                    <span      |
# |        | {\n      color: #005a9c; /* Example heading color  |    #enrollment th,\n        #enrollment td {\n     | */\n        nav[aria-label=\"Section navigation\"] |      class=\"navbar-toggler-icon\"></span>\n       |
# |        | - ensures good contrast */\n      margin-top: 0;\n |   border: 1px solid #ddd;\n            padding:    | { /* Changed from #menu ul */\n            margin- |  </button>\n                <div class=\"collapse  |
# |        | }\n    .heading {\n        /* This class was used  | 8px;\n            text-align: left;\n        }\n\n | top: 20px;\n            background-color: #eee;\n  |       navbar-collapse\" id=\"navbarNav\">\n        |
# |        |    for styling divs as headings. Replaced with     |  #enrollment th {\n            background-color:   |  padding: 10px 0;\n        }\n\n        nav[aria-  |        <ul class=\"navbar-nav ms-auto\">\n         |
# |        |  semantic tags. */\n    }\n\n    /* HR style from  |  #f2f2f2; /* Ensure sufficient contrast with text  |       label=\"Section navigation\"] > ul {\n       |             <li class=\"nav-item\">\n              |
# |        |  main.css */\n    .hr {\n      display: block;\n   | */\n            font-weight: bold;\n        }\n\n  |    list-style: none;\n            padding: 0;\n    | <a class=\"nav-link\" href=\"https://www.washingto |
# |        |  margin: 20px 0;\n      width: 100%; /* Ensure it  |      #enrollment tbody tr:nth-child(even) {\n      |      margin: 0;\n            display: flex;\n      |  n.edu/accesscomputing/AU/index.html\">Home</a>\n  |
# |        |      spans the width */\n      height: 5px;\n      |     background-color: #f9f9f9;\n        }\n\n      |   justify-content: space-around;\n        }\n\n    |  </li>\n                        <li class=\"nav-   |
# |        | background: linear-gradient(to right, #ccc, #fff); |  #enrollment caption {\n            caption-side:  |  nav[aria-label=\"Section navigation\"] > ul > li  |      item\">\n                            <a       |
# |        |   /* Example gradient */\n      border: none;\n    |       top;\n            font-weight: bold;\n       | {\n            position: relative;\n        }\n\n  | class=\"nav-link active\" href=\"https://www.washi |
# |        |     }\n\n    /* Video style from main.css */\n     |   margin-bottom: 10px;\n            text-align:    |  nav[aria-label=\"Section navigation\"] ul ul {\n  |  ngton.edu/accesscomputing/AU/before.html\" aria-  |
# |        |   video {\n      max-width: 100%;\n      height:   |     left;\n            color: #333; /* Ensure      |  display: none; /* Hidden by default, shown by JS  |           current=\"page\">Before</a>\n            |
# |        |  auto;\n    }\n\n    /* Menu styles from before-   |       sufficient contrast */\n        }\n\n        |       */\n            position: absolute;\n        |  </li>\n                        <li class=\"nav-   |
# |        |    menu.css */\n    #menu {\n      list-style:     | #appForm .required {\n            /* Original blue |         top: 100%;\n            left: 0;\n         |      item\">\n                            <a       |
# |        |    none;\n      padding: 0;\n      margin: 0;\n    |  color fails contrast. Keeping it for visual cue   |  background-color: #eee;\n            list-style:  | class=\"nav-link\" href=\"https://www.washington.e |
# |        | background-color: #333; /* Example dark background |    but adding text/aria */\n            color:     |        none;\n            padding: 10px;\n         |   du/accesscomputing/AU/after.html\">After</a>\n   |
# |        |  */\n      display: flex; /* Assuming horizontal   |   #0000ff; /* Fails WCAG contrast, but kept for    | margin: 0;\n            border: 1px solid #ccc;\n  |  </li>\n                        <li class=\"nav-   |
# |        | menu */\n    }\n    #menu > li {\n      position:  |  original visual reference */\n            font-   |    z-index: 10;\n        }\n\n        nav[aria-    |      item\">\n                            <a       |
# |        |  relative;\n      margin: 0;\n    }\n    #menu a   | weight: bold; /* Added for non-color emphasis */\n |     label=\"Section navigation\"] ul ul li {\n     | class=\"nav-link\" href=\"https://www.washington.e |
# |        |   {\n      display: block;\n      padding: 10px    |       }\n\n        #appForm .reqExample {\n        |   margin: 5px 0;\n        }\n\n        nav[aria-   |    du/accesscomputing/AU/info.html\">Info</a>\n    |
# |        |  15px;\n      color: #fff; /* Example light text   |  font-style: italic;\n             margin-bottom:  |     label=\"Section navigation\"] ul ul a {\n      |         </li>\n                    </ul>\n         |
# |        |   color - ensures good contrast */\n      text-    |    15px;\n        }\n\n        #appForm div {\n    | white-space: nowrap;\n        }\n\n        /* Main |   </div>\n            </div>\n        </nav>\n\n   |
# |        |   decoration: none; /* Remove underline for menu   |        margin-bottom: 15px;\n        }\n\n         |     content and Sidebar layout (from main.css,     |   <nav class=\"navbar navbar-expand-lg bg-light    |
# |        | items */\n    }\n    #menu a:hover, #menu a:focus  |  #appForm label {\n            display: block;\n   | modified for flex) */\n        .main-content-area  |    mb-3\">\n            <div class=\"container-    |
# |        |    {\n      background-color: #555; /* Example     | margin-bottom: 5px;\n        }\n\n        #appForm |  { /* New container div */\n            display:   | fluid\">\n                <button class=\"navbar-  |
# |        | hover/focus background */\n      text-decoration:  |      input[type=\"text\"],\n        #appForm       |    flex;\n            flex-wrap: wrap; /* Allow    |         toggler\" type=\"button\" data-bs-         |
# |        | none;\n      outline: none; /* Outline handled by  |    input[type=\"email\"] {\n            width:     |          wrapping on smaller screens */\n          |            toggle=\"collapse\" data-bs-            |
# |        |    link focus style */\n    }\n    #menu ul {\n    | 100%;\n            padding: 8px;\n            box- |          margin-top: 20px;\n        }\n\n          |           target=\"#secondaryNav\" aria-           |
# |        |      display: none; /* Hidden by default */\n      | sizing: border-box;\n        }\n\n        #majors  |  main[role=\"main\"] { /* Changed from #main div   | controls=\"secondaryNav\" aria-expanded=\"false\"  |
# |        | position: absolute;\n      top: 100%;\n      left: |    .major {\n            margin-bottom: 5px;\n     |  */\n            flex: 2; /* Takes up more space   |   aria-label=\"Toggle secondary navigation\">\n    |
# |        |    0;\n      background-color: #555; /* Example    | }\n\n        #captcha img {\n            display:  | */\n            min-width: 300px; /* Minimum width |   <span class=\"navbar-toggler-icon\"></span>\n    |
# |        |  submenu background */\n      list-style: none;\n  |      block;\n            margin-top: 10px;\n       |   before wrapping */\n            margin-right:    |  </button>\n                <div class=\"collapse  |
# |        |  padding: 0;\n      margin: 0;\n      min-width:   | max-width: 100%; /* Added for responsiveness */\n  |     20px; /* Space between main and aside */\n     |      navbar-collapse\" id=\"secondaryNav\">\n      |
# |        | 150px;\n      z-index: 10;\n    }\n    #menu ul a  |   height: auto; /* Added for responsiveness */\n   |  }\n\n        aside[role=\"aside\"] { /* Changed   |   <ul class=\"navbar-nav w-100 justify-content-    |
# |        | {\n      padding: 8px 15px;\n      color: #fff; /* |  }\n\n        #footer {\n            margin-top:   |   from #appForm div */\n            flex: 1; /*    |       around\">\n                        <li       |
# |        |   Example light text color */\n    }\n    #menu    |      30px;\n            padding-top: 20px;\n       |   Takes up less space */\n            min-width:   |           class=\"nav-item dropdown\">\n           |
# |        |    li:hover > ul, #menu li a:focus + ul, #menu     |   border-top: 1px solid #ddd;\n            font-   |    250px; /* Minimum width before wrapping */\n    |  <a class=\"nav-link dropdown-toggle\" href=\"#\"  |
# |        | ul:focus-within {\n       display: block; /* Show  |  size: 0.9em;\n            color: #555; /* Ensure  |  }\n\n        /* Headings (from main.css, before-  |   id=\"aboutDropdown\" role=\"button\" data-bs-    |
# |        |  submenu on hover/focus */\n    }\n\n    /* Form   |       sufficient contrast */\n        }\n\n        |     main.css) */\n        h2 { /* Changed from     |   toggle=\"dropdown\" aria-expanded=\"false\">\n   |
# |        | styles from before-form.css */\n    #appForm form  |      #license {\n            display: flex;\n      |    .heading */\n            font-size: 1.8em;\n    |     About\n                            </a>\n      |
# |        |     div {\n      margin-bottom: 15px;\n    }\n     |  align-items: center;\n            margin-bottom:  |   margin-top: 1.5em;\n            margin-bottom:   |         <ul class=\"dropdown-menu\" aria-          |
# |        |     #appForm label {\n      display: block;\n      |  15px;\n            flex-wrap: wrap; /* Added for  | 0.5em;\n            color: #000; /* Good contrast  |          labelledby=\"aboutDropdown\">\n           |
# |        |  margin-bottom: 5px;\n      font-weight: bold;\n   |  responsiveness */\n        }\n\n        #ccLogo   | */\n        }\n\n        /* Horizontal rule image  | <li><a class=\"dropdown-item\" href=\"https://www. |
# |        |   }\n    #appForm input[type=\"text\"], #appForm   | {\n            margin-right: 15px;\n        }\n\n  |  (decorative) (from main.css) */\n        img.hr   | washington.edu/accesscomputing/AU/somepage.html?re |
# |        | input[type=\"email\"] {\n      width: calc(100% -  |  #license img {\n             border-width: 0;\n   |          {\n            display: block;\n          |              f=News\">News</a></li>\n              |
# |        | 22px); /* Adjust width considering padding/border  |    }\n\n        #footer a {\n            color:    | margin: 20px auto;\n            max-width: 100%;\n | <li><a class=\"dropdown-item\" href=\"https://www. |
# |        | */\n      padding: 10px;\n      border: 1px solid  |    #0056b3; /* Ensure sufficient contrast */\n     |  height: auto;\n        }\n\n        /* Carousel   | washington.edu/accesscomputing/AU/somepage.html?re |
# |        |   #ccc;\n    }\n    #appForm .required label {\n   |   }\n\n        #footer a:hover,\n        #footer   |  (from before-carousel.css) */\n        #carousel  |        f=Governance\">Governance</a></li>\n        |
# |        | color: #005a9c; /* Example blue color for required |      a:focus {\n            text-decoration:       |        {\n            position: relative;\n        | <li><a class=\"dropdown-item\" href=\"https://www. |
# |        |  label - ensure contrast */\n    }\n    #appForm   |  underline;\n        }\n\n        /* Modal styles  |    margin-bottom: 20px;\n            overflow:     | washington.edu/accesscomputing/AU/somepage.html?re |
# |        | .required label::after { /* Added visual indicator |  adapted for Bootstrap modal */\n        .modal-   |   hidden; /* Hide extra slides */\n        }\n\n   |         f=Diversity\">Diversity</a></li>\n         |
# |        | */\n        content: \" *\";\n        color: red;  |     content {\n            border-radius: 0;\n     |    #carousel #controls {\n            position:    | <li><a class=\"dropdown-item\" href=\"https://www. |
# |        |     /* Example color for asterisk */\n    }\n      |           }\n\n        .modal-header {\n           |         absolute;\n            top: 50%;\n         | washington.edu/accesscomputing/AU/somepage.html?re |
# |        |   #appForm #majors label {\n        font-weight:   |  background-color: #f8f9fa;\n            border-   |     width: 100%;\n            display: flex;\n     |       f=Contact%20Us\">Contact Us</a></li>\n       |
# |        |  normal; /* Checkbox labels don't need bold */\n   |     bottom: 1px solid #dee2e6;\n        }\n\n      |         justify-content: space-between;\n          |       </ul>\n                        </li>\n       |
# |        |   display: inline-block; /* Allow checkboxes and   | .modal-title {\n            font-size: 1.25rem;\n  | transform: translateY(-50%);\n            z-index: |         <li class=\"nav-item dropdown\">\n         |
# |        |   labels on same line */\n        margin-right:    |          }\n\n        .modal-body ol {\n           |   5;\n            pointer-events: none; /* Allow   |  <a class=\"nav-link dropdown-toggle\" href=\"#\"  |
# |        |    15px;\n    }\n    #appForm #captcha img {\n     | padding-left: 20px;\n        }\n\n        .modal-  |      clicks to pass through */\n        }\n\n      | id=\"academicsDropdown\" role=\"button\" data-bs-  |
# |        |   vertical-align: middle;\n        margin-left:    |    footer {\n            border-top: 1px solid     | #carousel #controls button { /* Changed from div,  |   toggle=\"dropdown\" aria-expanded=\"false\">\n   |
# |        |   10px;\n        border: 1px solid #ccc; /* Add    | #dee2e6;\n        }\n\n        /* Carousel styles  |  styled as buttons */\n            width: 40px;\n  |   Academics\n                            </a>\n    |
# |        |   border for visibility */\n    }\n    #appForm    |        adapted for Bootstrap carousel */\n         |    height: 40px;\n            background-color:    |         <ul class=\"dropdown-menu\" aria-          |
# |        |       #submit {\n      padding: 10px 20px;\n       |  #carousel {\n            margin-bottom: 20px;\n   |  rgba(0, 0, 0, 0.5);\n            color: #fff;\n   |        labelledby=\"academicsDropdown\">\n         |
# |        | background-color: #005a9c; /* Example button color |   }\n\n        #carousel .carousel-item img {\n    | font-size: 2em;\n            line-height: 40px;\n  | <li><a class=\"dropdown-item\" href=\"https://www. |
# |        |   */\n      color: #fff; /* Example button text    |     width: 100%;\n            height: auto;\n      |      text-align: center;\n            cursor:      | washington.edu/accesscomputing/AU/somepage.html?re |
# |        |  color - ensures good contrast */\n      border:   |    }\n\n        #carousel .carousel-caption {\n    | pointer;\n            pointer-events: auto; /* Re- |  f=Degree%20Programs\">Degree Programs</a></li>\n  |
# |        | none;\n      cursor: pointer;\n    }\n    #appForm |  background-color: rgba(0, 0, 0, 0.5); /* Ensure   |  enable clicks for buttons */\n            user-   | <li><a class=\"dropdown-item\" href=\"https://www. |
# |        |     #submit:hover, #appForm #submit:focus {\n      |   text contrast on image */\n            color:    | select: none;\n            border: none; /* Remove | washington.edu/accesscomputing/AU/somepage.html?re |
# |        | background-color: #003f6b; /* Example darker hover |        #fff;\n            padding: 10px;\n         |   default button border */\n            padding:   |       f=AU%20Faculty\">AU Faculty</a></li>\n       |
# |        | color */\n    }\n    #error {\n        color: red; |         bottom: 0;\n            left: 0;\n         | 0;\n        }\n\n        #carousel #controls #btn- | <li><a class=\"dropdown-item\" href=\"https://www. |
# |        | /* Example error text color - ensure contrast */\n | right: 0;\n            width: 100%;\n        }\n\n |   prev { margin-left: 10px; }\n        #carousel   | washington.edu/accesscomputing/AU/somepage.html?re |
# |        | font-weight: bold;\n        margin-bottom: 15px;\n |     /* Original control styles removed, using      |  #controls #btn-next { margin-right: 10px; }\n\n   |          f=Distance%20Learning\">Distance          |
# |        |   }\n\n    /* Modal styles from before-modal.css   |  Bootstrap buttons */\n        /* Original lentil  | #carousel #slides {\n            display: flex; /* |                Learning</a></li>\n                 |
# |        |   */\n    #modalMask {\n      display: none; /*    | styles removed, using Bootstrap indicators */\n\n  |            Arrange slides in a row */\n            | <li><a class=\"dropdown-item\" href=\"https://www. |
# |        |   Hidden by default */\n      position: fixed;\n   |  </style>\n</head>\n<body>\n    <a href=\"#main-   | transition: transform 0.5s ease-in-out; /* Smooth  | washington.edu/accesscomputing/AU/somepage.html?re |
# |        |   top: 0;\n      left: 0;\n      width: 100%;\n    | content\" class=\"sr-only sr-only-focusable\">Skip |   transition */\n        }\n\n        #carousel    |         f=Libraries\">Libraries</a></li>\n         |
# |        | height: 100%;\n      background-color: rgba(0, 0,  |   to main content</a>\n\n    <div id=\"content\"   |   .slide {\n            min-width: 100%; /* Each   |       </ul>\n                        </li>\n       |
# |        |     0, 0.7); /* Semi-transparent overlay */\n      |      class=\"container\">\n\n        <header       |      slide takes full width of container */\n      |         <li class=\"nav-item dropdown\">\n         |
# |        |    z-index: 1000;\n    }\n    #modalContent {\n    | id=\"banner\">\n            <img id=\"logo\" src=\ |   box-sizing: border-box;\n            position:   |  <a class=\"nav-link dropdown-toggle\" href=\"#\"  |
# |        |      display: none; /* Hidden by default */\n      | "https://www.washington.edu/accesscomputing/AU/ima |  relative;\n        }\n\n        #carousel .slide  | id=\"admissionsDropdown\" role=\"button\" data-bs- |
# |        |   position: fixed;\n      top: 50%;\n      left:   | ges/au123456789.gif\" alt=\"Accessible University  |        img {\n            display: block;\n        |   toggle=\"dropdown\" aria-expanded=\"false\">\n   |
# |        |  50%;\n      transform: translate(-50%, -50%);\n   |       Logo\" width=\"441\" height=\"90\">\n        |     width: 100%;\n            height: auto;\n      |   Admissions\n                            </a>\n   |
# |        |  background-color: #fff;\n      padding: 20px;\n   |   <nav id=\"AU-menu\" aria-label=\"Primary site    |        }\n\n        #carousel .caption {\n         |         <ul class=\"dropdown-menu\" aria-          |
# |        |  border-radius: 5px;\n      box-shadow: 0 0 20px   |   menu\">\n                <ul class=\"nav\">\n    |  position: absolute;\n            bottom: 10px;\n  |        labelledby=\"admissionsDropdown\">\n        |
# |        |    rgba(0, 0, 0, 0.3);\n      z-index: 1001;\n     | <li class=\"nav-item\"><a class=\"nav-link\" href= | left: 10px;\n            background-color: rgba(0, | <li><a class=\"dropdown-item\" href=\"https://www. |
# |        |   max-width: 500px;\n      max-height: 80vh; /*    | \"https://www.washington.edu/accesscomputing/AU/in |      0, 0, 0.7);\n            color: #fff;\n       | washington.edu/accesscomputing/AU/somepage.html?re |
# |        |  Limit height */\n      overflow-y: auto; /* Add   | dex.html\">Home</a></li>\n                    <li  | padding: 5px 10px;\n        }\n\n        #carousel |     f=Undergraduate\">Undergraduate</a></li>\n     |
# |        |     scrolling if content overflows */\n    }\n     | class=\"nav-item\"><a class=\"nav-link active\" hr |         .lentils { /* Pagination dots */\n         | <li><a class=\"dropdown-item\" href=\"https://www. |
# |        |     .modalHeading {\n      font-size: 1.5em;\n     | ef=\"https://www.washington.edu/accesscomputing/AU |  position: absolute;\n            bottom: 10px;\n  | washington.edu/accesscomputing/AU/somepage.html?re |
# |        |   margin-bottom: 15px;\n      color: #005a9c; /*   |                /before.html\" aria-                |         left: 50%;\n            transform:         |          f=Graduate\">Graduate</a></li>\n          |
# |        |  Example heading color */\n    }\n    #modalClose  |         current=\"page\">Before</a></li>\n         | translateX(-50%);\n            list-style: none;\n | <li><a class=\"dropdown-item\" href=\"https://www. |
# |        |  {\n      position: absolute;\n      top: 10px;\n  | <li class=\"nav-item\"><a class=\"nav-link\" href= |       padding: 0;\n            margin: 0;\n        | washington.edu/accesscomputing/AU/somepage.html?re |
# |        |      right: 10px;\n      background: none;\n       | \"https://www.washington.edu/accesscomputing/AU/af |     display: flex;\n            z-index: 5;\n      |           f=Tuition\">Tuition</a></li>\n           |
# |        |      border: none;\n      font-size: 1.2em;\n      | ter.html\">After</a></li>\n                    <li |       }\n\n        #carousel .lentils li {\n       | <li><a class=\"dropdown-item\" href=\"https://www. |
# |        | font-weight: bold;\n      color: #333; /* Example  | class=\"nav-item\"><a class=\"nav-link\" href=\"ht |     width: 10px;\n            height: 10px;\n      | washington.edu/accesscomputing/AU/somepage.html?re |
# |        |   close button color */\n    }\n    #modalOk {\n   | tps://www.washington.edu/accesscomputing/AU/info.h |   background-color: rgba(255, 255, 255, 0.5);\n    |    f=Financial%20Aid\">Financial Aid</a></li>\n    |
# |        |     display: block;\n      margin-top: 20px;\n     |    tml\">Info</a></li>\n                </ul>\n    | border-radius: 50%;\n            margin: 0 5px;\n  |       </ul>\n                        </li>\n       |
# |        |    padding: 10px 20px;\n      background-color:    |     </nav>\n        </header>\n\n        <nav      |  cursor: pointer;\n        }\n\n        #carousel  |         <li class=\"nav-item dropdown\">\n         |
# |        | #005a9c; /* Example button color */\n      color:  |         class=\"secondary-nav mb-4\" aria-         |   .lentils li.active {\n            background-    |  <a class=\"nav-link dropdown-toggle\" href=\"#\"  |
# |        |      #fff; /* Example button text color */\n       |  label=\"Secondary site menu\">\n            <ul   |   color: #fff;\n        }\n\n\n        /* Table    |  id=\"visitorsDropdown\" role=\"button\" data-bs-  |
# |        |  border: none;\n      cursor: pointer;\n    }\n\n  |   class=\"nav nav-pills\">\n                <li    |  (from main.css) */\n        table#enrollment {\n  |   toggle=\"dropdown\" aria-expanded=\"false\">\n   |
# |        |  /* Carousel styles from before-carousel.css and   |           class=\"nav-item dropdown\">\n           |   border-collapse: collapse;\n            width:   |    Visitors\n                            </a>\n    |
# |        |       before-main.css */\n    #carousel {\n        |  <a class=\"nav-link dropdown-toggle\" href=\"#\"  |     100%;\n            margin-bottom: 20px;\n      |         <ul class=\"dropdown-menu\" aria-          |
# |        |     position: relative;\n      width: 100%;\n      |   id=\"aboutDropdown\" role=\"button\" data-bs-    |        }\n\n        table#enrollment th,\n         |         labelledby=\"visitorsDropdown\">\n         |
# |        |    max-width: 580px; /* Match image width */\n     |   toggle=\"dropdown\" aria-expanded=\"false\">\n   |   table#enrollment td {\n            border: 1px   | <li><a class=\"dropdown-item\" href=\"https://www. |
# |        |  margin: 0 auto;\n      overflow: hidden; /* Hide  |         About\n                    </a>\n          |      solid #ccc;\n            padding: 8px;\n      | washington.edu/accesscomputing/AU/somepage.html?re |
# |        |     extra slides */\n    }\n    #controls {\n      |         <ul class=\"dropdown-menu\" aria-          |          text-align: left;\n        }\n\n          |            f=Events\">Events</a></li>\n            |
# |        |       position: absolute;\n      top: 50%;\n       |          labelledby=\"aboutDropdown\">\n           |   table#enrollment th {\n            background-   | <li><a class=\"dropdown-item\" href=\"https://www. |
# |        | transform: translateY(-50%);\n      width: 100%;\n | <li><a class=\"dropdown-item\" href=\"https://www. | color: #f2f2f2;\n            font-weight: bold;\n  | washington.edu/accesscomputing/AU/somepage.html?re |
# |        |   display: flex;\n      justify-content: space-    | washington.edu/accesscomputing/AU/somepage.html?re |  }\n\n        table#enrollment caption { /* Added  |        f=Campus_Map\">Campus Map</a></li>\n        |
# |        |   between;\n      z-index: 5;\n      padding: 0    |              f=News\">News</a></li>\n              |   caption styling */\n            caption-side:    | <li><a class=\"dropdown-item\" href=\"https://www. |
# |        |   10px;\n      box-sizing: border-box;\n    }\n    | <li><a class=\"dropdown-item\" href=\"https://www. |       top;\n            text-align: left;\n        | washington.edu/accesscomputing/AU/somepage.html?re |
# |        |    #btn-prev, #btn-next {\n      width: 40px;\n    | washington.edu/accesscomputing/AU/somepage.html?re |   font-weight: bold;\n            margin-bottom:   |           f=Parking\">Parking</a></li>\n           |
# |        | height: 40px;\n      background-color: rgba(0, 0,  |        f=Governance\">Governance</a></li>\n        |     10px;\n        }\n\n        /* Video (from     |       </ul>\n                        </li>\n       |
# |        |    0, 0.5); /* Semi-transparent background */\n    | <li><a class=\"dropdown-item\" href=\"https://www. |  main.css) */\n        video {\n            max-   |          </ul>\n                </div>\n           |
# |        |     color: #fff; /* Arrow color - ensures good     | washington.edu/accesscomputing/AU/somepage.html?re |     width: 100%;\n            height: auto;\n      | </div>\n        </nav>\n    </header>\n\n    <main |
# |        |  contrast */\n      border: none;\n      border-   |         f=Diversity\">Diversity</a></li>\n         |   display: block;\n            margin: 20px 0;\n   |  id=\"main-content\" class=\"container mt-4\">\n   |
# |        | radius: 50%;\n      font-size: 1.5em;\n      line- | <li><a class=\"dropdown-item\" href=\"https://www. |  }\n\n        /* Form (from before-form.css) */\n  | <div class=\"row\">\n            <div class=\"col- |
# |        |     height: 40px;\n      text-align: center;\n     | washington.edu/accesscomputing/AU/somepage.html?re |     aside[role=\"aside\"] h2 { /* Changed from     |   md-8\">\n                <div id=\"carousel\"    |
# |        |       cursor: pointer;\n      padding: 0;\n        |       f=Contact%20Us\">Contact Us</a></li>\n       | .heading */\n             margin-top: 0; /* Adjust |       class=\"carousel slide mb-4\" data-bs-       |
# |        |   display: flex; /* Use flex for centering */\n    | </ul>\n                </li>\n                <li  |    margin for sidebar heading */\n        }\n\n    |    ride=\"carousel\">\n                    <div    |
# |        |    justify-content: center;\n      align-items:    |           class=\"nav-item dropdown\">\n           |         aside[role=\"aside\"] form div {\n         |            class=\"carousel-inner\">\n             |
# |        |  center;\n    }\n    #btn-prev::before { content:  |  <a class=\"nav-link dropdown-toggle\" href=\"#\"  |        margin-bottom: 15px;\n        }\n\n         |       <div class=\"carousel-item active\">\n       |
# |        | '<'; }\n    #btn-next::before { content: '>'; }\n  | id=\"academicsDropdown\" role=\"button\" data-bs-  |    aside[role=\"aside\"] label { /* Added label    | <img src=\"https://www.washington.edu/accesscomput |
# |        | #slides {\n      display: flex;\n      transition: |   toggle=\"dropdown\" aria-expanded=\"false\">\n   |     styling */\n            display: block;\n      |        ing/AU/images/carousel/slide1.jpg\"         |
# |        | transform 0.5s ease-in-out;\n    }\n    .slide {\n |       Academics\n                    </a>\n        |   margin-bottom: 5px;\n            font-weight:    | class=\"d-block w-100\" alt=\"A modern school\">\n |
# |        |   min-width: 100%;\n      position: relative;\n    |         <ul class=\"dropdown-menu\" aria-          | bold;\n        }\n\n        aside[role=\"aside\"]  |     <div class=\"carousel-caption d-none d-md-     |
# |        |    }\n    .slide img {\n      display: block;\n    |        labelledby=\"academicsDropdown\">\n         |              input[type=\"text\"],\n               |  block\">\n                                <h5>A   |
# |        |     width: 100%;\n      height: auto;\n    }\n     | <li><a class=\"dropdown-item\" href=\"https://www. |  aside[role=\"aside\"] input[type=\"email\"] { /*  |                modern school</h5>\n                |
# |        |      .caption {\n      position: absolute;\n       | washington.edu/accesscomputing/AU/somepage.html?re | Added email type */\n            width: calc(100%  |      </div>\n                        </div>\n      |
# |        |  bottom: 0;\n      left: 0;\n      width: 100%;\n  |  f=Degree%20Programs\">Degree Programs</a></li>\n  |     - 18px); /* Adjust for padding/border */\n     |          <div class=\"carousel-item\">\n           |
# |        |   background-color: rgba(0, 0, 0, 0.6); /* Semi-   | <li><a class=\"dropdown-item\" href=\"https://www. |    padding: 8px;\n            border: 1px solid    | <img src=\"https://www.washington.edu/accesscomput |
# |        |  transparent background */\n      color: #fff; /*  | washington.edu/accesscomputing/AU/somepage.html?re |   #ccc;\n        }\n\n        /* Required fields   |        ing/AU/images/carousel/slide2.jpg\"         |
# |        |  Caption text color - ensures good contrast */\n   |       f=AU%20Faculty\">AU Faculty</a></li>\n       | */\n        aside[role=\"aside\"] .required label  |    class=\"d-block w-100\" alt=\"Rooted in its     |
# ...
# |        |                                                    |                                                    |       <li>Insufficient color contrast</li>\n       |                                                    |
# |        |                                                    |                                                    |  <li>Color used to communicate information</li>\n  |                                                    |
# |        |                                                    |                                                    |   <!-- Keyboard-->\n            <li>Inaccessible   |                                                    |
# |        |                                                    |                                                    |    keyboard interface</li>\n            <li>No     |                                                    |
# |        |                                                    |                                                    |         visible indication of focus</li>\n         |                                                    |
# |        |                                                    |                                                    |    <li>No \"skip to main content\" link</li>\n     |                                                    |
# |        |                                                    |                                                    |     <!-- Links-->\n            <li>Redundant,      |                                                    |
# |        |                                                    |                                                    |           uninformative link text</li>\n           |                                                    |
# |        |                                                    |                                                    |    <li>Links vs buttons</li>\n            <!--     |                                                    |
# |        |                                                    |                                                    |     Features -->\n            <li>Inaccessible     |                                                    |
# |        |                                                    |                                                    | navigation menu</li>\n            <li>Inaccessible |                                                    |
# |        |                                                    |                                                    | carousel</li>\n            <li>Inaccessible modal  |                                                    |
# |        |                                                    |                                                    |     dialog</li>\n            <!-- Forms -->\n      |                                                    |
# |        |                                                    |                                                    |        <li>Form not properly labeled</li>\n        |                                                    |
# |        |                                                    |                                                    |          <li>Inaccessible CAPTCHA</li>\n           |                                                    |
# |        |                                                    |                                                    |      <li>Inaccessible input validation</li>\n      |                                                    |
# |        |                                                    |                                                    |      <!-- Tables -->\n            <li>Missing      |                                                    |
# |        |                                                    |                                                    |           accessible table markup</li>\n           |                                                    |
# |        |                                                    |                                                    |        <li>Missing abbreviation tags</li>\n        |                                                    |
# |        |                                                    |                                                    | <!-- Video -->\n            <li>Inaccessible audio |                                                    |
# |        |                                                    |                                                    |              content in video</li>\n               |                                                    |
# |        |                                                    |                                                    |  <li>Inaccessible visual content in video</li>\n   |                                                    |
# |        |                                                    |                                                    |       </ol>\n        <button type=\"button\"       |                                                    |
# |        |                                                    |                                                    |            id=\"modalOk\">OK</button>\n            |                                                    |
# |        |                                                    |                                                    |            </div>\n\n</body>\n</html>",            |                                                    |
# |        |                                                    |                                                    |    "Procedure": "1. Added `lang=\"en\"` attribute  |                                                    |
# |        |                                                    |                                                    |   to the `<html>` tag.\n2. Implemented semantic    |                                                    |
# |        |                                                    |                                                    |     HTML5 structure using `<header>`, `<nav>`,     |                                                    |
# |        |                                                    |                                                    |  `<main>`, `<aside>`, and `<footer>`.\n3. Added a  |                                                    |
# |        |                                                    |                                                    |  visually hidden `<h1>` element for the main page  |                                                    |
# |        |                                                    |                                                    |   title.\n4. Converted `div` elements with class   |                                                    |
# |        |                                                    |                                                    |  `heading` to appropriate `<h2>` tags for proper   |                                                    |
# |        |                                                    |                                                    | heading hierarchy.\n5. Provided descriptive `alt`  |                                                    |
# |        |                                                    |                                                    |  text for informative images and empty `alt=\"\"`  |                                                    |
# |        |                                                    |                                                    | for decorative images.\n6. Converted all relative  |                                                    |
# |        |                                                    |                                                    |   image, script, and video URLs to absolute URLs   |                                                    |
# |        |                                                    |                                                    |  based on the root URL.\n7. Inlined all external   |                                                    |
# |        |                                                    |                                                    |   CSS files into a single `<style>` block in the   |                                                    |
# |        |                                                    |                                                    |  `<head>` section.\n8. Adjusted link and required  |                                                    |
# |        |                                                    |                                                    | field text colors in the inlined CSS to meet WCAG  |                                                    |
# |        |                                                    |                                                    | AA color contrast requirements (4.5:1).\n9. Added  |                                                    |
# |        |                                                    |                                                    |     non-color indicators (asterisk and `aria-      |                                                    |
# |        |                                                    |                                                    | required=\"true\"`) for required form fields.\n10. |                                                    |
# |        |                                                    |                                                    |   Implemented `<label>` elements associated with   |                                                    |
# |        |                                                    |                                                    |    form inputs using the `for` attribute.\n11.     |                                                    |
# |        |                                                    |                                                    | Grouped related checkboxes using `<fieldset>` and  |                                                    |
# |        |                                                    |                                                    | `<legend>` elements.\n12. Added a note explaining  |                                                    |
# |        |                                                    |                                                    |    the inaccessibility of the image CAPTCHA and    |                                                    |
# |        |                                                    |                                                    |   suggesting accessible alternatives.\n13. Added   |                                                    |
# |        |                                                    |                                                    |    proper table markup (`<caption>`, `<thead>`,    |                                                    |
# |        |                                                    |                                                    |      `<th>` with `scope`) for the enrollment       |                                                    |
# |        |                                                    |                                                    |  table.\n14. Added placeholder `<track>` elements  |                                                    |
# |        |                                                    |                                                    |  for video captions and included a note about the  |                                                    |
# |        |                                                    |                                                    |   need for transcripts/audio descriptions.\n15.    |                                                    |
# |        |                                                    |                                                    |    Added a \"Skip to main content\" link at the    |                                                    |
# |        |                                                    |                                                    |   beginning of the body for keyboard users.\n16.   |                                                    |
# |        |                                                    |                                                    | Added basic focus styles (`:focus` outline) in the |                                                    |
# |        |                                                    |                                                    |  inlined CSS to make keyboard focus visible.\n17.  |                                                    |
# |        |                                                    |                                                    |          Added ARIA roles and attributes           |                                                    |
# |        |                                                    |                                                    |      (`role=\"navigation\"`, `role=\"main\"`,      |                                                    |
# |        |                                                    |                                                    | `role=\"aside\"`, `role=\"dialog\"`, `aria-label`, |                                                    |
# |        |                                                    |                                                    | `aria-labelledby`, `aria-modal`, `aria-required`)  |                                                    |
# |        |                                                    |                                                    |       to improve understanding for assistive       |                                                    |
# |        |                                                    |                                                    |  technologies.\n18. Added an `sr-only` CSS class   |                                                    |
# |        |                                                    |                                                    |  for visually hiding elements while keeping them   |                                                    |
# |        |                                                    |                                                    | available to screen readers.\n19. Changed carousel |                                                    |
# |        |                                                    |                                                    | navigation and modal close elements from `div` to  |                                                    |
# |        |                                                    |                                                    |       `button` with appropriate `aria-label`       |                                                    |
# |        |                                                    |                                                    |                    attributes."                    |                                                    |
# |        |                                                    |                                                    |                         }                          |                                                    |
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+

# %%
extracted_json_html = json.loads(extracted_html)
extracted_json_html_template = json.loads(extracted_html_template)
extracted_json_md = json.loads(extracted_md)
extracted_json_md_template = json.loads(extracted_md_template)

# %%
create_interface(extracted_json_html, extracted_json_html_template, extracted_json_md, extracted_json_md_template)

# %%
generate_output_files("gemini-site1", extracted_json_html, extracted_json_html_template, extracted_json_md, extracted_json_md_template)

# %% [markdown]
# ## GPT-4o: Duke University Site
#
# Let’s examine the result produced by this model.

# %%
extracted_html, extracted_html_template, extracted_md, extracted_md_template = display_extracted_content("gpt-4o", all_content_html, all_content_md, "Crawl4ai", site_name="Site 2", template="blocks")
# Out:
# Processing results:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for HTML input:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for HTML input and template:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for Markdown input:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for Markdown input and template:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracted Content Table:
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# |  Site  |                     From HTML                      |              From HTML with template               |                   From markdown                    |            From markdown with template             |
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# | Site 2 |              Completion tokens: 5,344              |              Completion tokens: 3,493              |              Completion tokens: 5,167              |              Completion tokens: 3,081              |
# |        |                Prompt tokens: 4,475                |                Prompt tokens: 7,404                |                Prompt tokens: 4,528                |                Prompt tokens: 7,399                |
# |        |               Total cost: $0.024547                |               Total cost: $0.027243                |               Total cost: $0.024238                |               Total cost: $0.026200                |
# |        |                                                    |                                                    |                                                    |                                                    |
# |        |                                                    |                                                    |                                                    |                                                    |
# |        |                         {                          |                         {                          |                         {                          |                         {                          |
# |        |            "HTML": "<!DOCTYPE html>\n<html         |             "HTML": "<!DOCTYPE html><html          |            "HTML": "<!DOCTYPE html>\n<html         |             "HTML": "<!DOCTYPE html><html          |
# |        |          lang=\"en\">\n<head>\n    <meta           |   lang=\"en\"><head>    <meta charset=\"UTF-8\">   |          lang=\"en\">\n<head>\n    <meta           |   lang=\"en\"><head>    <meta charset=\"UTF-8\">   |
# |        |  charset=\"utf-8\">\n    <meta name=\"viewport\"   |  <meta name=\"viewport\" content=\"width=device-   |  charset=\"utf-8\">\n    <meta name=\"viewport\"   |  <meta name=\"viewport\" content=\"width=device-   |
# |        |   content=\"width=device-width, initial-scale=1,   |   width, initial-scale=1\">    <title>Accessible   |   content=\"width=device-width, initial-scale=1,   |   width, initial-scale=1\">    <title>Accessible   |
# |        |      user-scalable=no\">\n    <title>Before -      | University Demo Site</title>    <link href=\"https |     user-scalable=no\">\n    <title>Accessible     | University Demo Site</title>    <link href=\"https |
# |        |   Accessible University Demo Site - Inaccessible   | ://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/css/b |         University Demo Site - Accessible          | ://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/css/b |
# |        | Version</title>\n    <script src=\"https://code.jq | ootstrap.min.css\" rel=\"stylesheet\">    <style>  | Version</title>\n    <link rel=\"icon\" href=\"htt | ootstrap.min.css\" rel=\"stylesheet\">    <style>  |
# |        | uery.com/jquery-3.3.1.slim.min.js\" integrity=\"sh |     .sr-only {            position: absolute;      | ps://openassessittoolkit.github.io/accessible_u/im |     .sr-only {            position: absolute;      |
# |        |                       a384-                        |        width: 1px;            height: 1px;         |    ages/favicon.ico\" type=\"image/x-icon\">\n     |        width: 1px;            height: 1px;         |
# |        | q8i/X+965DzO0rT7abK41JStQIAqVgRVzpbzo5smXKp4YfRvH+ |        padding: 0;            margin: -1px;        | <style>\n        body { font-family: Arial, sans-  |        padding: 0;            margin: -1px;        |
# |        |                  8abtTE1Pi6jizo\"                  |  overflow: hidden;            clip: rect(0, 0, 0,  |  serif; }\n        .sr-only { position: absolute;  |  overflow: hidden;            clip: rect(0, 0, 0,  |
# |        |   crossorigin=\"anonymous\"></script>\n    <link   |         0);            border: 0;        }         | width: 1px; height: 1px; padding: 0; margin: -1px; |         0);            border: 0;        }         |
# |        | rel=\"icon\" href=\"https://openassessittoolkit.gi | .carousel-item img {            max-height: 470px; | overflow: hidden; clip: rect(0, 0, 0, 0); border:  | .carousel-item img {            max-height: 470px; |
# |        |     thub.io/accessible_u/images/favicon.ico\"      |  object-fit: cover;        }        .navbar-dark   | 0; }\n        .navbar { background-color: #004080; |   object-fit: cover;        }        .navbar-nav   |
# |        |  type=\"image/x-icon\">\n    <style>\n        /*   |     .navbar-nav .nav-link {            color:      | }\n        .navbar-nav .nav-link { color: #ffffff; |  .nav-link.active {            background-color:   |
# |        | Inline styles for accessibility improvements */\n  | rgba(255, 255, 255, 0.9);        }        .navbar- |    }\n        .btn-success { background-color:     |     #0056b3;            color: white;        }     |
# |        |    body { font-family: Arial, sans-serif; line-    |   dark .navbar-nav .nav-link:hover, .navbar-dark   | #28a745; color: #ffffff; }\n        .btn-primary { |    .btn-primary {            background-color:     |
# |        |    height: 1.6; }\n        .sr-only { position:    |  .navbar-nav .nav-link:focus {            color:   |   background-color: #007bff; color: #ffffff; }\n   |     #0056b3;            border-color: #0056b3;     |
# |        |   absolute; width: 1px; height: 1px; padding: 0;   |  rgba(255, 255, 255, 0.75);        }        .btn-  |   .form-control { border: 1px solid #ced4da; }\n   |           }        .btn-primary:hover {            |
# |        |       margin: -1px; overflow: hidden; clip:        |  primary {            background-color: #007bff;   |  .heading { font-size: 1.5em; font-weight: bold;   |   background-color: #004494;            border-    |
# |        | rect(0,0,0,0); border: 0; }\n        .navbar-dark  |    border-color: #007bff;        }        .btn-    | margin-top: 1em; }\n        .table { width: 100%;  | color: #004494;        }    </style></head><body>  |
# |        |      .navbar-nav .nav-link { color: #fff; }\n      |        primary:hover, .btn-primary:focus {         |  border-collapse: collapse; }\n        .table th,  |  <nav class=\"navbar navbar-expand-lg navbar-dark  |
# |        | .btn-primary { background-color: #0056b3; border-  |   background-color: #0056b3;            border-    | .table td { border: 1px solid #ddd; padding: 8px;  | bg-dark\">        <div class=\"container-fluid\">  |
# |        |  color: #004085; }\n        .btn-primary:hover {   | color: #0056b3;        }    </style></head><body>  | }\n        .table th { background-color: #f2f2f2;  |  <a class=\"navbar-brand\" href=\"#\">Accessible   |
# |        | background-color: #004085; border-color: #003366;  |  <nav class=\"navbar navbar-expand-lg navbar-dark  | text-align: left; }\n    </style>\n    <script src | University</a>            <button class=\"navbar-  |
# |        |    }\n        .btn-success { background-color:     | bg-dark\">        <div class=\"container-fluid\">  |         =\"https://code.jquery.com/jquery-         |         toggler\" type=\"button\" data-bs-         |
# |        |  #28a745; border-color: #218838; }\n        .btn-  |  <a class=\"navbar-brand\" href=\"#\">Accessible   |      3.3.1.slim.min.js\" integrity=\"sha384-       | toggle=\"collapse\" data-bs-target=\"#navbarNav\"  |
# |        | success:hover { background-color: #218838; border- | University</a>            <button class=\"navbar-  | q8i/X+965DzO0rT7abK41JStQIAqVgRVzpbzo5smXKp4YfRvH+ |         aria-controls=\"navbarNav\" aria-          |
# |        | color: #1e7e34; }\n        .form-control { border: |         toggler\" type=\"button\" data-bs-         |                  8abtTE1Pi6jizo\"                  |       expanded=\"false\" aria-label=\"Toggle       |
# |        | 1px solid #ced4da; }\n        .form-control:focus  | toggle=\"collapse\" data-bs-target=\"#navbarNav\"  | crossorigin=\"anonymous\"></script>\n    <script s | navigation\">                <span class=\"navbar- |
# |        | { border-color: #80bdff; outline: 0; box-shadow: 0 |         aria-controls=\"navbarNav\" aria-          | rc=\"https://openassessittoolkit.github.io/accessi |    toggler-icon\"></span>            </button>     |
# |        |        0 0 0.2rem rgba(0,123,255,.25); }\n         |       expanded=\"false\" aria-label=\"Toggle       |     ble_u/scripts/before-menu.js\"></script>\n     |      <div class=\"collapse navbar-collapse\"       |
# |        |  .heading { font-size: 1.5em; font-weight: bold;   | navigation\">                <span class=\"navbar- | <script src=\"https://openassessittoolkit.github.i |        id=\"navbarNav\">                <ul        |
# |        | margin-top: 1em; }\n        .table th, .table td { |    toggler-icon\"></span>            </button>     |           o/accessible_u/scripts/before-           |    class=\"navbar-nav\">                    <li    |
# |        | padding: 0.75rem; vertical-align: top; border-top: |      <div class=\"collapse navbar-collapse\"       | form.js\"></script>\n    <script src=\"https://ope |   class=\"nav-item\">                        <a    |
# |        |  1px solid #dee2e6; }\n        .table thead th {   |        id=\"navbarNav\">                <ul        | nassessittoolkit.github.io/accessible_u/scripts/be |  class=\"nav-link active\" aria-current=\"page\"   |
# |        |  vertical-align: bottom; border-bottom: 2px solid  |    class=\"navbar-nav\">                    <li    | fore-modal.js\"></script>\n    <script src=\"https |    href=\"#\">Home</a>                    </li>    |
# |        | #dee2e6; }\n        .table tbody + tbody { border- |   class=\"nav-item\">                        <a    | ://openassessittoolkit.github.io/accessible_u/scri | <li class=\"nav-item\">                        <a  |
# |        | top: 2px solid #dee2e6; }\n        .table .table { |  class=\"nav-link active\" aria-current=\"page\"   | pts/before-hero.js\"></script>\n</head>\n<body>\n  |      class=\"nav-link\" href=\"#\">About</a>       |
# |        |     background-color: #fff; }\n    </style>\n      |    href=\"#\">Home</a>                    </li>    |        <header>\n        <div id=\"banner\"        |  </li>                    <li class=\"nav-item\">  |
# |        | <script src=\"https://openassessittoolkit.github.i | <li class=\"nav-item\">                        <a  |  class=\"container clearfix\">\n            <nav   |   <a class=\"nav-link\" href=\"#\">Academics</a>   |
# |        |           o/accessible_u/scripts/before-           |      class=\"nav-link\" href=\"#\">About</a>       |  aria-label=\"version\" class=\"float-right\">\n   |  </li>                    <li class=\"nav-item\">  |
# |        | menu.js\"></script>\n    <script src=\"https://ope |  </li>                    <li class=\"nav-item\">  |   <span class=\"float-left\">Examples:</span>\n    |  <a class=\"nav-link\" href=\"#\">Admissions</a>   |
# |        | nassessittoolkit.github.io/accessible_u/scripts/be |   <a class=\"nav-link\" href=\"#\">Academics</a>   |     <ul class=\"utility-menu float-left list-      |  </li>                    <li class=\"nav-item\">  |
# |        | fore-form.js\"></script>\n    <script src=\"https: |  </li>                    <li class=\"nav-item\">  | unstyled\">\n                    <li><a href=\"htt |   <a class=\"nav-link\" href=\"#\">Visitors</a>    |
# |        | //openassessittoolkit.github.io/accessible_u/scrip |  <a class=\"nav-link\" href=\"#\">Admissions</a>   | ps://openassessittoolkit.github.io/accessible_u/be |  </li>                </ul>                <form   |
# |        | ts/before-modal.js\"></script>\n    <script src=\" |  </li>                    <li class=\"nav-item\">  |     fore_u.html\" aria-current=\"page\" aria-      |     class=\"d-flex ms-auto\" role=\"search\">      |
# |        | https://openassessittoolkit.github.io/accessible_u |   <a class=\"nav-link\" href=\"#\">Visitors</a>    |            label=\"before version with             | <input class=\"form-control me-2\" type=\"search\" |
# |        |                  /scripts/before-                  |  </li>                </ul>                <form   |            problems\">Before</a></li>\n            |   placeholder=\"Search\" aria-label=\"Search\">    |
# |        |    hero.js\"></script>\n</head>\n<body>\n    <a    |     class=\"d-flex ms-auto\" role=\"search\">      | <li><a href=\"https://openassessittoolkit.github.i |     <button class=\"btn btn-outline-success\"      |
# |        |   href=\"#main\" class=\"sr-only\">Skip to main    | <input class=\"form-control me-2\" type=\"search\" |  o/accessible_u/after_u.html\" aria-label=\"after  |          type=\"submit\">Search</button>           |
# |        |       content</a>\n    <header id=\"banner\"       |   placeholder=\"Search\" aria-label=\"Search\">    |       version with fixes\">After</a></li>\n        | </form>            </div>        </div>    </nav>  |
# |        | class=\"container clearfix\">\n        <nav aria-  |     <button class=\"btn btn-outline-success\"      |     </ul>\n            </nav>\n            <a      | <main class=\"container mt-4\">        <h1>Welcome |
# |        |     label=\"version\" class=\"float-right\">\n     |          type=\"submit\">Search</button>           |         class=\"logo-link\" href=\"/\">\n          |     to Accessible University</h1>        <div      |
# |        |   <span class=\"float-left\">Examples:</span>\n    | </form>            </div>        </div>    </nav>  | <img id=\"logo\" src=\"https://openassessittoolkit |  id=\"carouselExample\" class=\"carousel slide\"   |
# |        |     <ul class=\"utility-menu float-left list-      | <main class=\"container mt-4\">        <h1>Welcome |  .github.io/accessible_u/images/8675309-l-o-g-o-   |     data-bs-ride=\"carousel\">            <div     |
# |        | unstyled\">\n                <li><a href=\"https:/ |     to Accessible University</h1>        <div      |     before.png\" width=\"950\" height=\"230\"      |   class=\"carousel-inner\">                <div    |
# |        | /openassessittoolkit.github.io/accessible_u/before |  id=\"carouselExample\" class=\"carousel slide\"   |       alt=\"Accessible University Logo\">\n        |          class=\"carousel-item active\">           |
# |        |       _u.html\" aria-current=\"page\" aria-        |     data-bs-ride=\"carousel\">            <div     |   </a>\n        </div>\n    </header>\n    <nav    | <img src=\"https://openassessittoolkit.github.io/a |
# |        |            label=\"before version with             |   class=\"carousel-inner\">                <div    |  class=\"navbar navbar-expand-lg navbar-dark\">\n  | ccessible_u/images/8675309-before_brass_band.jpg\" |
# |        | problems\">Before</a></li>\n                <li><a |          class=\"carousel-item active\">           |   <div class=\"container\">\n            <button   |      class=\"d-block w-100\" alt=\"Brass band      |
# |        | href=\"https://openassessittoolkit.github.io/acces | <img src=\"https://openassessittoolkit.github.io/a |   class=\"navbar-toggler\" type=\"button\" data-   |        performance\">                </div>        |
# |        | sible_u/after_u.html\" aria-label=\"after version  | ccessible_u/images/8675309-before_brass_band.jpg\" |             toggle=\"collapse\" data-              |           <div class=\"carousel-item\">            |
# |        |  with fixes\">After</a></li>\n            </ul>\n  |      class=\"d-block w-100\" alt=\"Brass band      |       target=\"#navbarSupportedContent\">\n        | <img src=\"https://openassessittoolkit.github.io/a |
# |        |       </nav>\n        <a class=\"logo-link\"       |        performance\">                </div>        |   <span class=\"navbar-toggler-icon\"></span>\n    |            ccessible_u/images/8675309-             |
# |        | href=\"/\">\n            <img id=\"logo\" src=\"ht |           <div class=\"carousel-item\">            |    </button>\n            <div class=\"collapse    |    before_articulated_bus.jpg\" class=\"d-block    |
# |        | tps://openassessittoolkit.github.io/accessible_u/i | <img src=\"https://openassessittoolkit.github.io/a | navbar-collapse\" id=\"navbarSupportedContent\">\n |          w-100\" alt=\"Articulated bus\">          |
# |        |  mages/8675309-l-o-g-o-before.png\" width=\"950\"  |            ccessible_u/images/8675309-             |        <ul class=\"navbar-nav mr-auto\">\n         |    </div>                <div class=\"carousel-    |
# |        |     height=\"230\" alt=\"Accessible University     |    before_articulated_bus.jpg\" class=\"d-block    |          <li class=\"nav-item active\">\n          | item\">                    <img src=\"https://open |
# |        |  Logo\">\n        </a>\n    </header>\n\n    <nav  |          w-100\" alt=\"Articulated bus\">          |    <a class=\"nav-link\" href=\"#\">Home</a>\n     | assessittoolkit.github.io/accessible_u/images/8675 |
# |        |  class=\"navbar navbar-expand-lg navbar-dark bg-   |    </div>                <div class=\"carousel-    |  </li>\n                    <li class=\"nav-item   |   309-before_construction.jpg\" class=\"d-block    |
# |        |       dark bg-primary md-3\">\n        <div        | item\">                    <img src=\"https://open |      dropdown\">\n                        <a       |         w-100\" alt=\"Construction site\">         |
# |        |     class=\"container\">\n            <button      | assessittoolkit.github.io/accessible_u/images/8675 |   class=\"nav-link dropdown-toggle\" href=\"#\"    |    </div>            </div>            <button     |
# |        |   class=\"navbar-toggler\" type=\"button\" data-   |   309-before_construction.jpg\" class=\"d-block    |        data-toggle=\"dropdown\">About</a>\n        |  class=\"carousel-control-prev\" type=\"button\"   |
# |        |             toggle=\"collapse\" data-              |         w-100\" alt=\"Construction site\">         |           <ul class=\"dropdown-menu\">\n           |    data-bs-target=\"#carouselExample\" data-bs-    |
# |        |      target=\"#navbarSupportedContent\" aria-      |    </div>            </div>            <button     |           <li><a class=\"dropdown-item\"           |        slide=\"prev\">                <span        |
# |        |     controls=\"navbarSupportedContent\" aria-      |  class=\"carousel-control-prev\" type=\"button\"   |             href=\"#\">News</a></li>\n             |     class=\"carousel-control-prev-icon\" aria-     |
# |        |       expanded=\"false\" aria-label=\"Toggle       |    data-bs-target=\"#carouselExample\" data-bs-    |           <li><a class=\"dropdown-item\"           |    hidden=\"true\"></span>                <span    |
# |        |        navigation\">\n                <span        |        slide=\"prev\">                <span        |          href=\"#\">Governance</a></li>\n          |     class=\"visually-hidden\">Previous</span>      |
# |        |      class=\"navbar-toggler-icon\"></span>\n       |     class=\"carousel-control-prev-icon\" aria-     |           <li><a class=\"dropdown-item\"           |   </button>            <button class=\"carousel-   |
# |        |   </button>\n\n            <div class=\"collapse   |    hidden=\"true\"></span>                <span    |          href=\"#\">Diversity</a></li>\n           |      control-next\" type=\"button\" data-bs-       |
# |        | navbar-collapse\" id=\"navbarSupportedContent\">\n |     class=\"visually-hidden\">Previous</span>      | <li><a class=\"dropdown-item\" href=\"#\">Contact  |        target=\"#carouselExample\" data-bs-        |
# |        |        <ul class=\"navbar-nav mr-auto\">\n         |   </button>            <button class=\"carousel-   |    Us</a></li>\n                        </ul>\n    |        slide=\"next\">                <span        |
# |        |          <li class=\"nav-item active\">\n          |      control-next\" type=\"button\" data-bs-       |  </li>\n                    <li class=\"nav-item   |     class=\"carousel-control-next-icon\" aria-     |
# |        |    <a class=\"nav-link\" href=\"#\">Home</a>\n     |        target=\"#carouselExample\" data-bs-        |      dropdown\">\n                        <a       |    hidden=\"true\"></span>                <span    |
# |        |  </li>\n                    <li class=\"nav-item   |        slide=\"next\">                <span        |   class=\"nav-link dropdown-toggle\" href=\"#\"    |       class=\"visually-hidden\">Next</span>        |
# |        |      dropdown\">\n                        <a       |     class=\"carousel-control-next-icon\" aria-     |      data-toggle=\"dropdown\">Academics</a>\n      |      </button>        </div>        <section       |
# |        |   class=\"nav-link dropdown-toggle\" href=\"#\"    |    hidden=\"true\"></span>                <span    |           <ul class=\"dropdown-menu\">\n           |  class=\"mt-4\">            <h2>About Accessible   |
# |        |   id=\"aboutDropdown\" data-toggle=\"dropdown\"    |       class=\"visually-hidden\">Next</span>        |  <li><a class=\"dropdown-item\" href=\"#\">Degree  |      University</h2>            <p>Accessible      |
# |        | aria-haspopup=\"true\" aria-expanded=\"false\">\n  |      </button>        </div>        <section       |                Programs</a></li>\n                 |              University (AU) is a <a               |
# |        |       About\n                        </a>\n        |    class=\"mt-4\">            <h2>Welcome!</h2>    |    <li><a class=\"dropdown-item\" href=\"#\">AU    |            href=\"https://www.merriam-             |
# |        |         <ul class=\"dropdown-menu\" aria-          |       <p>Accessible University (AU) is a <a        |                 Faculty</a></li>\n                 |  webster.com/dictionary/fictional\">fictional</a>  |
# |        |          labelledby=\"aboutDropdown\">\n           |            href=\"https://www.merriam-             | <li><a class=\"dropdown-item\" href=\"#\">Distance | <a href=\"https://en.wikipedia.org/wiki/University |
# |        |           <li><a class=\"dropdown-item\"           |  webster.com/dictionary/fictional\">fictional</a>  |                Learning</a></li>\n                 | \">university</a>, and this is its fictional home  |
# |        |             href=\"#\">News</a></li>\n             | <a href=\"https://en.wikipedia.org/wiki/University |           <li><a class=\"dropdown-item\"           |    page. This page is designed to demonstrate a    |
# |        |           <li><a class=\"dropdown-item\"           | \">university</a>, and this is its fictional home  |          href=\"#\">Libraries</a></li>\n           |          variety of common web design <a           |
# |        |          href=\"#\">Governance</a></li>\n          |    page. This page is designed to demonstrate a    |         </ul>\n                    </li>\n         |            href=\"https://www.merriam-             |
# |        |           <li><a class=\"dropdown-item\"           |          variety of common web design <a           |         <li class=\"nav-item dropdown\">\n         |   webster.com/dictionary/problems\">problems</a>   |
# |        |          href=\"#\">Diversity</a></li>\n           |            href=\"https://www.merriam-             |  <a class=\"nav-link dropdown-toggle\" href=\"#\"  |  that result in visitors with disabilities being   |
# |        | <li><a class=\"dropdown-item\" href=\"#\">Contact  |   webster.com/dictionary/problems\">problems</a>   |     data-toggle=\"dropdown\">Admissions</a>\n      | unable to access the content or features of a web  |
# |        |    Us</a></li>\n                        </ul>\n    |  that result in visitors with disabilities being   |           <ul class=\"dropdown-menu\">\n           |   page. Although the heading at the top of this    |
# |        |  </li>\n                    <li class=\"nav-item   | unable to access the content or features of a web  |           <li><a class=\"dropdown-item\"           |   section of the page suggests that AU may be a    |
# |        |      dropdown\">\n                        <a       |   page. Although the heading at the top of this    |        href=\"#\">Undergraduate</a></li>\n         | welcoming institution, the inaccessible design of  |
# |        |   class=\"nav-link dropdown-toggle\" href=\"#\"    |   section of the page suggests that AU may be a    |           <li><a class=\"dropdown-item\"           |     this page sends the opposite message.</p>      |
# |        | id=\"academicsDropdown\" data-toggle=\"dropdown\"  | welcoming institution, the inaccessible design of  |           href=\"#\">Graduate</a></li>\n           |     </section>        <section class=\"mt-4\">     |
# |        | aria-haspopup=\"true\" aria-expanded=\"false\">\n  |     this page sends the opposite message.</p>      |           <li><a class=\"dropdown-item\"           |  <h2>AU Enrollment Trends</h2>            <table   |
# |        |     Academics\n                        </a>\n      |    <h2>Bienvenido!</h2>            <p>Accesible    |           href=\"#\">Tuition</a></li>\n            |          class=\"table table-bordered\">           |
# |        |         <ul class=\"dropdown-menu\" aria-          |  Universidad (UA) es una universidad ficticia, y   |           <li><a class=\"dropdown-item\"           |          <thead>                    <tr>           |
# |        |        labelledby=\"academicsDropdown\">\n         |   esta es su página de ficción. Esta página está   |        href=\"#\">Financial Aid</a></li>\n         |           <th scope=\"col\">&nbsp;</th>            |
# |        |  <li><a class=\"dropdown-item\" href=\"#\">Degree  |  diseñada para demostrar una variedad de común de  |         </ul>\n                    </li>\n         |   <th scope=\"col\" colspan=\"5\" class=\"text-    |
# |        |                Programs</a></li>\n                 |   diseño web que se traducen en problemas de los   |             <li class=\"nav-item\">\n              | center\">Last year</th>                        <th |
# |        |    <li><a class=\"dropdown-item\" href=\"#\">AU    |  visitantes con discapacidad no poder acceder al   |  <a class=\"nav-link\" href=\"#\">Visitors</a>\n   |     scope=\"col\" colspan=\"5\" class=\"text-      |
# |        |                 Faculty</a></li>\n                 | contenido o las características de una página web. |           </li>\n                </ul>\n           |  center\">This year</th>                    </tr>  |
# |        | <li><a class=\"dropdown-item\" href=\"#\">Distance |   Aunque el título en la parte superior de esta    |      <form class=\"form-inline my-2 my-lg-0\"      |          <tr>                        <th           |
# |        |                Learning</a></li>\n                 | sección de la página sugiere que AU puede ser una  |    role=\"search\">\n                    <label    |             scope=\"col\">&nbsp;</th>              |
# |        |           <li><a class=\"dropdown-item\"           |  institución de bienvenida, el diseño inaccesible  |          for=\"search-input\" class=\"sr-          |             <th scope=\"col\">CS</th>              |
# |        |          href=\"#\">Libraries</a></li>\n           |    de esta página envía el mensaje opuesto.</p>    | only\">Search</label>\n                    <input  |             <th scope=\"col\">Eng</th>             |
# |        |         </ul>\n                    </li>\n         |        <h2>Can you spot the barriers?</h2>         | id=\"search-input\" class=\"form-control mr-sm-2\" |             <th scope=\"col\">Eco</th>             |
# |        |         <li class=\"nav-item dropdown\">\n         | <p><img style=\"float:left;max-width:200px;margin- |    type=\"search\" placeholder=\"Search\" aria-    |             <th scope=\"col\">Phy</th>             |
# |        |  <a class=\"nav-link dropdown-toggle\" href=\"#\"  | right:10px\" src=\"https://openassessittoolkit.git |   label=\"Search\">\n                    <button   |             <th scope=\"col\">Psy</th>             |
# |        | id=\"admissionsDropdown\" data-toggle=\"dropdown\" |   hub.io/accessible_u/images/8675309-block.jpg\"   |       class=\"btn btn-success my-2 my-sm-0\"       |             <th scope=\"col\">CS</th>              |
# |        | aria-haspopup=\"true\" aria-expanded=\"false\">\n  |    alt=\"Block graphic\"> There are at least 18    |           type=\"submit\">Go</button>\n            |             <th scope=\"col\">Eng</th>             |
# |        |     Admissions\n                        </a>\n     |  accessibility issues on this page. To see a list  |   </form>\n            </div>\n        </div>\n    |             <th scope=\"col\">Eco</th>             |
# |        |         <ul class=\"dropdown-menu\" aria-          | of all known issues, <a href=\"https://openassessi |          </nav>\n    <main>\n        <div          |             <th scope=\"col\">Phy</th>             |
# |        |        labelledby=\"admissionsDropdown\">\n        | ttoolkit.github.io/accessible_u/issues.html\">clic |       class=\"container\">\n            <div       |             <th scope=\"col\">Psy</th>             |
# |        |           <li><a class=\"dropdown-item\"           |  k here</a>. To see a more accessible version of   | class=\"row\">\n                <div class=\"col-  |           </tr>                </thead>            |
# |        |        href=\"#\">Undergraduate</a></li>\n         | this same page, <a href=\"https://openassessittool | md-8\" id=\"main\">\n                    <section  |          <tbody>                    <tr>           |
# |        |           <li><a class=\"dropdown-item\"           |  kit.github.io/accessible_u/after_u.html\">click   |   class=\"mb-3\">\n                        <div    |            <th scope=\"row\">Total</th>            |
# |        |           href=\"#\">Graduate</a></li>\n           |  here</a>. To view a popup list of accessibility   |  id=\"carousel\" aria-label=\"Image carousel\">\n  |  <td>84</td>                        <td>126</td>   |
# |        |           <li><a class=\"dropdown-item\"           |     issues:</p>            <a class=\"btn btn-     |    <div>\n                                <div     |   <td>43</td>                        <td>32</td>   |
# |        |           href=\"#\">Tuition</a></li>\n            | primary\" href=\"https://openassessittoolkit.githu |             class=\"slide current\">\n             |  <td>112</td>                        <td>82</td>   |
# |        |           <li><a class=\"dropdown-item\"           | b.io/accessible_u/cheatsheet.html\">click here</a> |     <a href=\"somepage.html?ref=Slide%201\">\n     |  <td>140</td>                        <td>45</td>   |
# |        |        href=\"#\">Financial Aid</a></li>\n         |  <h2>AU Enrollment Trends</h2>            <table   | <img src=\"https://openassessittoolkit.github.io/a |  <td>34</td>                        <td>101</td>   |
# |        |         </ul>\n                    </li>\n         |          class=\"table table-bordered\">           | ccessible_u/images/8675309-before_brass_band.jpg\" |           </tr>                    <tr>            |
# |        |             <li class=\"nav-item\">\n              |          <thead>                    <tr>           |   width=\"700\" height=\"470\" alt=\"Brass band    |           <th scope=\"row\">% Male</th>            |
# |        |  <a class=\"nav-link\" href=\"#\">Visitors</a>\n   |           <th scope=\"col\">&nbsp;</th>            |                  performing\">\n                   |   <td>59</td>                        <td>84</td>   |
# |        |           </li>\n                </ul>\n           |   <th scope=\"col\" colspan=\"5\" class=\"text-    |   </a>\n                                </div>\n   |   <td>73</td>                        <td>69</td>   |
# |        |      <form class=\"form-inline my-2 my-lg-0\"      | center\">Last year</th>                        <th |              <div class=\"slide\">\n               |   <td>20</td>                        <td>87</td>   |
# |        |    role=\"search\">\n                    <label    |     scope=\"col\" colspan=\"5\" class=\"text-      |     <a href=\"somepage.html?ref=Slide%202\">\n     |   <td>80</td>                        <td>69</td>   |
# |        |          for=\"search-input\" class=\"sr-          |  center\">This year</th>                    </tr>  | <img src=\"https://openassessittoolkit.github.io/a |   <td>69</td>                        <td>22</td>   |
# |        | only\">Search</label>\n                    <input  |          <tr>                        <th           |            ccessible_u/images/8675309-             |           </tr>                    <tr>            |
# |        | id=\"search-input\" class=\"form-control mr-sm-2\" |             scope=\"col\">&nbsp;</th>              |   before_articulated_bus.jpg\" alt=\"Articulated   |          <th scope=\"row\">% Female</th>           |
# |        |    type=\"search\" placeholder=\"Search\" aria-    |             <th scope=\"col\">CS</th>              | bus\">\n                                    </a>\n |   <td>41</td>                        <td>16</td>   |
# |        |   label=\"Search\">\n                    <button   |             <th scope=\"col\">Eng</th>             |    </div>\n                                <div    |   <td>27</td>                        <td>31</td>   |
# |        |       class=\"btn btn-success my-2 my-sm-0\"       |             <th scope=\"col\">Eco</th>             |                 class=\"slide\">\n                 |   <td>80</td>                        <td>13</td>   |
# |        |           type=\"submit\">Go</button>\n            |             <th scope=\"col\">Phy</th>             |     <a href=\"somepage.html?ref=Slide%203\">\n     |   <td>20</td>                        <td>31</td>   |
# |        |   </form>\n            </div>\n        </div>\n    |             <th scope=\"col\">Psy</th>             | <img src=\"https://openassessittoolkit.github.io/a |   <td>31</td>                        <td>78</td>   |
# |        |          </nav>\n\n    <main id=\"main\"           |             <th scope=\"col\">CS</th>              |            ccessible_u/images/8675309-             | </tr>                </tbody>            </table>  |
# |        |       class=\"container\">\n        <section       |             <th scope=\"col\">Eng</th>             |    before_construction.jpg\" alt=\"Construction    |     </section>        <section class=\"mt-4\">     |
# |        | class=\"mb-3\">\n            <div id=\"carousel\"  |             <th scope=\"col\">Eco</th>             |                     site\">\n                      |   <h2>Events</h2>            <div class=\"list-    |
# |        |          aria-label=\"Image carousel\">\n          |             <th scope=\"col\">Phy</th>             |   </a>\n                                </div>\n   |  group\">                <div class=\"list-group-  |
# |        |   <div>\n                    <div class=\"slide    |             <th scope=\"col\">Psy</th>             |    </div>\n                            <div>\n     |           item\">                    <h3           |
# |        |       current\">\n                        <a       |           </tr>                </thead>            |  <button class=\"btn-prev\" aria-label=\"Previous  |            class=\"h5\">December 1</h3>            |
# |        |      href=\"somepage.html?ref=Slide%201\">\n       |          <tbody>                    <tr>           | slide\"><img src=\"https://openassessittoolkit.git |   <h4 class=\"h6\"><a href=\"#\">A great holiday   |
# |        | <img src=\"https://openassessittoolkit.github.io/a |            <th scope=\"row\">Total</th>            |     hub.io/accessible_u/images/8675309-arrow-      |  event</a></h4>                    <p>Don't miss   |
# |        | ccessible_u/images/8675309-before_brass_band.jpg\" |  <td>84</td>                        <td>126</td>   |       left.png\" width=\"70\" height=\"120\"       |       this event.</p>                </div>        |
# |        |   width=\"700\" height=\"470\" alt=\"Brass band    |   <td>43</td>                        <td>32</td>   |            alt=\"Previous\"></button>\n            |          <div class=\"list-group-item\">           |
# |        |   performance\">\n                        </a>\n   |  <td>112</td>                        <td>82</td>   |    <button class=\"btn-next\" aria-label=\"Next    |         <h3 class=\"h5\">December 31</h3>          |
# |        |          </div>\n                    <div          |  <td>140</td>                        <td>45</td>   | slide\"><img src=\"https://openassessittoolkit.git |   <h4 class=\"h6\"><a href=\"#\">New year's eve    |
# |        |    class=\"slide\">\n                        <a    |  <td>34</td>                        <td>101</td>   |     hub.io/accessible_u/images/8675309-arrow-      |  party</a></h4>                    <p>Ring in the  |
# |        |      href=\"somepage.html?ref=Slide%202\">\n       |           </tr>                    <tr>            |      right.png\" width=\"70\" height=\"120\"       |          new year with your friends.</p>           |
# |        | <img src=\"https://openassessittoolkit.github.io/a |           <th scope=\"row\">% Male</th>            |              alt=\"Next\"></button>\n              |     </div>            </div>        </section>     |
# |        |            ccessible_u/images/8675309-             |   <td>59</td>                        <td>84</td>   |      </div>\n                            <ul       | <section class=\"mt-4\">            <h2>Start your |
# |        |   before_articulated_bus.jpg\" alt=\"Articulated   |   <td>73</td>                        <td>69</td>   |       class=\"lentils\" role=\"tablist\">\n        |   application</h2>            <form action=\"#\"   |
# |        |       bus\">\n                        </a>\n       |   <td>20</td>                        <td>87</td>   | <li data-slide=\"0\" class=\"active\" role=\"tab\" |        method=\"post\">                <div        |
# |        |          </div>\n                    <div          |   <td>80</td>                        <td>69</td>   |           aria-selected=\"true\"></li>\n           |     class=\"mb-3\">                    <label      |
# |        |    class=\"slide\">\n                        <a    |   <td>69</td>                        <td>22</td>   |      <li data-slide=\"1\" role=\"tab\" aria-       |    for=\"name\" class=\"form-label\">Name <span    |
# |        |      href=\"somepage.html?ref=Slide%203\">\n       |           </tr>                    <tr>            |             selected=\"false\"></li>\n             |       class=\"text-danger\">*</span></label>       |
# |        | <img src=\"https://openassessittoolkit.github.io/a |          <th scope=\"row\">% Female</th>           |      <li data-slide=\"2\" role=\"tab\" aria-       |    <input type=\"text\" class=\"form-control\"     |
# |        |            ccessible_u/images/8675309-             |   <td>41</td>                        <td>16</td>   |             selected=\"false\"></li>\n             |        id=\"name\" name=\"name\" required>         |
# |        |    before_construction.jpg\" alt=\"Construction    |   <td>27</td>                        <td>31</td>   |      </ul>\n                        </div>\n       |     </div>                <div class=\"mb-3\">     |
# |        |      site\">\n                        </a>\n       |   <td>80</td>                        <td>13</td>   |                    <article>\n                     |  <label for=\"email\" class=\"form-label\">Email   |
# |        |          </div>\n                </div>\n          |   <td>20</td>                        <td>31</td>   |                <h1>Welcome!</h1>\n                 |    <span class=\"text-danger\">*</span></label>    |
# |        |  <div>\n                    <button class=\"btn-   |   <td>31</td>                        <td>78</td>   |       <p>Accessible University (AU) is a <a        |    <input type=\"email\" class=\"form-control\"    |
# |        | prev\" aria-label=\"Previous slide\"><img src=\"ht | </tr>                </tbody>            </table>  |            href=\"https://www.merriam-             |       id=\"email\" name=\"email\" required>        |
# |        | tps://openassessittoolkit.github.io/accessible_u/i |      </section>        <aside class=\"mt-4\">      |  webster.com/dictionary/fictional\">fictional</a>  |     </div>                <div class=\"mb-3\">     |
# |        |    mages/8675309-arrow-left.png\" width=\"70\"     |    <h2>Events</h2>            <div class=\"card    | <a href=\"https://en.wikipedia.org/wiki/University |        <label for=\"country\" class=\"form-        |
# |        |    height=\"120\" alt=\"Previous\"></button>\n     |  mb-3\">                <div class=\"card-body\">  | \">university</a>, and this is its fictional home  | label\">Country</label>                    <input  |
# |        |    <button class=\"btn-next\" aria-label=\"Next    |      <h5 class=\"card-title\">December 1</h5>      |    page. This page is designed to demonstrate a    |        type=\"text\" class=\"form-control\"        |
# |        | slide\"><img src=\"https://openassessittoolkit.git |   <h6 class=\"card-subtitle mb-2 text-muted\">A    |          variety of common web design <a           |          id=\"country\" name=\"country\">          |
# |        |     hub.io/accessible_u/images/8675309-arrow-      |   great holiday event</h6>                    <p   |            href=\"https://www.merriam-             |     </div>                <div class=\"mb-3\">     |
# |        |      right.png\" width=\"70\" height=\"120\"       |   class=\"card-text\">Don't miss this event.</p>   |   webster.com/dictionary/problems\">problems</a>   |        <label class=\"form-label\">Desired         |
# |        |  alt=\"Next\"></button>\n                </div>\n  |      </div>            </div>            <div      |  that result in visitors with disabilities being   |     major(s):</label>                    <div      |
# |        |     <ul class=\"lentils\" role=\"tablist\">\n      |      class=\"card mb-3\">                <div      | unable to access the content or features of a web  |               class=\"form-check\">                |
# |        | <li data-slide=\"0\" class=\"active\" role=\"tab\" |    class=\"card-body\">                    <h5     |   page. Although the heading at the top of this    |         <input class=\"form-check-input\"          |
# |        |           aria-selected=\"true\"></li>\n           |       class=\"card-title\">December 31</h5>        |   section of the page suggests that AU may be a    |  type=\"checkbox\" id=\"majorCS\" name=\"majors\"  |
# |        |      <li data-slide=\"1\" role=\"tab\" aria-       |  <h6 class=\"card-subtitle mb-2 text-muted\">New   | welcoming institution, the inaccessible design of  |    value=\"CS\">                        <label     |
# |        | selected=\"false\"></li>\n                    <li  |     years eve party</h6>                    <p     |    this page sends the opposite message.</p>\n     |             class=\"form-check-label\"             |
# |        |        data-slide=\"2\" role=\"tab\" aria-         | class=\"card-text\">Ring in the new year with your |  </article>\n                        <article>\n   |      for=\"majorCS\">Computer Science</label>      |
# |        | selected=\"false\"></li>\n                </ul>\n  |         friends</p>                </div>          |               <h2>Bienvenido!</h2>\n               |    </div>                    <div class=\"form-    |
# |        |           </div>\n\n            <article           |       </div>        </aside>        <section       |  <p>Accesible Universidad (UA) es una universidad  |       check\">                        <input       |
# |        |      class=\"section\">\n                <h1       |     class=\"mt-4\">            <h2>Start your      |   ficticia, y esta es su página de ficción. Esta   |    class=\"form-check-input\" type=\"checkbox\"    |
# |        |         class=\"heading\">Welcome!</h1>\n          |    application</h2>            <p class=\"text-    |  página está diseñada para demostrar una variedad  |   id=\"majorEng\" name=\"majors\" value=\"Eng\">   |
# |        |       <p>Accessible University (AU) is a <a        |      info\">(required fields are in blue)</p>      |     de común de diseño web que se traducen en      |         <label class=\"form-check-label\"          |
# |        |            href=\"https://www.merriam-             |        <form action=\"#\" method=\"post\">         |  problemas de los visitantes con discapacidad no   |        for=\"majorEng\">Engineering</label>        |
# |        |  webster.com/dictionary/fictional\">fictional</a>  |   <div class=\"mb-3\">                    <label   |  poder acceder al contenido o las características  |    </div>                    <div class=\"form-    |
# |        | <a href=\"https://en.wikipedia.org/wiki/University |    for=\"name\" class=\"form-label\">Name <span    |  de una página web. Aunque el título en la parte   |       check\">                        <input       |
# |        | \">university</a>, and this is its fictional home  |        class=\"text-info\">*</span></label>        | superior de esta sección de la página sugiere que  |    class=\"form-check-input\" type=\"checkbox\"    |
# |        |    page. This page is designed to demonstrate a    |    <input type=\"text\" class=\"form-control\"     |   AU puede ser una institución de bienvenida, el   |   id=\"majorEco\" name=\"majors\" value=\"Eco\">   |
# |        |          variety of common web design <a           |        id=\"name\" name=\"name\" required>         | diseño inaccesible de esta página envía el mensaje |         <label class=\"form-check-label\"          |
# |        |            href=\"https://www.merriam-             |     </div>                <div class=\"mb-3\">     | opuesto.</p>\n                        </article>\n |         for=\"majorEco\">Economics</label>         |
# |        |   webster.com/dictionary/problems\">problems</a>   |  <label for=\"email\" class=\"form-label\">Email   | <article>\n                            <h2>Can you |    </div>                    <div class=\"form-    |
# |        |  that result in visitors with disabilities being   |     <span class=\"text-info\">*</span></label>     |             spot the barriers?</h2>\n              |       check\">                        <input       |
# |        | unable to access the content or features of a web  |    <input type=\"email\" class=\"form-control\"    | <p><img style=\"float:left;max-width:200px;margin- |    class=\"form-check-input\" type=\"checkbox\"    |
# ...
# |        |   #CNS-054061S). The contents do not necessarily   |                                                    |    accessibility issues</div>\n        <button     |                                                    |
# |        |     represent the policies of the U.S. federal     |                                                    |     type=\"button\" id=\"modalXButton\" aria-      |                                                    |
# |        |    government, and you should not assume their     |                                                    | label=\"Close\">x</button>\n        <p>Note: This  |                                                    |
# |        |  endorsement.</p>\n                <p>Subsequent   |                                                    | popup does not receive keyboard focus. The cursor  |                                                    |
# |        |  modifications to this instance have been made by  |                                                    | continues to tab down the page behind the it. As a |                                                    |
# |        |  Duke University to modernize the look, feel, and  |                                                    |  result keyboard-only users cannot dismiss it and  |                                                    |
# |        |  code.</p>\n            </div>\n        </div>\n   |                                                    |   screen reader users will not be alerted to its   |                                                    |
# |        | </footer>\n\n    <div id=\"modalMask\" class=\"sr- |                                                    |    presence. They will not be able to close it;    |                                                    |
# |        |    only\"></div>\n    <div id=\"modalContent\"     |                                                    | rendering the webpage useless.</p>\n        <p>On  |                                                    |
# |        |  role=\"dialog\" aria-labelledby=\"modalHeading\"  |                                                    |     the inaccessible version of this page the      |                                                    |
# |        |        aria-hidden=\"true\">\n        <div         |                                                    | following errors can be found:</p>\n        <ol>\n |                                                    |
# |        | class=\"modalHeading\" id=\"modalHeading\">List of |                                                    |     <li>Missing bypass block <br>(skip-to main     |                                                    |
# |        |    accessibility issues</div>\n        <button     |                                                    |  content).</li>\n            <li>Improper use of   |                                                    |
# |        |     type=\"button\" id=\"modalXButton\" aria-      |                                                    |      headings</li>\n            <li>Images of      |                                                    |
# |        | label=\"Close\">x</button>\n        <p>Note: This  |                                                    |  text</li>\n            <li>No alternate text on   |                                                    |
# |        | popup does not receive keyboard focus. The cursor  |                                                    |  informative images</li>\n            <li>Missing  |                                                    |
# |        |   continues to tab down the page behind it. As a   |                                                    |     or excessive alternate text on decorative      |                                                    |
# |        | result, keyboard-only users cannot dismiss it and  |                                                    |  images</li>\n            <li>Insufficient color   |                                                    |
# |        |   screen reader users will not be alerted to its   |                                                    | contrast</li>\n            <li>Insufficient visual |                                                    |
# |        |    presence. They will not be able to close it;    |                                                    |  cues</li>\n            <li>Inaccessible dropdown  |                                                    |
# |        | rendering the webpage useless.</p>\n        <p>On  |                                                    |       menu</li>\n            <li>Redundant,        |                                                    |
# |        |     the inaccessible version of this page the      |                                                    |           uninformative link text</li>\n           |                                                    |
# |        | following errors can be found:</p>\n        <ol>\n |                                                    |  <li>Color used to communicate information</li>\n  |                                                    |
# |        |     <li>Missing bypass block <br>(skip-to main     |                                                    |         <li>Language not specified</li>\n          |                                                    |
# |        |  content).</li>\n            <li>Improper use of   |                                                    |     <li>Missing accessible form markup</li>\n      |                                                    |
# |        |      headings</li>\n            <li>Images of      |                                                    |          <li>Inaccessible CAPTCHA</li>\n           |                                                    |
# |        |  text</li>\n            <li>No alternate text on   |                                                    |         <li>Inaccessible validation</li>\n         |                                                    |
# |        |  informative images</li>\n            <li>Missing  |                                                    |       <li>Missing ARIA landmark roles</li>\n       |                                                    |
# |        |     or excessive alternate text on decorative      |                                                    |        <li>Inaccessible modal window</li>\n        |                                                    |
# |        |  images</li>\n            <li>Insufficient color   |                                                    |          <li>Inaccessible carousel</li>\n          |                                                    |
# |        | contrast</li>\n            <li>Insufficient visual |                                                    |     <li>Missing accessible table markup</li>\n     |                                                    |
# |        |  cues</li>\n            <li>Inaccessible dropdown  |                                                    |  <li>HTML fails validation</li>\n        </ol>\n   |                                                    |
# |        |       menu</li>\n            <li>Redundant,        |                                                    | <button class=\"btn btn-primary\" type=\"button\"  |                                                    |
# |        |           uninformative link text</li>\n           |                                                    |         id=\"modalOkButton\">OK</button>\n         |                                                    |
# |        |  <li>Color used to communicate information</li>\n  |                                                    |             </div>\n</body>\n</html>",             |                                                    |
# |        |         <li>Language not specified</li>\n          |                                                    |      "Procedure": "1. Added lang attribute to the  |                                                    |
# |        |     <li>Missing accessible form markup</li>\n      |                                                    | html tag.\n2. Converted relative URLs to absolute  |                                                    |
# |        |          <li>Inaccessible CAPTCHA</li>\n           |                                                    | URLs.\n3. Added alt text to images.\n4. Corrected  |                                                    |
# |        |         <li>Inaccessible validation</li>\n         |                                                    |     heading structure and added semantic HTML      |                                                    |
# |        |       <li>Missing ARIA landmark roles</li>\n       |                                                    | elements.\n5. Improved color contrast in CSS.\n6.  |                                                    |
# |        |        <li>Inaccessible modal window</li>\n        |                                                    |  Added aria-labels for better accessibility.\n7.   |                                                    |
# |        |          <li>Inaccessible carousel</li>\n          |                                                    |    Added aria-live to error container for form     |                                                    |
# |        |     <li>Missing accessible table markup</li>\n     |                                                    |  validation.\n8. Added labels to form inputs.\n9.  |                                                    |
# |        |  <li>HTML fails validation</li>\n        </ol>\n   |                                                    |    Added role and aria attributes to modal for     |                                                    |
# |        | <button class=\"btn btn-primary\" type=\"button\"  |                                                    | accessibility.\n10. Added captions and headers to  |                                                    |
# |        |         id=\"modalOkButton\">OK</button>\n         |                                                    |  tables.\n11. Added skip-to-main-content link for  |                                                    |
# |        |             </div>\n</body>\n</html>",             |                                                    |   better navigation.\n12. Ensured all links have   |                                                    |
# |        |     "Procedure": "1. Added lang attribute to html  |                                                    |     descriptive text.\n13. Added aria roles to     |                                                    |
# |        |  tag.\n2. Included skip-to-main-content link for   |                                                    |  navigation and footer.\n14. Added sr-only class   |                                                    |
# |        |  better navigation.\n3. Corrected heading levels   |                                                    |  for screen reader text.\n15. Ensured all buttons  |                                                    |
# |        |  and added semantic HTML elements.\n4. Added alt   |                                                    |  have aria-labels.\n16. Added aria-describedby to  |                                                    |
# |        | text to all images.\n5. Improved color contrast in |                                                    |  tables for better context.\n17. Ensured all form  |                                                    |
# |        |  CSS styles.\n6. Added aria-labels to buttons and  |                                                    |    elements have associated labels.\n18. Added     |                                                    |
# |        |  navigation elements.\n7. Converted relative URLs  |                                                    |         role=\"dialog\" to modal content."         |                                                    |
# |        |     to absolute URLs.\n8. Added aria roles and     |                                                    |                         }                          |                                                    |
# |        | properties to improve accessibility.\n9. Corrected |                                                    |                                                    |                                                    |
# |        |    form elements with labels and aria-required     |                                                    |                                                    |                                                    |
# |        | attributes.\n10. Improved table markup with scope  |                                                    |                                                    |                                                    |
# |        | attributes.\n11. Added role and aria attributes to |                                                    |                                                    |                                                    |
# |        |  modal for better accessibility.\n12. Ensured all  |                                                    |                                                    |                                                    |
# |        | interactive elements are keyboard accessible.\n13. |                                                    |                                                    |                                                    |
# |        |     Added sr-only class for screen reader only     |                                                    |                                                    |                                                    |
# |        |   text.\n14. Ensured all links have descriptive    |                                                    |                                                    |                                                    |
# |        |  text.\n15. Added aria-live to error messages for  |                                                    |                                                    |                                                    |
# |        |   form validation.\n16. Ensured all scripts and    |                                                    |                                                    |                                                    |
# |        |  styles are included and accessible.\n17. Checked  |                                                    |                                                    |                                                    |
# |        | and corrected HTML validation errors.\n18. Ensured |                                                    |                                                    |                                                    |
# |        |    all elements are focusable and navigable by     |                                                    |                                                    |                                                    |
# |        |                     keyboard."                     |                                                    |                                                    |                                                    |
# |        |                         }                          |                                                    |                                                    |                                                    |
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+

# %%
extracted_json_html = json.loads(extracted_html)
extracted_json_html_template = json.loads(extracted_html_template)
extracted_json_md = json.loads(extracted_md)
extracted_json_md_template = json.loads(extracted_md_template)

# %%
generate_output_files("gpt-site2", extracted_json_html, extracted_json_html_template, extracted_json_md, extracted_json_md_template)

# %% [markdown]
# ## Google Gemini: Duke University Site
#
# Let’s examine the result produced by this model.

# %%
extracted_html, extracted_html_template, extracted_md, extracted_md_template = display_extracted_content("gemini-2.5-flash-preview-04-17", all_content_html, all_content_md, "Crawl4ai", site_name="Site 2", template="blocks")
# Out:
# Processing results:   0%|          | 0/2 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for HTML input:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for HTML input and template:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for Markdown input:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracting content with Crawl4ai for Markdown input and template:   0%|          | 0/1 [00:00<?, ?it/s]
# Extracted Content Table:
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# |  Site  |                     From HTML                      |              From HTML with template               |                   From markdown                    |            From markdown with template             |
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+
# | Site 2 |             Completion tokens: 10,746              |              Completion tokens: 7,996              |             Completion tokens: 10,443              |              Completion tokens: 6,496              |
# |        |                Prompt tokens: 4,583                |                Prompt tokens: 7,462                |                Prompt tokens: 4,636                |                Prompt tokens: 7,457                |
# |        |               Total cost: $0.038323                |               Total cost: $0.038645                |               Total cost: $0.037698                |               Total cost: $0.034882                |
# |        |                                                    |                                                    |                                                    |                                                    |
# |        |                                                    |                                                    |                                                    |                                                    |
# |        |                         {                          |                         {                          |                         {                          |                         {                          |
# |        |           "HTML": "<!DOCTYPE html>\n<html          |           "HTML": "<!DOCTYPE html>\n<html          |           "HTML": "<!DOCTYPE html>\n<html          |           "HTML": "<!DOCTYPE html>\n<html          |
# |        | lang=\"en\">\n<head>\n\t<meta charset=\"utf-8\">\n |          lang=\"en\">\n<head>\n    <meta           | lang=\"en\">\n<head>\n\t<meta charset=\"utf-8\">\n |          lang=\"en\">\n<head>\n    <meta           |
# |        |  <meta name=\"viewport\" content=\"width=device-   |  charset=\"UTF-8\">\n    <meta name=\"viewport\"   |  <meta name=\"viewport\" content=\"width=device-   |  charset=\"UTF-8\">\n    <meta name=\"viewport\"   |
# |        |           width, initial-scale=1, user-            | content=\"width=device-width, initial-scale=1\">\n |           width, initial-scale=1, user-            | content=\"width=device-width, initial-scale=1\">\n |
# |        |    scalable=no\">\n\t<title>Before - Accessible    |      <title>Accessible University Demo Site -      |   scalable=no\">\n\t<title>Accessible University   |  <title>Accessible University Demo Site - Before   |
# |        |        University Demo Site - Inaccessible         | Accessible Version</title>\n    <link href=\"https | Demo Site - Before Version</title>\n  <script src= | Version</title>\n    <link href=\"https://cdn.jsde |
# |        | Version</title>\n  <script src=\"https://code.jque | ://cdn.jsdelivr.net/npm/bootstrap@5.3.3/dist/css/b |         \"https://code.jquery.com/jquery-          | livr.net/npm/bootstrap@5.3.3/dist/css/bootstrap.mi |
# |        | ry.com/jquery-3.3.1.slim.min.js\" integrity=\"sha3 | ootstrap.min.css\" rel=\"stylesheet\">\n    <link  |      3.3.1.slim.min.js\" integrity=\"sha384-       |       n.css\" rel=\"stylesheet\">\n    <link       |
# |        |                        84-                         | rel=\"icon\" href=\"https://openassessittoolkit.gi | q8i/X+965DzO0rT7abK41JStQIAqVgRVzpbzo5smXKp4YfRvH+ | rel=\"icon\" href=\"https://openassessittoolkit.gi |
# |        | q8i/X+965DzO0rT7abK41JStQIAqVgRVzpbzo5smXKp4YfRvH+ |     thub.io/accessible_u/images/favicon.ico\"      |                  8abtTE1Pi6jizo\"                  |     thub.io/accessible_u/images/favicon.ico\"      |
# |        |                  8abtTE1Pi6jizo\"                  | type=\"image/x-icon\">\n    <style>\n        .sr-  |    crossorigin=\"anonymous\"></script>\n\t<link    | type=\"image/x-icon\">\n    <style>\n        .sr-  |
# |        |    crossorigin=\"anonymous\"></script>\n\t<link    |     only {\n            position: absolute;\n      | rel=\"icon\" href=\"https://openassessittoolkit.gi |     only {\n            position: absolute;\n      |
# |        | rel=\"icon\" href=\"https://openassessittoolkit.gi |      width: 1px;\n            height: 1px;\n       |     thub.io/accessible_u/images/favicon.ico\"      |      width: 1px;\n            height: 1px;\n       |
# |        |     thub.io/accessible_u/images/favicon.ico\"      |      padding: 0;\n            margin: -1px;\n      |  type=\"image/x-icon\">\n  <!-- Inlined CSS from   |      padding: 0;\n            margin: -1px;\n      |
# |        | type=\"image/x-icon\">\n  <style>\n    /* sr-only  | overflow: hidden;\n            clip: rect(0, 0, 0, |   original files -->\n  <style>\n    /* sr-only    | overflow: hidden;\n            clip: rect(0, 0, 0, |
# |        |  class for visually hidden elements */\n    .sr-   |      0);\n            white-space: nowrap;\n       |  class for visually hidden elements */\n    .sr-   |      0);\n            white-space: nowrap;\n       |
# |        |  only {\n      position: absolute;\n      width:   |  border: 0;\n        }\n        /* Inlined styles  |  only {\n      position: absolute;\n      width:   |  border: 0;\n        }\n        /* Basic styling   |
# |        |   1px;\n      height: 1px;\n      padding: 0;\n    |       from original CSS files, corrected for       |   1px;\n      height: 1px;\n      padding: 0;\n    |     for required indicator */\n        .form-      |
# |        |      margin: -1px;\n      overflow: hidden;\n      |   accessibility */\n        /* Note: Full color    |      margin: -1px;\n      overflow: hidden;\n      |  label.required::after {\n            content: \"  |
# |        |    clip: rect(0, 0, 0, 0);\n      white-space:     |       contrast review and correction applied       |    clip: rect(0, 0, 0, 0);\n      white-space:     |   *\";\n            color: red; /* Using red for   |
# |        | nowrap;\n      border: 0;\n    }\n\n    /* Inlined |         conceptually */\n        body {\n          |  nowrap;\n      border: 0;\n    }\n\n    /* Basic  | visibility, ensure contrast */\n            font-  |
# |        |  styles from original CSS files */\n    /* Note:   |  padding-top: 0;\n        }\n        #content {\n  |   body and link styles (simulated from main.css)   |   weight: bold;\n        }\n        /* Style for   |
# |        |  Color contrast adjustments made where necessary   |  padding-top: 0;\n        }\n        #banner {\n   |  */\n    body {\n      font-family: sans-serif;\n  |     form error messages */\n        #error {\n     |
# |        | */\n\n    /* From bootstrap.min.css (simplified -  |  padding: 1rem 0;\n        }\n        .logo-link   |    line-height: 1.5;\n      color: #212529; /*     |   color: red;\n            font-weight: bold;\n    |
# |        |    full Bootstrap is complex) */\n    /* Basic     | {\n            display: inline-block;\n        }\n |       Bootstrap default body text color */\n       | margin-bottom: 1rem;\n        }\n        /* Custom |
# |        | structure and typography */\n    body { margin: 0; |      #logo {\n            max-width: 100%;\n       | background-color: #fff; /* Bootstrap default body  |       styles not covered by Bootstrap 5 */\n       |
# |        |  font-family: -apple-system, BlinkMacSystemFont,   |  height: auto;\n        }\n        .utility-menu   |   background */\n    }\n\n    a {\n      color:    | .logo-link {\n            display: inline-block;\n |
# |        |  \"Segoe UI\", Roboto, \"Helvetica Neue\", Arial,  |        {\n            margin-left: 1rem;\n         |   #007bff; /* Bootstrap default link color */\n    | margin-bottom: 1rem;\n        }\n        .utility- |
# |        |   sans-serif, \"Apple Color Emoji\", \"Segoe UI    | padding-left: 0;\n        }\n        .utility-menu |  text-decoration: none;\n    }\n\n    a:hover {\n  |      menu {\n            margin-left: 1rem;\n      |
# |        |   Emoji\", \"Segoe UI Symbol\"; font-size: 1rem;   |     li {\n            display: inline-block;\n     | text-decoration: underline;\n    }\n\n    /* Skip  |          }\n        .utility-menu li {\n           |
# |        |     font-weight: 400; line-height: 1.5; color:     | margin-right: 1rem;\n        }\n        .utility-  | link styling */\n    .skip-link {\n      position: |  display: inline-block;\n            margin-left:  |
# |        | #212529; text-align: left; background-color: #fff; |  menu li:last-child {\n            margin-right:   |   absolute;\n      top: -40px;\n      left: 0;\n   |         1rem;\n        }\n        .box {\n         |
# |        |   }\n    h1, h2, h3, h4, h5, h6 { margin-top: 0;   |    0;\n        }\n        .navbar-nav .nav-item    |   background-color: #000;\n      color: white;\n   |   border: 1px solid #ccc;\n            padding:    |
# |        |  margin-bottom: 0.5rem; }\n    p { margin-top: 0;  | .dropdown-menu {\n             /* Ensure dropdowns |   padding: 8px;\n      z-index: 100;\n    }\n\n    |    1rem;\n            margin-bottom: 1.5rem;\n     |
# |        |  margin-bottom: 1rem; }\n    a { color: #007bff;   |      are visible and keyboard accessible */\n      | .skip-link:focus {\n      top: 0;\n    }\n\n    /* |  }\n        .events h3 {\n            margin-top:  |
# |        |      text-decoration: none; background-color:      |   display: none; /* Handled by Bootstrap JS */\n   |      Banner/Header styles */\n    #banner {\n      |   0.5rem;\n            margin-bottom: 0.5rem;\n    |
# |        |   transparent; }\n    a:hover { color: #0056b3;    | position: absolute;\n             z-index: 1000;\n |   padding: 1rem 0;\n    }\n\n    .logo-link {\n    | }\n        .events p {\n            margin-bottom: |
# |        |  text-decoration: underline; }\n    .container {   | background-color: #fff;\n             border: 1px  |   display: inline-block;\n    }\n\n    #logo {\n   |     1rem;\n        }\n        .main-footer {\n     |
# |        |  width: 100%; padding-right: 15px; padding-left:   |    solid rgba(0,0,0,.15);\n             border-    |  max-width: 100%;\n      height: auto;\n    }\n\n  |      background-color: #f8f9fa;\n        }\n       |
# |        |  15px; margin-right: auto; margin-left: auto; }\n  |  radius: .25rem;\n        }\n        .navbar-nav   |  /* Utility menu styles */\n    .utility-menu {\n  |  .sub-footer {\n            font-size: 0.9rem;\n   |
# |        |   @media (min-width: 576px) { .container { max-    |         .nav-item.show .dropdown-menu {\n          |  padding: 0;\n      margin: 0;\n      list-style:  |  }\n        #ccLogo {\n            margin-bottom:  |
# |        | width: 540px; } }\n    @media (min-width: 768px) { |  display: block;\n        }\n        .navbar-nav   |      none;\n    }\n\n    .utility-menu li {\n      |      1rem;\n        }\n        .social li {\n      |
# |        |   .container { max-width: 720px; } }\n    @media   |  .nav-item .dropdown-item {\n            padding:  | display: inline-block;\n      margin-left: 1rem;\n |  display: inline-block;\n            margin-left:  |
# |        |    (min-width: 992px) { .container { max-width:    | .5rem 1rem;\n            color: #212529; /* Ensure |     }\n\n    /* Navbar styles (simulated from      |   1rem;\n        }\n        /* Ensure sufficient   |
# |        |    960px; } }\n    @media (min-width: 1200px) {    |     sufficient contrast */\n            text-      |  bootstrap.min.css and menu.css) */\n    .navbar   |  contrast for links in footer */\n        .main-   |
# |        |  .container { max-width: 1140px; } }\n    .row {   |  decoration: none;\n            display: block;\n  |     {\n      padding: 0.5rem 1rem;\n    }\n\n      | footer a {\n            color: #0056b3; /* Example |
# |        |   display: flex; flex-wrap: wrap; margin-right:    |    }\n        .navbar-nav .nav-item .dropdown-     | .navbar-dark .navbar-nav .nav-link {\n      color: | blue, check contrast */\n        }\n        .main- |
# |        | -15px; margin-left: -15px; }\n    .col-md-4, .col- |    item:hover, .navbar-nav .nav-item .dropdown-    |  rgba(255, 255, 255, 0.75); /* Light text on dark  |  footer a:hover {\n            color: #003f7f; /*  |
# |        |  md-8 { position: relative; width: 100%; padding-  |    item:focus {\n            color: #1e2125;\n     | background */\n    }\n\n    .navbar-dark .navbar-  |   Darker blue on hover */\n        }\n        /*   |
# |        |   right: 15px; padding-left: 15px; }\n    @media   |      background-color: #e9ecef;\n        }\n       | nav .nav-link:hover,\n    .navbar-dark .navbar-nav | Ensure sufficient contrast for text in footer */\n |
# |        |     (min-width: 768px) { .col-md-4 { flex: 0 0     |  .carousel-item img {\n            width: 100%;\n  |   .nav-link:focus {\n      color: rgba(255, 255,   | .main-footer, .main-footer p, .main-footer li {\n  |
# |        |  33.333333%; max-width: 33.333333%; } .col-md-8 {  |     height: auto;\n        }\n        .box {\n     |   255, 1); /* White on hover/focus */\n    }\n\n   |  color: #212529; /* Bootstrap default text color   |
# |        | flex: 0 0 66.666667%; max-width: 66.666667%; } }\n |   border: 1px solid #ccc;\n            padding:    |  .navbar-dark .navbar-nav .nav-item.active .nav-   |  */\n        }\n\n    </style>\n</head>\n<body>\n  |
# |        |     .float-left { float: left !important; }\n      |     1rem;\n            margin-bottom: 1rem;\n      |  link {\n      color: #fff; /* Active link color   | <a href=\"#main-content\" class=\"sr-only sr-only- |
# |        |    .float-right { float: right !important; }\n     |       }\n        .events h3, .events h4 {\n        |   */\n    }\n\n    .bg-dark {\n      background-   |      focusable\">Skip to main content</a>\n\n      |
# |        |   .list-unstyled { padding-left: 0; list-style:    | margin-bottom: .5rem;\n        }\n        .events  | color: #343a40 !important; /* Bootstrap dark */\n  |      <header class=\"container clearfix\">\n       |
# |        |  none; }\n    .clearfix::after { display: block;   |        img.hr {\n            width: 100%;\n        |  }\n\n    .bg-primary {\n      background-color:   | <nav aria-label=\"version\" class=\"float-end\">\n |
# |        |    clear: both; content: \"\"; }\n    .navbar {    |    height: auto;\n            margin: 1rem 0;\n    | #007bff !important; /* Bootstrap primary blue */\n |   <span class=\"float-start\">Examples:</span>\n   |
# |        |   position: relative; display: flex; flex-wrap:    |      }\n        #appForm .required label {\n       |     }\n\n    .dropdown-menu {\n      position:     |     <ul class=\"utility-menu float-start list-     |
# |        | wrap; align-items: center; justify-content: space- | color: #007bff; /* Original blue - check contrast  |   absolute;\n      top: 100%;\n      left: 0;\n    | unstyled\">\n                <li><a href=\"https:/ |
# |        |   between; padding: 0.5rem 1rem; }\n    .navbar-   |   */\n            /* Added visual indicator */\n   | z-index: 1000;\n      display: none; /* Managed by | /openassessittoolkit.github.io/accessible_u/before |
# |        |    expand-lg { flex-flow: row nowrap; justify-     | border-left: 4px solid #007bff; /* Example visual  |    JS */\n      float: left;\n      min-width:     |       _u.html\" aria-current=\"page\" aria-        |
# |        |   content: flex-start; }\n    .navbar-expand-lg    |     cue */\n            padding-left: .5rem;\n     |  10rem;\n      padding: 0.5rem 0;\n      margin:   |            label=\"before version with             |
# |        | .navbar-nav { flex-direction: row; }\n    .navbar- |     }\n        #appForm .form-group label {\n      |      0.125rem 0 0;\n      font-size: 1rem;\n       | problems\">Before</a></li>\n                <li><a |
# |        |   expand-lg .navbar-toggler { display: none; }\n   |    display: block;\n             margin-bottom:    |     color: #212529;\n      text-align: left;\n     | href=\"https://openassessittoolkit.github.io/acces |
# |        |    .navbar-dark .navbar-nav .nav-link { color:     |     .5rem;\n             font-weight: bold;\n      | list-style: none;\n      background-color: #fff;\n | sible_u/after_u.html\" aria-label=\"after version  |
# |        |   rgba(255, 255, 255, 0.75); }\n    .navbar-dark   |       }\n        #appForm .form-control {\n        |  background-clip: padding-box;\n      border: 1px  |  with fixes\">After</a></li>\n            </ul>\n  |
# |        | .navbar-nav .nav-link:hover, .navbar-dark .navbar- |    display: block;\n            width: 100%;\n     |  solid rgba(0, 0, 0, 0.15);\n      border-radius:  | </nav>\n        <a class=\"logo-link\" href=\"http |
# |        |  nav .nav-link:focus { color: rgba(255, 255, 255,  |  padding: .375rem .75rem;\n            font-size:  |    0.25rem;\n    }\n\n    .dropdown-menu.show {    | s://openassessittoolkit.github.io/accessible_u/\"> |
# |        |   1); }\n    .navbar-dark .navbar-nav .active >    |       1rem;\n            line-height: 1.5;\n       |     display: block; } /* Managed by JS */\n\n      | \n            <img id=\"logo\" src=\"https://opena |
# |        |     .nav-link { color: #fff; }\n    .bg-dark {     |   color: #495057;\n            background-color:   |     .dropdown-item {\n      display: block;\n      | ssessittoolkit.github.io/accessible_u/images/86753 |
# |        | background-color: #343a40 !important; }\n    .bg-  | #fff;\n            background-clip: padding-box;\n |   width: 100%;\n      padding: 0.25rem 1.5rem;\n   |       09-l-o-g-o-before.png\" width=\"950\"        |
# |        |  primary { background-color: #007bff !important;   |  border: 1px solid #ced4da;\n            border-   |      clear: both;\n      font-weight: 400;\n       |     height=\"230\" alt=\"Accessible University     |
# |        | }\n    .md-3 { margin-bottom: 1rem !important; }\n |  radius: .25rem;\n            transition: border-  |   color: #212529;\n      text-align: inherit;\n    |  Logo\">\n        </a>\n    </header>\n\n    <nav  |
# |        |    .mb-3 { margin-bottom: 1rem !important; }\n     |  color .15s ease-in-out,box-shadow .15s ease-in-   |   white-space: nowrap;\n      background-color:    |  class=\"navbar navbar-expand-lg navbar-dark bg-   |
# |        |     .mt-2 { margin-top: 0.5rem !important; }\n     |      out;\n        }\n        #appForm .form-      |     transparent;\n      border: 0;\n    }\n\n      |        dark bg-primary mb-3\">\n      <div         |
# |        |   .my-2 { margin-top: 0.5rem !important; margin-   |   control:focus {\n            color: #495057;\n   |   .dropdown-item:hover, .dropdown-item:focus {\n   |       class=\"container\">\n        <button        |
# |        |    bottom: 0.5rem !important; }\n    .my-lg-0 {    | background-color: #fff;\n            border-color: |  color: #16181b;\n      text-decoration: none;\n   | class=\"navbar-toggler\" type=\"button\" data-bs-  |
# |        |     margin-top: 0 !important; margin-bottom: 0     |        #80bdff;\n            outline: 0;\n         |  background-color: #f8f9fa;\n    }\n\n    /* Form  |            toggle=\"collapse\" data-bs-            |
# |        |  !important; }\n    .mr-auto { margin-right: auto  |   box-shadow: 0 0 0 .2rem rgba(0,123,255,.25);\n   |  styles (simulated from form.css) */\n    .form-   |      target=\"#navbarSupportedContent\" aria-      |
# |        | !important; }\n    .mr-sm-2 { margin-right: 0.5rem |        }\n        #appForm #majors div {\n         |   group {\n      margin-bottom: 1rem;\n    }\n\n   |     controls=\"navbarSupportedContent\" aria-      |
# |        |      !important; }\n    .p-5 { padding: 3rem       | margin-bottom: .5rem;\n        }\n        #appForm |      .form-control {\n      display: block;\n      |       expanded=\"false\" aria-label=\"Toggle       |
# |        |  !important; }\n    .form-inline { display: flex;  |   #captcha img {\n            display: block;\n    | width: 100%;\n      height: calc(1.5em + 0.75rem + |   navigation\">\n          <span class=\"navbar-   |
# |        |   flex-flow: row wrap; align-items: center; }\n    | margin-top: .5rem;\n            max-width: 100%;\n |     2px);\n      padding: 0.375rem 0.75rem;\n      |   toggler-icon\"></span>\n        </button>\n\n    |
# |        |    .form-control { display: block; width: 100%;    | height: auto;\n        }\n        #footer .social  |    font-size: 1rem;\n      font-weight: 400;\n     |      <div class=\"collapse navbar-collapse\"       |
# |        |   height: calc(1.5em + 0.75rem + 2px); padding:    |     li {\n            display: inline-block;\n     |     line-height: 1.5;\n      color: #495057;\n     |   id=\"navbarSupportedContent\">\n          <ul    |
# |        |  0.375rem 0.75rem; font-size: 1rem; font-weight:   |   margin-left: 1rem;\n        }\n        #footer   |  background-color: #fff;\n      background-clip:   |    class=\"navbar-nav me-auto mb-2 mb-lg-0\">\n    |
# |        | 400; line-height: 1.5; color: #495057; background- | .social img {\n            width: 24px; /* Example |  padding-box;\n      border: 1px solid #ced4da;\n  |     <li class=\"nav-item\">\n              <a      |
# |        | color: #fff; background-clip: padding-box; border: | size */\n            height: 24px; /* Example size | border-radius: 0.25rem;\n      transition: border- |  class=\"nav-link active\" aria-current=\"page\"   |
# |        |     1px solid #ced4da; border-radius: 0.25rem;     |     */\n        }\n        #footer nav ul {\n      | color 0.15s ease-in-out, box-shadow 0.15s ease-in- |      href=\"#\">Home</a>\n            </li>\n      |
# |        |  transition: border-color 0.15s ease-in-out, box-  | padding-left: 0;\n            list-style: none;\n  |     out;\n    }\n\n    .form-control:focus {\n     | <li class=\"nav-item dropdown\">\n              <a |
# |        |  shadow 0.15s ease-in-out; }\n    .btn { display:  |          }\n        #footer nav ul li {\n          |  color: #495057;\n      background-color: #fff;\n  |   class=\"nav-link dropdown-toggle\" href=\"#\"    |
# |        |  inline-block; font-weight: 400; color: #212529;   | margin-bottom: .5rem;\n        }\n        #footer  |    border-color: #80bdff;\n      outline: 0;\n     |   id=\"aboutDropdown\" role=\"button\" data-bs-    |
# |        |    text-align: center; vertical-align: middle;     |   .sub-footer {\n            margin-top: 1rem;\n   |     box-shadow: 0 0 0 0.2rem rgba(0, 123, 255,     |   toggle=\"dropdown\" aria-expanded=\"false\">\n   |
# |        | cursor: pointer; -webkit-user-select: none; -moz-  |   font-size: .9rem;\n        }\n        #footer    |    0.25);\n    }\n\n    .btn {\n      display:     |    About\n              </a>\n              <ul    |
# |        |  user-select: none; -ms-user-select: none; user-   |    .sub-footer p {\n            margin-bottom:     |      inline-block;\n      font-weight: 400;\n      |           class=\"dropdown-menu\" aria-            |
# |        |    select: none; background-color: transparent;    |     .5rem;\n        }\n        #ccLogo img {\n     |    color: #212529;\n      text-align: center;\n    |          labelledby=\"aboutDropdown\">\n           |
# |        |  border: 1px solid transparent; padding: 0.375rem  | margin-bottom: 1rem;\n        }\n        /* Modal  | vertical-align: middle;\n      cursor: pointer;\n  |           <li><a class=\"dropdown-item\"           |
# |        |    0.75rem; font-size: 1rem; line-height: 1.5;     |    styles - using Bootstrap modal classes */\n     |    user-select: none;\n      background-color:     |  href=\"#\">News</a></li>\n                <li><a  |
# |        |  border-radius: 0.25rem; transition: color 0.15s   |      .modal-content {\n            position:       |       transparent;\n      border: 1px solid        |              class=\"dropdown-item\"               |
# |        |  ease-in-out, background-color 0.15s ease-in-out,  |      relative;\n            display: flex;\n       |  transparent;\n      padding: 0.375rem 0.75rem;\n  |          href=\"#\">Governance</a></li>\n          |
# |        |  border-color 0.15s ease-in-out, box-shadow 0.15s  |    flex-direction: column;\n            width:     |    font-size: 1rem;\n      line-height: 1.5;\n     |           <li><a class=\"dropdown-item\"           |
# |        |  ease-in-out; }\n    .btn-primary { color: #fff;   |     100%;\n            pointer-events: auto;\n     |  border-radius: 0.25rem;\n      transition: color  |          href=\"#\">Diversity</a></li>\n           |
# |        | background-color: #007bff; border-color: #007bff;  |  background-color: #fff;\n            background-  | 0.15s ease-in-out, background-color 0.15s ease-in- | <li><a class=\"dropdown-item\" href=\"#\">Contact  |
# |        |      }\n    .btn-primary:hover { color: #fff;      | clip: padding-box;\n            border: 1px solid  |  out, border-color 0.15s ease-in-out, box-shadow   |         Us</a></li>\n              </ul>\n         |
# |        | background-color: #0069d9; border-color: #0062cc;  |    rgba(0,0,0,.2);\n            border-radius:     | 0.15s ease-in-out;\n    }\n\n    .btn-success {\n  |      </li>\n            <li class=\"nav-item       |
# |        |   }\n    .btn-success { color: #fff; background-   |    .3rem;\n            outline: 0;\n        }\n    |  color: #fff; /* White text */\n      background-  |   dropdown\">\n              <a class=\"nav-link   |
# |        |     color: #28a745; border-color: #28a745; }\n     |   .modal-header {\n            display: flex;\n    |  color: #28a745; /* Bootstrap success green */\n   |            dropdown-toggle\" href=\"#\"            |
# |        |   .btn-success:hover { color: #fff; background-    |     flex-shrink: 0;\n            align-items:      |     border-color: #28a745;\n    }\n\n    .btn-     | id=\"academicsDropdown\" role=\"button\" data-bs-  |
# |        |     color: #218838; border-color: #1e7e34; }\n     |    center;\n            justify-content: space-    |       success:hover {\n      color: #fff;\n        |   toggle=\"dropdown\" aria-expanded=\"false\">\n   |
# |        |     .btn-lg { padding: 0.5rem 1rem; font-size:     |    between;\n            padding: 1rem 1rem;\n     |  background-color: #218838;\n      border-color:   |  Academics\n              </a>\n              <ul  |
# |        | 1.25rem; line-height: 1.5; border-radius: 0.3rem;  |        border-bottom: 1px solid #dee2e6;\n         |      #1e7e34;\n    }\n\n    .btn-primary {\n       |           class=\"dropdown-menu\" aria-            |
# |        |  }\n    .btn-block { display: block; width: 100%;  |    border-top-left-radius: calc(.3rem - 1px);\n    |  color: #fff; /* White text */\n      background-  |        labelledby=\"academicsDropdown\">\n         |
# |        | }\n    .table { width: 100%; margin-bottom: 1rem;  |   border-top-right-radius: calc(.3rem - 1px);\n    |   color: #007bff; /* Bootstrap primary blue */\n   |  <li><a class=\"dropdown-item\" href=\"#\">Degree  |
# |        |   color: #212529; }\n    .table th, .table td {    |   }\n        .modal-title {\n            margin-   |     border-color: #007bff;\n    }\n\n    .btn-     |     Programs</a></li>\n                <li><a      |
# |        | padding: 0.75rem; vertical-align: top; border-top: |    bottom: 0;\n            line-height: 1.5;\n     |       primary:hover {\n      color: #fff;\n        |       class=\"dropdown-item\" href=\"#\">AU        |
# |        |    1px solid #dee2e6; }\n    .table thead th {     |  }\n        .modal-body {\n            position:   |  background-color: #0069d9;\n      border-color:   |      Faculty</a></li>\n                <li><a      |
# |        |  vertical-align: bottom; border-bottom: 2px solid  |      relative;\n            flex: 1 1 auto;\n      |  #0062cc;\n    }\n\n    .btn-lg {\n      padding:  |    class=\"dropdown-item\" href=\"#\">Distance     |
# |        | #dee2e6; }\n    .table tbody + tbody { border-top: |  padding: 1rem;\n        }\n        .modal-footer  |     0.5rem 1rem;\n      font-size: 1.25rem;\n      |     Learning</a></li>\n                <li><a      |
# |        | 2px solid #dee2e6; }\n    .table-sm th, .table-sm  |  {\n            display: flex;\n            flex-  | line-height: 1.5;\n      border-radius: 0.3rem;\n  |              class=\"dropdown-item\"               |
# |        |   td { padding: 0.3rem; }\n    .table-bordered {   |     wrap: wrap;\n            flex-shrink: 0;\n     |   }\n\n    .btn-block {\n      display: block;\n   |          href=\"#\">Libraries</a></li>\n           |
# |        | border: 1px solid #dee2e6; }\n    .table-bordered  | align-items: center;\n            justify-content: |    width: 100%;\n    }\n\n    /* Required field    |     </ul>\n            </li>\n            <li      |
# |        |     th, .table-bordered td { border: 1px solid     |     flex-end;\n            padding: .75rem;\n      | styling (original blue color fails contrast) */\n  |   class=\"nav-item dropdown\">\n              <a   |
# |        | #dee2e6; }\n    .table-bordered thead th, .table-  |          border-top: 1px solid #dee2e6;\n          | /* Keeping the blue as a supplementary visual cue, |   class=\"nav-link dropdown-toggle\" href=\"#\"    |
# |        | bordered thead td { border-bottom-width: 2px; }\n  |  border-bottom-right-radius: calc(.3rem - 1px);\n  |   but relying on aria-required */\n    .required   | id=\"admissionsDropdown\" role=\"button\" data-bs- |
# |        |    .table-borderless th, .table-borderless td,     |  border-bottom-left-radius: calc(.3rem - 1px);\n   |  label {\n      color: #007bff; /* Original blue   |   toggle=\"dropdown\" aria-expanded=\"false\">\n   |
# |        |   .table-borderless thead th, .table-borderless    |   }\n        .btn-close {\n            padding:    |   */\n    }\n\n    /* Events and Box styles */\n   | Admissions\n              </a>\n              <ul  |
# |        |  tbody + tbody { border: 0; }\n    .table-striped  |  .5rem .5rem;\n            margin: -.5rem -.5rem   |      .box {\n      border: 1px solid #ccc;\n       |           class=\"dropdown-menu\" aria-            |
# |        |   tbody tr:nth-of-type(odd) { background-color:    | -.5rem auto;\n        }\n        /* Custom styles  |    padding: 1rem;\n      margin-bottom: 1rem;\n    |        labelledby=\"admissionsDropdown\">\n        |
# |        |   rgba(0, 0, 0, 0.05); }\n    .table-hover tbody   |  for required field indicator */\n        .form-   | }\n\n    .events h3 a {\n      color: #007bff; /*  |           <li><a class=\"dropdown-item\"           |
# |        |    tr:hover { color: #212529; background-color:    |          group label.required::after {\n           |   Link color */\n    }\n\n    .events img.hr {\n   |        href=\"#\">Undergraduate</a></li>\n         |
# |        |    rgba(0, 0, 0, 0.075); }\n    .table-primary,    |    content: \"*\";\n            color: red; /*     | display: block;\n      width: 100%;\n      height: |           <li><a class=\"dropdown-item\"           |
# |        |     .table-primary > th, .table-primary > td {     | Example color for asterisk */\n            margin- |   auto;\n      margin: 1rem 0;\n    }\n\n    /*    |           href=\"#\">Graduate</a></li>\n           |
# |        |  background-color: #b8daff; }\n    .table-primary  | left: .25rem;\n        }\n        .reqExample {\n  |    Table styles */\n    .table {\n      width:     |           <li><a class=\"dropdown-item\"           |
# |        |  th, .table-primary td, .table-primary thead th,   |  font-style: italic;\n            color: #6c757d;  |  100%;\n      margin-bottom: 1rem;\n      color:   |           href=\"#\">Tuition</a></li>\n            |
# |        |    .table-primary tbody + tbody { border-color:    |          /* Example color */\n        }\n          |    #212529;\n      border-collapse: collapse;\n    |           <li><a class=\"dropdown-item\"           |
# |        | #7abaff; }\n    .table-hover .table-primary:hover  |  </style>\n</head>\n<body>\n    <a href=\"#main-   |       }\n\n    .table th,\n    .table td {\n       |        href=\"#\">Financial Aid</a></li>\n         |
# |        |  { background-color: #9fcdff; }\n    .table-hover  | content\" class=\"sr-only sr-only-focusable\">Skip |  padding: 0.75rem;\n      vertical-align: top;\n   |     </ul>\n            </li>\n            <li      |
# |        |  .table-primary:hover > td, .table-hover .table-   | to main content</a>\n\n    <header>\n        <div  |     border-top: 1px solid #dee2e6;\n    }\n\n      | class=\"nav-item\">\n              <a class=\"nav- |
# |        |  primary:hover > th { background-color: #9fcdff;   |   id=\"banner\" class=\"container clearfix\">\n    | .table thead th {\n      vertical-align: bottom;\n |  link\" href=\"#\">\n                  Visitors\n  |
# |        |  }\n    /* ... other bootstrap styles ... */\n\n   | <nav aria-label=\"version\" class=\"float-end\">\n |    border-bottom: 2px solid #dee2e6;\n    }\n\n    |     </a>\n            </li>\n          </ul>\n     |
# |        | /* From before-main.css */\n    #content { margin: |   <span class=\"float-start\">Examples:</span>\n   |   .table tbody + tbody {\n      border-top: 2px    |     <form class=\"d-flex\" role=\"search\">\n      |
# |        |   0 auto; width: 100%; }\n    #banner { padding:   |     <ul class=\"utility-menu float-start list-     | solid #dee2e6;\n    }\n\n    /* Footer styles */\n |      <label for=\"search-input\" class=\"sr-       |
# |        |  10px 0; }\n    .logo-link { display: block; }\n   | unstyled\">\n                    <li><a href=\"htt |  #footer .main-footer {\n      background-color:   |     only\">Search</label>\n            <input      |
# |        |     #logo { max-width: 100%; height: auto; }\n     | ps://openassessittoolkit.github.io/accessible_u/be | #f8f9fa; /* Light grey background */\n      color: |  id=\"search-input\" class=\"form-control me-2\"   |
# |        | .utility-menu { margin: 0; padding: 0; list-style: |     fore_u.html\" aria-current=\"page\">Before     |   #212529; /* Dark text */\n    }\n\n    #footer   |    type=\"search\" placeholder=\"Search\" aria-    |
# |        |  none; }\n    .utility-menu li { display: inline-  |             (Inaccessible)</a></li>\n              |  .main-footer a {\n       color: #007bff; /* Link  | label=\"Search\">\n            <button class=\"btn |
# |        | block; margin-left: 10px; }\n    .utility-menu a { | <li><a href=\"https://openassessittoolkit.github.i |   color */\n    }\n\n    #footer .sub-footer {\n   |    btn-success\" type=\"submit\">Go</button>\n     |
# |        | text-decoration: none; }\n    #main { padding-top: |        o/accessible_u/after_u.html\">After         | font-size: 0.9rem;\n      color: #6c757d; /* Muted |      </form>\n        </div>\n      </div>\n       |
# |        | 20px; }\n    #footer { background-color: #f8f9fa;  |   (Accessible)</a></li>\n                </ul>\n   |    text */\n    }\n\n    #footer .social li {\n    |      </nav>\n\n    <main id=\"main-content\"       |
# |        |  padding: 20px 0; }\n    .main-footer { padding:   |       </nav>\n            <div class=\"logo-       |     display: inline-block;\n      margin-left:     | class=\"container\">\n      <div class=\"row\">\n  |
# |        |   20px 0; }\n    .sub-footer { font-size: 0.9em;   | container\">\n                 <!-- Replaced image |  0.5rem;\n    }\n\n    /* Modal styles (simulated  |   <div class=\"col-md-8\">\n            <section   |
# |        |    color: #6c757d; }\n    .social { margin: 0;     |  of text with actual text -->\n                <a  |       from modal.css) */\n    #modalMask {\n       |       class=\"mb-3\">\n\n              <div        |
# |        | padding: 0; list-style: none; }\n    .social li {  | class=\"logo-link\" href=\"https://openassessittoo | position: fixed;\n      top: 0;\n      left: 0;\n  |  id=\"carouselExampleCaptions\" class=\"carousel   |
# |        |   display: inline-block; margin-left: 10px; }\n    |         lkit.github.io/accessible_u/\">\n          |        width: 100%;\n      height: 100%;\n         |        slide\" data-bs-ride=\"carousel\">\n        |
# |        |    .social img { width: 24px; height: 24px; }\n    |  <h1 class=\"h4\">Accessible University Demo Site  |   background-color: rgba(0, 0, 0, 0.5); /* Semi-   |       <div class=\"carousel-indicators\">\n        |
# |        |   #ccLogo img { vertical-align: middle; margin-    |    <span class=\"badge bg-danger\">Inaccessible    |    transparent black */\n      z-index: 1040;\n    |          <button type=\"button\" data-bs-          |
# |        | right: 5px; }\n    hr { margin-top: 1rem; margin-  |    Version</span></h1>\n                </a>\n     |   display: none; /* Managed by JS */\n    }\n\n    | target=\"#carouselExampleCaptions\" data-bs-slide- |
# |        |   bottom: 1rem; border: 0; border-top: 1px solid   |       </div>\n        </div>\n\n        <nav       |     #modalContent {\n      position: fixed;\n      |  to=\"0\" class=\"active\" aria-current=\"true\"   |
# |        |    rgba(0, 0, 0, 0.1); box-sizing: content-box;    |  class=\"navbar navbar-expand-lg navbar-dark bg-   |   top: 50%;\n      left: 50%;\n      transform:    |         aria-label=\"Slide 1\"></button>\n         |
# |        |   height: 0; overflow: visible; }\n    img.hr {    |     dark bg-primary mb-3\">\n            <div      |  translate(-50%, -50%);\n      background-color:   |          <button type=\"button\" data-bs-          |
# |        |   display: block; margin: 1em auto; width: 80%;    |   class=\"container\">\n                <button    |    #fff;\n      padding: 1.5rem;\n      border-    | target=\"#carouselExampleCaptions\" data-bs-slide- |
# |        |   height: auto; }\n\n    /* From before-menu.css   | class=\"navbar-toggler\" type=\"button\" data-bs-  |      radius: 0.3rem;\n      z-index: 1050;\n       |    to=\"1\" aria-label=\"Slide 2\"></button>\n     |
# |        |   */\n    .navbar-nav .dropdown-menu { position:   |            toggle=\"collapse\" data-bs-            |   display: none; /* Managed by JS */\n      max-   |          <button type=\"button\" data-bs-          |
# |        |    absolute; top: 100%; left: 0; z-index: 1000;    |      target=\"#navbarSupportedContent\" aria-      |      width: 500px; /* Example max width */\n       | target=\"#carouselExampleCaptions\" data-bs-slide- |
# |        |   display: none; float: left; min-width: 10rem;    |     controls=\"navbarSupportedContent\" aria-      |    width: 90%;\n      box-shadow: 0 0.5rem 1rem    |    to=\"2\" aria-label=\"Slide 3\"></button>\n     |
# |        |   padding: 0.5rem 0; margin: 0.125rem 0 0; font-   |       expanded=\"false\" aria-label=\"Toggle       |          rgba(0, 0, 0, 0.175);\n    }\n\n          |   </div>\n                <div class=\"carousel-   |
# |        |   size: 1rem; color: #212529; text-align: left;    |      navigation\">\n                    <span      | #modalContent.show { display: block; } /* Managed  | inner\">\n                  <div class=\"carousel- |
# |        |     list-style: none; background-color: #fff;      |      class=\"navbar-toggler-icon\"></span>\n       | by JS */\n\n    .modalHeading {\n      font-size:  | item active\">\n                    <a href=\"http |
# |        |  background-clip: padding-box; border: 1px solid   | </button>\n\n                <div class=\"collapse | 1.5rem;\n      margin-bottom: 1rem;\n      border- | s://openassessittoolkit.github.io/accessible_u/som |
# |        |  rgba(0, 0, 0, 0.15); border-radius: 0.25rem; }\n  | navbar-collapse\" id=\"navbarSupportedContent\">\n | bottom: 1px solid #dee2e6;\n      padding-bottom:  |           epage.html?ref=Slide%201\">\n            |
# |        |   .navbar-nav .dropdown-menu a { display: block;   |  <ul class=\"navbar-nav me-auto mb-2 mb-lg-0\">\n  |      0.5rem;\n    }\n\n    #modalXButton {\n       | <img src=\"https://openassessittoolkit.github.io/a |
# |        | padding: 0.25rem 1.5rem; clear: both; font-weight: |             <li class=\"nav-item\">\n              |      position: absolute;\n      top: 10px;\n       | ccessible_u/images/8675309-before_brass_band.jpg\" |
# |        |  400; color: #212529; text-align: inherit; white-  | <a class=\"nav-link active\" aria-current=\"page\" |      right: 10px;\n      background: none;\n       |      class=\"d-block w-100\" alt=\"Brass band      |
# |        |   space: nowrap; background-color: transparent;    |               href=\"#\">Home</a>\n                |     border: none;\n      font-size: 1.5rem;\n      | performing outdoors\">\n                    </a>\n |
# |        |    border: 0; }\n    .navbar-nav .dropdown-menu    |  </li>\n                        <li class=\"nav-   |  cursor: pointer;\n    }\n\n    #modalContent ol   |  </div>\n                  <div class=\"carousel-  |
# |        |   a:hover, .navbar-nav .dropdown-menu a:focus {    |  item dropdown\">\n                            <a  |     {\n      padding-left: 1.5rem;\n    }\n\n      | item\">\n                    <a href=\"https://ope |
# |        | color: #16181b; text-decoration: none; background- |   class=\"nav-link dropdown-toggle\" href=\"#\"    |    #modalOkButton {\n      margin-top: 1rem;\n     | nassessittoolkit.github.io/accessible_u/somepage.h |
# |        |   color: #f8f9fa; }\n    .navbar-nav .dropdown-    |   id=\"aboutDropdown\" role=\"button\" data-bs-    |    }\n\n    /* Carousel styles (simulated from     | tml?ref=Slide%202\">\n                      <img s |
# |        |   toggle::after { display: inline-block; margin-   |   toggle=\"dropdown\" aria-expanded=\"false\">\n   |   hero.css) */\n    #carousel {\n      position:   | rc=\"https://openassessittoolkit.github.io/accessi |
# |        |  left: 0.255em; vertical-align: 0.255em; content:  |     About\n                            </a>\n      | relative;\n      overflow: hidden;\n      margin-  | ble_u/images/8675309-before_articulated_bus.jpg\"  |
# |        | \"\"; border-top: 0.3em solid; border-right: 0.3em |         <ul class=\"dropdown-menu\" aria-          |  bottom: 1rem;\n    }\n\n    #carousel .slide {\n  | class=\"d-block w-100\" alt=\"Articulated bus on a |
# |        | solid transparent; border-bottom: 0; border-left:  |          labelledby=\"aboutDropdown\">\n           |   display: none; /* Managed by JS */\n    }\n\n    |     city street\">\n                    </a>\n     |
# |        |    0.3em solid transparent; }\n    .navbar-nav     |           <li><a class=\"dropdown-item\"           | #carousel .slide.current {\n      display: block;  |  </div>\n                  <div class=\"carousel-  |
# |        |  .dropdown-toggle:empty::after { margin-left: 0;   |             href=\"#\">News</a></li>\n             |  /* Managed by JS */\n    }\n\n    #carousel img   | item\">\n                    <a href=\"https://ope |
# |        |    }\n    .navbar-nav .dropdown-toggle::after {    |           <li><a class=\"dropdown-item\"           |  {\n      max-width: 100%;\n      height: auto;\n  | nassessittoolkit.github.io/accessible_u/somepage.h |
# |        |   display: none; } /* Hide default caret */\n\n    |          href=\"#\">Governance</a></li>\n          | }\n\n    #carousel .btn-prev, #carousel .btn-next  | tml?ref=Slide%203\">\n                      <img s |
# |        |    /* From before-events.css */\n    .events {     |           <li><a class=\"dropdown-item\"           |  {\n      position: absolute;\n      top: 50%;\n   | rc=\"https://openassessittoolkit.github.io/accessi |
# |        | padding: 15px; background-color: #f8f9fa; border:  |          href=\"#\">Diversity</a></li>\n           |  transform: translateY(-50%);\n      background:   |   ble_u/images/8675309-before_construction.jpg\"   |
# |        |   1px solid #dee2e6; border-radius: 0.25rem; }\n   | <li><a class=\"dropdown-item\" href=\"#\">Contact  | rgba(0, 0, 0, 0.5); /* Semi-transparent background |  class=\"d-block w-100\" alt=\"Construction site   |
# |        |  .events h6 { margin-bottom: 0.25rem; font-size:   |  Us</a></li>\n                            </ul>\n  |  */\n      border: none;\n      color: white; /*   |  with scaffolding\">\n                    </a>\n   |
# |        |    0.9rem; color: #6c757d; }\n    .events h5 {     |  </li>\n                        <li class=\"nav-   |   Arrow color */\n      padding: 10px; /* Adjust   |          </div>\n                </div>\n          |
# |        |   margin-bottom: 0.5rem; font-size: 1.1rem; }\n    |  item dropdown\">\n                            <a  |   padding as needed */\n      cursor: pointer;\n   |      <button class=\"carousel-control-prev\"       |
# |        |   .events p { margin-bottom: 0.5rem; }\n\n    /*   |   class=\"nav-link dropdown-toggle\" href=\"#\"    | z-index: 10;\n    }\n\n    #carousel .btn-prev {\n |              type=\"button\" data-bs-              |
# |        | From before-form.css */\n    .form-group { margin- | id=\"academicsDropdown\" role=\"button\" data-bs-  |   left: 0;\n    }\n\n    #carousel .btn-next {\n   |    target=\"#carouselExampleCaptions\" data-bs-    |
# |        | bottom: 1rem; }\n    .form-group label { display:  |   toggle=\"dropdown\" aria-expanded=\"false\">\n   |  right: 0;\n    }\n\n    #carousel .btn-prev img,  |      slide=\"prev\">\n                  <span      |
# |        | inline-block; margin-bottom: 0.5rem; }\n    .form- |   Academics\n                            </a>\n    | #carousel .btn-next img {\n      display: block;\n |     class=\"carousel-control-prev-icon\" aria-     |
# |        |      group input[type=\"text\"], .form-group       |         <ul class=\"dropdown-menu\" aria-          |   width: 30px; /* Adjust size */\n      height:    |  hidden=\"true\"></span>\n                  <span  |
# |        |   input[type=\"email\"] { display: block; width:   |        labelledby=\"academicsDropdown\">\n         |     auto;\n    }\n\n    #carousel .lentils {\n     |    class=\"visually-hidden\">Previous</span>\n     |
# |        | 100%; padding: 0.375rem 0.75rem; font-size: 1rem;  |  <li><a class=\"dropdown-item\" href=\"#\">Degree  |     position: absolute;\n      bottom: 10px;\n     |         </button>\n                <button         |
# |        |   line-height: 1.5; color: #495057; background-    |                Programs</a></li>\n                 |  left: 50%;\n      transform: translateX(-50%);\n  |  class=\"carousel-control-next\" type=\"button\"   |
# |        | color: #fff; background-clip: padding-box; border: |    <li><a class=\"dropdown-item\" href=\"#\">AU    |       list-style: none;\n      padding: 0;\n       | data-bs-target=\"#carouselExampleCaptions\" data-  |
# |        |     1px solid #ced4da; border-radius: 0.25rem;     |                 Faculty</a></li>\n                 |     margin: 0;\n      z-index: 10;\n    }\n\n      |    bs-slide=\"next\">\n                  <span     |
# |        |  transition: border-color 0.15s ease-in-out, box-  | <li><a class=\"dropdown-item\" href=\"#\">Distance |  #carousel .lentils li {\n      display: inline-   |     class=\"carousel-control-next-icon\" aria-     |
# ...
# |        | text on informative images</li>\n      <li>Missing |                                                    |   attributes.\n10. Added ARIA attributes to the    |                                                    |
# |        |     or excessive alternate text on decorative      |                                                    |     carousel for better accessibility (`aria-      |                                                    |
# |        |     images</li>\n      <li>Insufficient color      |                                                    |    roledescription`, `aria-label`, `aria-live`,    |                                                    |
# |        |    contrast</li>\n      <li>Insufficient visual    |                                                    |              `role=\"group\"`, `aria-              |                                                    |
# |        |     cues</li>\n      <li>Inaccessible dropdown     |                                                    |  roledescription=\"slide\"`, `aria-label=\"[slide  |                                                    |
# |        | menu</li>\n      <li>Redundant, uninformative link |                                                    |     number] of [total]\"`, `role=\"tablist\"`,     |                                                    |
# |        |   text</li>\n      <li>Color used to communicate   |                                                    |  `role=\"tab\"`, `aria-selected`).\n11. Improved   |                                                    |
# |        |      information</li>\n      <li>Language not      |                                                    |  link text for clarity (e.g., \"view the list of   |                                                    |
# |        | specified</li>\n      <li>Missing accessible form  |                                                    |  issues\", \"view the accessible version\").\n12.  |                                                    |
# |        | markup</li>\n      <li>Inaccessible CAPTCHA</li>\n |                                                    | Changed the popup link to a `<button>` with `aria- |                                                    |
# |        |         <li>Inaccessible validation</li>\n         |                                                    |     controls` and descriptive text.\n13. Added     |                                                    |
# |        |       <li>Missing ARIA landmark roles</li>\n       |                                                    |  `<caption>` to the enrollment table.\n14. Added   |                                                    |
# |        |        <li>Inaccessible modal window</li>\n        |                                                    |     `<thead>` and `<tbody>` to the table.\n15.     |                                                    |
# |        | <li>Inaccessible carousel</li>\n      <li>Missing  |                                                    |  Converted appropriate `<td>` cells in the table   |                                                    |
# |        | accessible table markup</li>\n      <li>HTML fails |                                                    |       header and first column to `<th>` with       |                                                    |
# |        |      validation</li>\n    </ol>\n    <button       |                                                    |  `scope=\"col\"` or `scope=\"row\"`.\n16. Wrapped  |                                                    |
# |        |     class=\"btn btn-primary\" type=\"button\"      |                                                    | event entries in `<article>` and used `<time>` for |                                                    |
# |        |         id=\"modalOkButton\">OK</button>\n         |                                                    | dates.\n17. Added `<label>` elements for all form  |                                                    |
# |        |            </div>\n\n\n</body></html>",            |                                                    |     inputs and associated them using the `for`     |                                                    |
# |        |     "Procedure": "1. Added `lang=\"en\"` to the    |                                                    | attribute.\n18. Wrapped the major checkboxes in a  |                                                    |
# |        | `<html>` tag.\n2. Added a \"Skip to main content\" |                                                    | `<fieldset>` with a `<legend>`.\n19. Added `aria-  |                                                    |
# |        | link with `sr-only` class.\n3. Converted relative  |                                                    |  required=\"true\"` to required form inputs.\n20.  |                                                    |
# |        |  URLs for images, scripts, and links to absolute   |                                                    |    Removed the text relying solely on color to     |                                                    |
# |        |  URLs.\n4. Inlined CSS from external files into a  |                                                    |        indicate required fields.\n21. Added        |                                                    |
# |        | `<style>` block in the `<head>`.\n5. Added an `sr- |                                                    | `role=\"alert\"` and `aria-live=\"assertive\"` to  |                                                    |
# |        | only` CSS class for visually hidden elements.\n6.  |                                                    |   the form error container.\n22. Wrapped social    |                                                    |
# |        |   Corrected color contrast for `.reqExample` and   |                                                    |   links and footer links in `<nav>` with `aria-    |                                                    |
# |        |   `#error` text.\n7. Added a non-color indicator   |                                                    | label`.\n23. Wrapped the entire footer content in  |                                                    |
# |        | (asterisk) and `aria-hidden=\"true\"` for required |                                                    |   a `<footer>` element.\n24. Improved the modal    |                                                    |
# |        |       fields.\n8. Included the commented-out       |                                                    |      structure with `role=\"dialog\"`, `aria-      |                                                    |
# |        |   `bootstrap.bundle.min.js` script.\n9. Replaced   |                                                    |   modal=\"true\"`, `aria-labelledby`, and `aria-   |                                                    |
# |        |      `div` elements with class `heading` with      |                                                    |   describedby`.\n25. Added an `id` to the modal    |                                                    |
# |        |     appropriate semantic heading tags (`<h1>`,     |                                                    | heading and wrapped the descriptive text in a div  |                                                    |
# |        | `<h2>`).\n10. Added descriptive `alt` text to all  |                                                    |    with an `id`.\n26. Added `aria-label=\"Close    |                                                    |
# |        |  informative images.\n11. Added empty `alt=\"\"`   |                                                    |  modal\"` to the modal close button.\n27. Removed  |                                                    |
# |        |  and `role=\"presentation\"` to decorative images  |                                                    |    the invalid `div` with `role=\"bottom\"` and    |                                                    |
# |        |     (`hr.png`).\n12. Added ARIA landmark roles     |                                                    |   `aria-foo=\"yes\"`.\n28. Inlined CSS from the    |                                                    |
# |        |     (`role=\"banner\"`, `role=\"navigation\"`,     |                                                    |    original files into a `<style>` block in the    |                                                    |
# |        |     `role=\"main\"`, `role=\"complementary\"`,     |                                                    |  `<head>`.\n29. Added an `sr-only` CSS class for   |                                                    |
# |        |  `role=\"contentinfo\"`).\n13. Added `aria-label`  |                                                    | visually hidden elements.\n30. Converted relative  |                                                    |
# |        | to navigation regions.\n14. Added `aria-controls`, |                                                    | URLs for images, CSS, and scripts to absolute URLs |                                                    |
# |        |  `aria-expanded`, and `aria-label` to the navbar   |                                                    |  based on the provided root URL.\n31. Added ARIA   |                                                    |
# |        |   toggler button.\n15. Added `role=\"button\"`,    |                                                    |   attributes (`aria-haspopup`, `aria-expanded`,    |                                                    |
# |        |          `aria-haspopup=\"true\"`, `aria-          |                                                    |     `aria-controls`, `role=\"button\"`, `aria-     |                                                    |
# |        | expanded=\"false\"`, and unique `id` attributes to |                                                    | labelledby`) to navigation dropdown toggles.\n32.  |                                                    |
# |        |     dropdown toggles, linking them with `aria-     |                                                    |  Added `<span class=\"sr-only\">(current)</span>`  |                                                    |
# |        | labelledby` to the dropdown menus.\n16. Associated |                                                    |     to the active navigation link.\n33. Added      |                                                    |
# |        |    form inputs with labels using `<label>` and     |                                                    |  `role=\"search\"` to the search form.\n34. Added  |                                                    |
# |        |      `for`/`id` attributes.\n17. Added `aria-      |                                                    |   basic responsive grid and utility class styles   |                                                    |
# |        |  required=\"true\"` to required form inputs.\n18.  |                                                    |  based on Bootstrap usage.\n35. Adjusted CSS for   |                                                    |
# |        | Wrapped major checkboxes in a `<fieldset>` with a  |                                                    |    required fields to keep the blue color as a     |                                                    |
# |        | `<legend>`.\n19. Added a `<caption>` to the table  |                                                    | supplementary cue but rely on `aria-required` for  |                                                    |
# |        | and used `<thead>`, `<tbody>`, `<th>`, and `scope` |                                                    |  programmatic identification.\n36. Ensured color   |                                                    |
# |        |  attributes for proper table structure and header  |                                                    | contrast for basic text, links, and buttons based  |                                                    |
# |        |   association.\n20. Added ARIA attributes to the   |                                                    | on standard Bootstrap colors (noting the original  |                                                    |
# |        |        carousel (`role=\"region\"`, `aria-         |                                                    | blue required text color issue).\n37. Included the |                                                    |
# |        | roledescription`, `aria-label`, `role=\"group\"`,  |                                                    |  original script files with absolute URLs in the   |                                                    |
# |        | `aria-hidden`, `role=\"tablist\"`, `role=\"tab\"`, |                                                    |                     `<head>`."                     |                                                    |
# |        | `aria-controls`, `aria-selected`, `tabindex`) and  |                                                    |                         }                          |                                                    |
# |        | navigation buttons (`aria-label`).\n21. Added ARIA |                                                    |                                                    |                                                    |
# |        | attributes to the modal (`role=\"dialog\"`, `aria- |                                                    |                                                    |                                                    |
# |        | modal=\"true\"`, `aria-labelledby`) and linked the |                                                    |                                                    |                                                    |
# |        | heading using `id`.\n22. Added `aria-label=\"Close |                                                    |                                                    |                                                    |
# |        |  modal\"` to the modal close button.\n23. Added a  |                                                    |                                                    |                                                    |
# |        |  note about accessible CAPTCHA alternatives.\n24.  |                                                    |                                                    |                                                    |
# |        | Added `role=\"alert\"` and `aria-live=\"polite\"`  |                                                    |                                                    |                                                    |
# |        |  to the error message container.\n25. Removed the  |                                                    |                                                    |                                                    |
# |        |  extra, incorrect footer `div` at the end of the   |                                                    |                                                    |                                                    |
# |        |                       body."                       |                                                    |                                                    |                                                    |
# |        |                         }                          |                                                    |                                                    |                                                    |
# +--------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+----------------------------------------------------+

# %%
extracted_json_html = json.loads(extracted_html)
extracted_json_html_template = json.loads(extracted_html_template)
extracted_json_md = json.loads(extracted_md)
extracted_json_md_template = json.loads(extracted_md_template)

# %%
generate_output_files("gemini-site2", extracted_json_html, extracted_json_html_template, extracted_json_md, extracted_json_md_template)

# %% [markdown]
# ---
# ## Evaluation of the Results
#
# The generated outputs are located in the `output` folder. We now need to use the WAVE and Lighthouse tools to evaluate accessibility, following the WCAG-EM methodology. The results from these evaluations should be recorded accordingly.

# %% [markdown]
# ### Paso 1: Armar el DataFrame

# %%
# Paso 1: Estructura de costos con claves únicas
costs = {
    "GPT_Site1_html": {"ptokens": 3861, "ctokens": 4306, "cost": 0.020418},
    "GPT_Site1_html_template": {"ptokens": 6790, "ctokens": 3345, "cost": 0.025337},
    "GPT_Site1_md": {"ptokens": 3914, "ctokens": 3642, "cost": 0.018890},
    "GPT_Site1_md_template": {"ptokens": 6785, "ctokens": 3311, "cost": 0.025240},

    "Gem_Site1_html": {"ptokens": 3890, "ctokens": 8414, "cost": 0.030760},
    "Gem_Site1_html_template": {"ptokens": 6769, "ctokens": 7831, "cost": 0.036500},
    "Gem_Site1_md": {"ptokens": 3943, "ctokens": 10118, "cost": 0.035153},
    "Gem_Site1_md_template": {"ptokens": 6764, "ctokens": 7269, "cost": 0.035083},

    "GPT_Site2_html": {"ptokens": 4475, "ctokens": 5344, "cost": 0.024547},
    "GPT_Site2_html_template": {"ptokens": 7404, "ctokens": 3493, "cost": 0.027243},
    "GPT_Site2_md": {"ptokens": 4528, "ctokens": 5167, "cost": 0.024238},
    "GPT_Site2_md_template": {"ptokens": 7399, "ctokens": 3081, "cost": 0.026200},

    "Gem_Site2_html": {"ptokens": 4583, "ctokens": 10746, "cost": 0.038323},
    "Gem_Site2_html_template": {"ptokens": 7462, "ctokens": 7996, "cost": 0.038645},
    "Gem_Site2_md": {"ptokens": 4636, "ctokens": 10443, "cost": 0.037698},
    "Gem_Site2_md_template": {"ptokens": 7457, "ctokens": 6496, "cost": 0.034882},
}

# Paso 2: Calcular y agregar TotalTokens
for entry in costs.values():
    entry["totaltokens"] = entry["ptokens"] + entry["ctokens"]

# %%
# !pip install pandas --quiet

# %%
import pandas as pd

# Puntos base de referencia (originales sin remediar)
original_lighthouse_scores = {
    'Site 1': 69,
    'Site 2': 58
}

# Datos originales de los sitios (según el reporte inicial)
original_wave_metrics = {
    'Site 1': {'WAVEErrors': 16, 'WAVEContrastErrors': 4, 'WAVEAlerts': 11, 'WAVEFeatures': 1},
    'Site 2': {'WAVEErrors': 24, 'WAVEContrastErrors': 21, 'WAVEAlerts': 11, 'WAVEFeatures': 3}
}

# Lista de combinaciones que vamos a mapear a mano (modelo, sitio, entrada, template, otras métricas)
combinations = [
    # Model, Site, InputType, TemplateUsed, AccessibilityScore, WAVE Errors, Contrast, Alerts, Features, cost_key
    ['GPT-4o', 'Site 1', 'HTML', 'No', 96, 1, 0, 9, 19, 'GPT_Site1_html'],
    ['GPT-4o', 'Site 1', 'HTML', 'Yes', 100, 1, 3, 6, 17, 'GPT_Site1_html_template'],
    ['GPT-4o', 'Site 1', 'Markdown', 'No', 100, 1, 0, 6, 18, 'GPT_Site1_md'],
    ['GPT-4o', 'Site 1', 'Markdown', 'Yes', 100, 1, 2, 6, 17, 'GPT_Site1_md_template'],

    ['Gemini', 'Site 1', 'HTML', 'No', 96, 0, 0, 10, 17, 'Gem_Site1_html'],
    ['Gemini', 'Site 1', 'HTML', 'Yes', 100, 1, 3, 5, 26, 'Gem_Site1_html_template'],
    ['Gemini', 'Site 1', 'Markdown', 'No', 96, 0, 0, 1, 25, 'Gem_Site1_md'],
    ['Gemini', 'Site 1', 'Markdown', 'Yes', 97, 0, 5, 4, 22, 'Gem_Site1_md_template'],

    ['GPT-4o', 'Site 2', 'HTML', 'No', 87, 4, 6, 7, 23, 'GPT_Site2_html'],
    ['GPT-4o', 'Site 2', 'HTML', 'Yes', 93, 4, 4, 5, 15, 'GPT_Site2_html_template'],
    ['GPT-4o', 'Site 2', 'Markdown', 'No', 75, 5, 3, 8, 19, 'GPT_Site2_md'],
    ['GPT-4o', 'Site 2', 'Markdown', 'Yes', 96, 2, 5, 7, 15, 'GPT_Site2_md_template'],

    ['Gemini', 'Site 2', 'HTML', 'No', 80, 2, 33, 4, 28, 'Gem_Site2_html'],
    ['Gemini', 'Site 2', 'HTML', 'Yes', 93, 1, 5, 0, 24, 'Gem_Site2_html_template'],
    ['Gemini', 'Site 2', 'Markdown', 'No', 88, 2, 23, 1, 26, 'Gem_Site2_md'],
    ['Gemini', 'Site 2', 'Markdown', 'Yes', 95, 0, 3, 3, 24, 'Gem_Site2_md_template'],
]

# Construir data list a partir de combinaciones y costos
data = []
for row in combinations:
    model, site, input_type, template, score, err, contrast, alerts, features, key = row
    tokens = costs[key]
    data.append([
        model, site, input_type, template,
        score, err, contrast, alerts, features,
        tokens['ptokens'], tokens['ctokens'], tokens['totaltokens'], tokens['cost']
    ])

columns = [
    'Model', 'Site', 'InputType', 'TemplateUsed',
    'AccessibilityScore', 
    'WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts', 'WAVEFeatures',
    'PromptTokens', 'CompletionTokens', 'TotalTokens', 'TotalCost'
]

# Crear el DataFrame
df = pd.DataFrame(data, columns=columns)

# Mostrar el DataFrame completo
pd.set_option('display.width', 800)
print(df)

# Opcional: guardar el CSV
# df.to_csv('results_summary_fullwave.csv', index=False)
# Out:
#      Model    Site InputType TemplateUsed  AccessibilityScore  WAVEErrors  WAVEContrastErrors  WAVEAlerts  WAVEFeatures  PromptTokens  CompletionTokens  TotalTokens  TotalCost
# 0   GPT-4o  Site 1      HTML           No                  96           1                   0           9            19          3861              4306         8167   0.020418
# 1   GPT-4o  Site 1      HTML          Yes                 100           1                   3           6            17          6790              3345        10135   0.025337
# 2   GPT-4o  Site 1  Markdown           No                 100           1                   0           6            18          3914              3642         7556   0.018890
# 3   GPT-4o  Site 1  Markdown          Yes                 100           1                   2           6            17          6785              3311        10096   0.025240
# 4   Gemini  Site 1      HTML           No                  96           0                   0          10            17          3890              8414        12304   0.030760
# 5   Gemini  Site 1      HTML          Yes                 100           1                   3           5            26          6769              7831        14600   0.036500
# 6   Gemini  Site 1  Markdown           No                  96           0                   0           1            25          3943             10118        14061   0.035153
# 7   Gemini  Site 1  Markdown          Yes                  97           0                   5           4            22          6764              7269        14033   0.035083
# 8   GPT-4o  Site 2      HTML           No                  87           4                   6           7            23          4475              5344         9819   0.024547
# 9   GPT-4o  Site 2      HTML          Yes                  93           4                   4           5            15          7404              3493        10897   0.027243
# 10  GPT-4o  Site 2  Markdown           No                  75           5                   3           8            19          4528              5167         9695   0.024238
# 11  GPT-4o  Site 2  Markdown          Yes                  96           2                   5           7            15          7399              3081        10480   0.026200
# 12  Gemini  Site 2      HTML           No                  80           2                  33           4            28          4583             10746        15329   0.038323
# 13  Gemini  Site 2      HTML          Yes                  93           1                   5           0            24          7462              7996        15458   0.038645
# 14  Gemini  Site 2  Markdown           No                  88           2                  23           1            26          4636             10443        15079   0.037698
# 15  Gemini  Site 2  Markdown          Yes                  95           0                   3           3            24          7457              6496        13953   0.034882

# %% [markdown]
# ### Step 2: Apply Statistical Analysis
#
# Once the final `df` is ready, you can perform the full statistical analysis:
#
#  - Descriptive statistics
#  - Shapiro-Wilk normality tests
#  - T-tests / Wilcoxon comparisons
#  - Spearman correlations
#  - Boxplots and scatterplots (accessibility, tokens, etc.)
#
# ---
#
# **In simple terms:**
#
# | Method               | What does it tell us?                     | How do we use it?                          |
# |:---------------------|:------------------------------------------|:-------------------------------------------|
# | **p-value**          | Whether a result is real or by chance     | Comes from all statistical tests           |
# | **Mann-Whitney U**   | Compares two groups                       | e.g., Are GPT-4o and Gemini significantly different? |
# | **Spearman correlation** | Measures relationship between variables | e.g., Do more tokens mean better scores?   |
# | **Descriptive statistics** | Summarizes data behavior             | e.g., How high or variable are the scores? |

# %% [markdown]
# **What is a p-value?**
#
# - The **p-value** helps us decide **whether a difference or relationship is real or just happened by chance**.
# - **In simple terms**: The p-value tells you **how likely** it is to observe those results **if there were actually no difference**.
#
# **How do we interpret it?**
# - If the **p-value is small** (typically **less than 0.05**), it suggests that the **difference or relationship is likely real**.
# - If the **p-value is large** (greater than or equal to 0.05), the result **might have happened by chance**, and **we cannot conclude that the difference is real**.
#
# | p-value | What does it mean? |
# |:--------|:-------------------|
# | < 0.05  | The difference or relationship **is statistically significant** (unlikely to be due to chance). |
# | ≥ 0.05  | **Not enough evidence** to claim the difference or relationship is real. |
#
# **Simple example**:
# You flip a coin 100 times. If it lands on heads 95 times, the p-value would be very low → something unusual is happening. It's unlikely to be random, so it's considered significant.

# %% [markdown]
# ### 1. Descriptive Analysis
#
# First, we get basic statistics.
#
# - It's just a summary of **how big or small** the values of a variable are.
# - It includes:
#   - **Mean**: the average value.
#   - **Standard Deviation (std)**: how much the data varies (are values close together or widely spread?).
#   - **Min**: the smallest value.
#   - **Max**: the largest value.
#   - **Percentiles (25%, 50%, 75%)**: to see where most of the values are concentrated.
#
# **Put simply**:
# > These are **quick summaries** of the data: "Are the values high or low? Are they all similar, or very different?"

# %%
# !pip install scipy --quiet

# %%
# !pip install seaborn --quiet

# %%
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# Asegúrate de tener cargado tu DataFrame df
# con las columnas nuevas actualizadas

# 1. Descriptive statistics
print("Descriptive Statistics:\n")
print(df[['AccessibilityScore', 'WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts', 'WAVEFeatures', 
          'PromptTokens', 'CompletionTokens', 'TotalTokens', 'TotalCost']].describe())
# Out:
# Descriptive Statistics:
#
#        AccessibilityScore  WAVEErrors  WAVEContrastErrors  WAVEAlerts  WAVEFeatures  PromptTokens  CompletionTokens   TotalTokens  TotalCost
# count           16.000000   16.000000           16.000000   16.000000     16.000000     16.000000         16.000000     16.000000  16.000000
# mean            93.250000    1.562500            5.937500    5.125000     20.937500   5666.250000       6312.625000  11978.875000   0.029947
# std              7.325754    1.547848            9.021964    2.872281      4.281258   1522.995448       2724.196147   2667.105819   0.006668
# min             75.000000    0.000000            0.000000    0.000000     15.000000   3861.000000       3081.000000   7556.000000   0.018890
# 25%             91.750000    0.750000            1.500000    3.750000     17.000000   4342.000000       3604.750000  10026.750000   0.025067
# 50%             96.000000    1.000000            3.000000    5.500000     20.500000   5700.000000       5920.000000  11600.500000   0.029001
# 75%             97.750000    2.000000            5.000000    7.000000     24.250000   6942.250000       8100.500000  14195.750000   0.035490
# max            100.000000    5.000000           33.000000   10.000000     28.000000   7462.000000      10746.000000  15458.000000   0.038645

# %% [markdown]
# ### 2. Normality Tests (Shapiro-Wilk)
#
# Before choosing a statistical test, you should always ask:
#
# **Do my data follow a normal distribution (a bell-shaped curve, like the Gaussian curve)?**
#
# - If the data **is normally distributed**, you can use **parametric tests** like the t-test.
# - If the data **is not normal**, you should use **non-parametric tests**, like the Mann-Whitney U test.
#
# To decide between t-test and Mann-Whitney:
#
# - If **p < 0.05** → the data is **not normal** → use **Mann-Whitney U-test**.
# - If **p ≥ 0.05** → the data **is normal** → use **t-test**.

# %%
print("\nShapiro-Wilk Normality Tests:")
for column in ['AccessibilityScore', 'WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts', 'WAVEFeatures', 
               'PromptTokens', 'CompletionTokens', 'TotalTokens', 'TotalCost']:
    stat, p = stats.shapiro(df[column])
    print(f'{column}: W={stat:.4f}, p-value={p:.4f}')
# Out:
# Shapiro-Wilk Normality Tests:
# AccessibilityScore: W=0.8246, p-value=0.0059
# WAVEErrors: W=0.8371, p-value=0.0088
# WAVEContrastErrors: W=0.6165, p-value=0.0000
# WAVEAlerts: W=0.9675, p-value=0.7967
# WAVEFeatures: W=0.9224, p-value=0.1846
# PromptTokens: W=0.8005, p-value=0.0028
# CompletionTokens: W=0.9010, p-value=0.0835
# TotalTokens: W=0.9067, p-value=0.1031
# TotalCost: W=0.9067, p-value=0.1031

# %% [markdown]
# ### Interpretation of Normality Results
#
# The key variables (AccessibilityScore, WAVEErrors, WAVEContrastErrors, PromptTokens) have **p-values < 0.05**, which indicates they **do not follow a normal distribution**.
#
# **Reflection**
#
# Since several of the analyzed variables are **not normally distributed**, using the **Mann–Whitney U test** is more appropriate than the t-test because:
#
# - It **does not assume normality**.
# - It is **robust to skewed distributions and outliers**.
# - It is **suitable for small samples**, as in this case (**n = 16**).
#
# **Conclusion:**
# - The **t-test is not suitable** in this context.
# - The use of the **Mann–Whitney U test in this study is statistically justified**.

# %% [markdown]
# ### 3. Condition Comparisons (Mann–Whitney U Test)
#
# **What is the Mann–Whitney U test?**
#
# - It’s a statistical test to compare **two independent groups** and determine if one tends to have **higher values** than the other.
# - It **does not assume normal distribution** of data, which makes it suitable for real-world scenarios.
# - It is the **non-parametric equivalent** of the t-test.
#
# **How does it work?**
#
# - All values from both groups are **ranked from lowest to highest**.
# - It checks whether one group **consistently ranks higher** than the other.
# - A **p-value** is computed to assess if the observed difference is statistically significant.
#
# **Why do we use it in this study?**
#
# - To compare groups like:
#   - **GPT-4o vs. Gemini** (e.g., who achieves better accessibility scores?)
#   - **HTML vs. Markdown** inputs
#   - **Template vs. No Template** prompts
#
# **In short:**
# Mann–Whitney helps determine if there's a **real difference between two groups**, even with small or non-normal samples.

# %%
comparisons = [
    ('Model', 'GPT-4o', 'Gemini'),
    ('InputType', 'HTML', 'Markdown'),
    ('TemplateUsed', 'Yes', 'No')
]

metrics = ['AccessibilityScore', 'WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts', 'WAVEFeatures', 
           'PromptTokens', 'CompletionTokens', 'TotalTokens', 'TotalCost']

for compare_by, val1, val2 in comparisons:
    print(f"\nComparisons by {compare_by}: {val1} vs {val2}")
    group1 = df[df[compare_by] == val1]
    group2 = df[df[compare_by] == val2]
    for metric in metrics:
        stat, p = stats.mannwhitneyu(group1[metric], group2[metric])
        print(f'{metric}: U={stat:.4f}, p-value={p:.4f}')
# Out:
# Comparisons by Model: GPT-4o vs Gemini
# AccessibilityScore: U=36.0000, p-value=0.7089
# WAVEErrors: U=51.0000, p-value=0.0435
# WAVEContrastErrors: U=25.0000, p-value=0.4870
# WAVEAlerts: U=55.5000, p-value=0.0151
# WAVEFeatures: U=6.0000, p-value=0.0071
# PromptTokens: U=29.0000, p-value=0.7984
# CompletionTokens: U=0.0000, p-value=0.0002
# TotalTokens: U=0.0000, p-value=0.0002
# TotalCost: U=0.0000, p-value=0.0002
#
# Comparisons by InputType: HTML vs Markdown
# AccessibilityScore: U=28.0000, p-value=0.7089
# WAVEErrors: U=37.5000, p-value=0.5854
# WAVEContrastErrors: U=36.0000, p-value=0.7082
# WAVEAlerts: U=39.0000, p-value=0.4923
# WAVEFeatures: U=33.0000, p-value=0.9579
# PromptTokens: U=31.0000, p-value=0.9591
# CompletionTokens: U=37.0000, p-value=0.6454
# TotalTokens: U=37.0000, p-value=0.6454
# TotalCost: U=37.0000, p-value=0.6454
#
# Comparisons by TemplateUsed: Yes vs No
# AccessibilityScore: U=47.0000, p-value=0.1219
# WAVEErrors: U=25.5000, p-value=0.5127
# WAVEContrastErrors: U=37.5000, p-value=0.5929
# WAVEAlerts: U=22.0000, p-value=0.3156
# WAVEFeatures: U=21.5000, p-value=0.2908
# PromptTokens: U=64.0000, p-value=0.0002
# CompletionTokens: U=16.0000, p-value=0.1049
# TotalTokens: U=40.0000, p-value=0.4418
# TotalCost: U=40.0000, p-value=0.4418

# %% [markdown]
# ### 4. Correlation Analysis (Spearman)
#
# Used tokens vs. accessibility quality.
#
# - Spearman correlation is used to measure **whether two variables tend to increase or decrease together**.
# - It’s ideal when data is **not normally distributed** or the relationship is **not linear**.
# - Unlike comparison tests, it tells us **how strongly two variables are related**.
#
# **How does it work?**
# - It ranks the values of each variable.
# - It compares the rankings to assess **how similar their trends are**.
# - The result is a coefficient called **rho (ρ)**:
#
# | ρ (rho) Value | Interpretation |
# |:-------------:|:-------------------------------|
# | +1.0          | Perfect positive correlation: as one increases, the other also increases. |
# | -1.0          | Perfect negative correlation: as one increases, the other decreases. |
# |  0.0          | No correlation at all. |
#
# **When do we use it in this study?**
# - To examine relationships like:
#   - Do **more tokens** result in **higher accessibility**?
#   - Do **more WAVE errors** mean **lower accessibility**?
#
# **In short:**
# > Spearman tells us **how well two variables move together**, regardless of shape or distribution.

# %%
print("\nSpearman Correlation Analysis:")
correlation_pairs = [
    ('TotalTokens', 'AccessibilityScore'),
    ('WAVEErrors', 'AccessibilityScore'),
    ('WAVEContrastErrors', 'AccessibilityScore'),
    ('WAVEAlerts', 'AccessibilityScore'),
    ('WAVEFeatures', 'AccessibilityScore'),
    ('PromptTokens', 'AccessibilityScore'),
    ('CompletionTokens', 'AccessibilityScore'),
    ('TotalCost', 'AccessibilityScore')
]

for x, y in correlation_pairs:
    rho, p = stats.spearmanr(df[x], df[y])
    print(f'{x} vs {y}: rho={rho:.4f}, p-value={p:.4f}')
# Out:
# Spearman Correlation Analysis:
# TotalTokens vs AccessibilityScore: rho=-0.2196, p-value=0.4138
# WAVEErrors vs AccessibilityScore: rho=-0.5843, p-value=0.0175
# WAVEContrastErrors vs AccessibilityScore: rho=-0.5643, p-value=0.0228
# WAVEAlerts vs AccessibilityScore: rho=0.1142, p-value=0.6736
# WAVEFeatures vs AccessibilityScore: rho=-0.3253, p-value=0.2189
# PromptTokens vs AccessibilityScore: rho=0.0030, p-value=0.9912
# CompletionTokens vs AccessibilityScore: rho=-0.4018, p-value=0.1229
# TotalCost vs AccessibilityScore: rho=-0.2196, p-value=0.4138

# %% [markdown]
# ### 5. Visualizations
# ### 5.1 Boxplots — Group Comparisons
#
# Boxplots are a great way to visually compare how different groups behave.
#
# - They show the **distribution** of a variable within each group.
# - You can quickly spot **differences in medians**, **variability**, and **potential outliers**.
#
# **What do they display?**
# - **Box**: shows the middle 50% of the data (interquartile range).
# - **Line inside the box**: the median value.
# - **Whiskers**: extend to the minimum and maximum values (excluding outliers).
# - **Dots**: possible outliers.
#
# **How we use them in this study:**
# - Compare **accessibility scores** between models (e.g., GPT-4o vs. Gemini).
# - Compare **token usage** by input format (HTML vs. Markdown).
# - Compare **WAVE errors** between pages with and without templates.
#
# > Boxplots help visualize **how spread out and different** the data is across conditions.

# %% [markdown]
# #### Accessibility Scores by Model

# %%
# Estilo visual
sns.reset_defaults()

plt.figure(figsize=(8,6))
sns.boxplot(x='Model', y='AccessibilityScore', data=df, width=0.4,
    boxprops=dict(edgecolor='#6969FF', facecolor='#B3B3FF'),
    medianprops=dict(color='black'),
    whiskerprops=dict(color='#6969FF'),
    capprops=dict(color='#6969FF'),
    flierprops=dict(markerfacecolor='#B3B3FF', markeredgecolor='#6969FF')
)
plt.title('Accessibility Score by Model')
plt.ylabel('Accessibility Score (Lighthouse)')
plt.xlabel('Model')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/boxplot_accessibility_model.jpg', dpi=300)
plt.show()

# %% [markdown]
# #### Wave Errors by Model

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Model', y='WAVEErrors', data=df, width=0.4,
    boxprops=dict(edgecolor='#6969FF', facecolor='#B3B3FF'),
    medianprops=dict(color='black'),
    whiskerprops=dict(color='#6969FF'),
    capprops=dict(color='#6969FF'),
    flierprops=dict(markerfacecolor='#B3B3FF', markeredgecolor='#6969FF')
)
plt.title('Wave Errors by Model')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/boxplot_waveerrors_model.jpg', dpi=300)
plt.show()

# %% [markdown]
# #### Accessibility Score by Input Type (HTML vs Markdown)

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='InputType', y='AccessibilityScore', data=df, width=0.4,
    boxprops=dict(edgecolor='#6969FF', facecolor='#B3B3FF'),
    medianprops=dict(color='black'),
    whiskerprops=dict(color='#6969FF'),
    capprops=dict(color='#6969FF'),
    flierprops=dict(markerfacecolor='#B3B3FF', markeredgecolor='#6969FF')
)
plt.title('Accessibility Score by Input Type')
plt.ylabel('Accessibility Score (Lighthouse)')
plt.xlabel('Input Type')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/boxplot_accessibility_inputtype.jpg', dpi=300)
plt.show()

# %% [markdown]
# #### Accessibility Score by Template Usage

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='TemplateUsed', y='AccessibilityScore', data=df, width=0.4,
    boxprops=dict(edgecolor='#6969FF', facecolor='#B3B3FF'),
    medianprops=dict(color='black'),
    whiskerprops=dict(color='#6969FF'),
    capprops=dict(color='#6969FF'),
    flierprops=dict(markerfacecolor='#B3B3FF', markeredgecolor='#6969FF')
)
# plt.title('Accessibility Score by Template Usage')
plt.ylabel('Accessibility Score (Lighthouse)')
plt.xlabel('Template Used')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/boxplot_accessibility_template.jpg', dpi=300)
plt.show()

# %% [markdown]
# ### Tokens by model

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='Model', y='TotalTokens', data=df, width=0.4,
    boxprops=dict(edgecolor='#6969FF', facecolor='#B3B3FF'),
    medianprops=dict(color='black'),
    whiskerprops=dict(color='#6969FF'),
    capprops=dict(color='#6969FF'),
    flierprops=dict(markerfacecolor='#B3B3FF', markeredgecolor='#6969FF')
)
plt.title('Total tokens by Model')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/boxplot_tokens_model.jpg', dpi=300)
plt.show()

# %% [markdown]
# ### 2. Scatterplots — Correlations

# %% [markdown]
# #### 2.1 Tokens completion vs Accessibility Score

# %%
# Crear scatterplot
plt.figure(figsize=(8,6))
sns.scatterplot(
    x='CompletionTokens', 
    y='AccessibilityScore', 
    hue='Model', 
    style='TemplateUsed', 
    data=df,
    s=100
)

# Añadir línea de tendencia (regresión lineal)
sns.regplot(
    x='CompletionTokens', 
    y='AccessibilityScore', 
    data=df, 
    scatter=False, 
    color='#6969FF',  # Color personalizado
    ci=None
)

plt.title('Completion Tokens vs Accessibility Score')
plt.xlabel('Completion Tokens')
plt.ylabel('Accessibility Score (Lighthouse)')
plt.grid(linestyle='--', linewidth=0.7)
plt.tight_layout()

# Guardar imagen
plt.savefig('figures/scatter_completiontokens_vs_accessibility.jpg', dpi=300)
plt.show()

# %% [markdown]
# #### 2.2 Total Tokens vs Accessibility Score

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='TotalTokens', y='AccessibilityScore', hue=df['Model'], style=df['TemplateUsed'], data=df)
sns.regplot(x='TotalTokens', y='AccessibilityScore', data=df, scatter=False, color='#6969FF', ci=None)
plt.title('Total Tokens vs Accessibility Score')
plt.xlabel('Total Tokens (Prompt + Completion)')
plt.ylabel('Accessibility Score (Lighthouse)')
plt.grid(linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/scatter_tokens_vs_accessibility.jpg', dpi=300)
plt.show()

# %% [markdown]
# #### 2.3 WAVE Errors vs Accessibility Score

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(x='WAVEErrors', y='AccessibilityScore', hue=df['Model'], style=df['InputType'], data=df, s=100, edgecolor='black')
sns.regplot(x='WAVEErrors', y='AccessibilityScore', data=df, scatter=False, color='#6969FF', ci=None)
# plt.title('WAVE Errors vs Accessibility Score')
plt.xlabel('Number of WAVE Errors')
plt.ylabel('Accessibility Score (Lighthouse)')
plt.grid(linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/scatter_waveerrors_vs_accessibility.jpg', dpi=300)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

plt.figure(figsize=(8,6))

# Aplicar jitter a los valores
x_jittered = df['WAVEErrors'] + np.random.normal(0, 0.1, size=len(df))
y_jittered = df['AccessibilityScore'] + np.random.normal(0, 0.1, size=len(df))

# Dibujar el scatter con jitter
sns.scatterplot(
    x=x_jittered, 
    y=y_jittered, 
    hue=df['Model'], 
    style=df['InputType'], 
    s=100,
    edgecolor='black'
)

# Dibujar la línea de tendencia original sin jitter
sns.regplot(
    x='WAVEErrors', 
    y='AccessibilityScore', 
    data=df, 
    scatter=False, 
    color='#6969FF', 
    ci=None
)

plt.title('WAVE Errors vs Accessibility Score')
plt.xlabel('Number of WAVE Errors')
plt.ylabel('Accessibility Score (Lighthouse)')
plt.grid(linestyle='--', linewidth=0.7)
plt.tight_layout()
plt.savefig('figures/scatter_waveerrors_vs_accessibility_jitt.jpg', dpi=300)
plt.show()

# %% [markdown]
# ### 3. Bar Charts — Before and After Comparisons

# %% [markdown]
# #### 3.1 Errores WAVE Original vs Mejorados (per site)

# %%
import pandas as pd

# Provided dataframe `df` assumed to be already loaded with all metrics
# Compute the generated means grouped by site
generated_metrics = df.groupby('Site')[['WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts', 'WAVEFeatures']].mean()

# Build summary table
rows = []
for site in ['Site 1', 'Site 2']:
    for metric in ['WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts', 'WAVEFeatures']:
        original = original_wave_metrics[site][metric]
        generated = generated_metrics.loc[site, metric]
        if metric == 'WAVEFeatures':
            improvement = ((generated - original) / original) * 100
        else:
            improvement = ((original - generated) / original) * 100
        rows.append({
            'Site': site,
            'Metric': metric.replace('WAVE', ''),
            'Original': original,
            'Generated Mean': round(generated, 2),
            'Improvement (%)': round(improvement, 1)
        })

# Convert to DataFrame
improvement_df = pd.DataFrame(rows)

# Show the result
print(improvement_df)
# Out:
#      Site          Metric  Original  Generated Mean  Improvement (%)
# 0  Site 1          Errors        16            0.62             96.1
# 1  Site 1  ContrastErrors         4            1.62             59.4
# 2  Site 1          Alerts        11            5.88             46.6
# 3  Site 1        Features         1           20.12           1912.5
# 4  Site 2          Errors        24            2.50             89.6
# 5  Site 2  ContrastErrors        21           10.25             51.2
# 6  Site 2          Alerts        11            4.38             60.2
# 7  Site 2        Features         3           21.75            625.0

# %% [markdown]
# #### 3.2 WAVE Errors: Original vs Improved (per site)
#
# This bar chart compares the average number of WAVE errors before and after remediation for each site. The results show a significant reduction in detected errors, demonstrating the effectiveness of the LLM-based remediation process.

# %%
# Promedios de las métricas generadas
generated_metrics = df.groupby('Site')[['WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts', 'WAVEFeatures']].mean()

# Estructurar los datos para graficar
data = []
sites = ['Site 1', 'Site 2']
metrics = ['WAVEErrors', 'WAVEContrastErrors', 'WAVEAlerts', 'WAVEFeatures']

for site in sites:
    for metric in metrics:
        data.append({
            'Site': site,
            'Metric': metric,
            'Type': 'Original',
            'Value': original_wave_metrics[site][metric]
        })
        data.append({
            'Site': site,
            'Metric': metric,
            'Type': 'Generated',
            'Value': generated_metrics.loc[site, metric]
        })

compare_df = pd.DataFrame(data)
print(compare_df)

# Remover prefijo 'WAVE' de las etiquetas
compare_df['Metric'] = compare_df['Metric'].str.replace('WAVE', '')

# Gráfica
plt.figure(figsize=(12,6))

# Dibujar las barras manualmente por tipo
palette = {'Original': '#B3B3FF', 'Generated': '#D8DEFF'}
edgecolor = '#6969FF'

sns.barplot(x='Metric', y='Value', hue='Type', data=compare_df, errorbar=None, palette=palette, edgecolor=edgecolor)
plt.title('Comparison of WAVE metrics: Original vs Generated pages')
plt.ylabel('Average number of issues')
plt.xlabel('Accessibility Metric')
plt.grid(axis='y', linestyle='--', linewidth=0.7)
plt.legend(title='Page Type')
plt.tight_layout()
plt.savefig('figures/bar_wave_metrics_comparison.jpg', dpi=300)
plt.show()
# Out:
#       Site              Metric       Type   Value
# 0   Site 1          WAVEErrors   Original  16.000
# 1   Site 1          WAVEErrors  Generated   0.625
# 2   Site 1  WAVEContrastErrors   Original   4.000
# 3   Site 1  WAVEContrastErrors  Generated   1.625
# 4   Site 1          WAVEAlerts   Original  11.000
# 5   Site 1          WAVEAlerts  Generated   5.875
# 6   Site 1        WAVEFeatures   Original   1.000
# 7   Site 1        WAVEFeatures  Generated  20.125
# 8   Site 2          WAVEErrors   Original  24.000
# 9   Site 2          WAVEErrors  Generated   2.500
# 10  Site 2  WAVEContrastErrors   Original  21.000
# 11  Site 2  WAVEContrastErrors  Generated  10.250
# 12  Site 2          WAVEAlerts   Original  11.000
# 13  Site 2          WAVEAlerts  Generated   4.375
# 14  Site 2        WAVEFeatures   Original   3.000
# 15  Site 2        WAVEFeatures  Generated  21.750

# %% [markdown]
# ### 3.3 Comparison of Improvement Using the Lighthouse Score
#
# Generates a table with the percentage improvement relative to the original Lighthouse score. This table will later be used to create a heatmap.

# %%
def generate_improvement_table(df):

    # Etiquetas ordenadas como columnas
    variant_labels = [
        'GPT-HTML', 'GPT-HTML+T', 'GPT-MD', 'GPT-MD+T',
        'Gem-HTML', 'Gem-HTML+T', 'Gem-MD', 'Gem-MD+T'
    ]

    improvement_table = []

    for site in ['Site 1', 'Site 2']:
        row = [site, original_lighthouse_scores[site]]
        for model in ['GPT-4o', 'Gemini']:
            for input_type in ['HTML', 'Markdown']:
                for template in ['No', 'Yes']:
                    score = df[
                        (df['Site'] == site) &
                        (df['Model'] == model) &
                        (df['InputType'] == input_type) &
                        (df['TemplateUsed'] == template)
                    ]['AccessibilityScore'].values[0]
                    original = original_lighthouse_scores[site]
                    improvement = round(((score - original) / original) * 100, 2)
                    row.append(improvement)
        improvement_table.append(row)

    # Mostrar tabla
    header = ['Site', 'Original'] + variant_labels
    print("{:<8} {:<10} ".format(header[0], header[1]) + " ".join(f"{col:<13}" for col in header[2:]))

    for row in improvement_table:
        print("{:<8} {:<10} ".format(row[0], row[1]) + " ".join(f"{val:<13}" for val in row[2:]))
        
generate_improvement_table(df)
# Out:
# Site     Original   GPT-HTML      GPT-HTML+T    GPT-MD        GPT-MD+T      Gem-HTML      Gem-HTML+T    Gem-MD        Gem-MD+T
# Site 1   69         39.13         44.93         44.93         44.93         39.13         44.93         39.13         40.58
# Site 2   58         50.0          60.34         29.31         65.52         37.93         60.34         51.72         63.79

# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns

def save_improvement_heatmap(df, output_path='figures/heatmap_accessibility_improvement.jpg'):
    # Crear carpeta si no existe
    os.makedirs(os.path.dirname(output_path), exist_ok=True)

    # Etiquetas
    variant_labels = [
        'GPT-HTML', 'GPT-HTML+T', 'GPT-MD', 'GPT-MD+T',
        'Gem-HTML', 'Gem-HTML+T', 'Gem-MD', 'Gem-MD+T'
    ]

    improvement_table = []

    for site in ['Site 1', 'Site 2']:
        row = [site, original_lighthouse_scores[site]]
        for model in ['GPT-4o', 'Gemini']:
            for input_type in ['HTML', 'Markdown']:
                for template in ['No', 'Yes']:
                    score = df[
                        (df['Site'] == site) &
                        (df['Model'] == model) &
                        (df['InputType'] == input_type) &
                        (df['TemplateUsed'] == template)
                    ]['AccessibilityScore'].values[0]
                    original = original_lighthouse_scores[site]
                    improvement = round(((score - original) / original) * 100, 2)
                    row.append(improvement)
        improvement_table.append(row)

    # Crear heatmap
    header = ['Site', 'Original'] + variant_labels
    df_plot = pd.DataFrame(improvement_table, columns=header).set_index('Site')
    df_plot = df_plot.drop(columns='Original')

    # Paleta en tonos morado oscuro
    cmap = sns.light_palette("#3A3AF6", as_cmap=True)

    plt.figure(figsize=(12, 4))
    sns.heatmap(df_plot, annot=True, fmt=".2f", cmap=cmap, cbar_kws={'label': '% Improvement'})
    plt.title('Percentage improvement in accessibility score over original')
    plt.xlabel('Variant')
    plt.ylabel('Site')
    plt.tight_layout()
    plt.savefig(output_path, format='jpg', dpi=300)
    plt.show()
    plt.close()

save_improvement_heatmap(df)

# %% [markdown]
# ### Distribution of Studies After QA

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Simulamos una lista de puntajes QA sin normalizar
qa_scores = [
    0.95, 0.88, 0.80, 0.80, 0.98, 0.80, 0.80, 0.90, 0.80, 0.80,
    1.00, 0.80, 0.90, 0.98, 1.00, 0.95, 0.80, 0.95, 0.80, 0.95,
    0.80, 0.83, 0.80, 0.80, 0.98, 0.80, 1.00, 0.98, 0.98, 0.80,
    0.80, 0.80, 0.80, 0.80, 0.98, 0.80, 0.80, 0.80, 0.80, 0.80,
    0.80, 0.95, 1.00, 0.80, 0.80, 0.80, 0.80, 0.88, 0.88, 0.80,
    1.00, 1.00, 0.80, 0.80, 0.80, 0.88, 0.80, 0.80, 0.93, 0.98,
    0.80, 1.00, 0.80, 1.00, 0.95, 1.00, 0.80, 0.80, 0.80, 0.98,
    0.90, 0.80, 0.98, 1.00, 0.90, 0.80, 1.00, 0.98, 1.00, 0.98,
    0.80, 0.85, 1.00
]

# Convertimos a DataFrame
df = pd.DataFrame({'NormalizedScore': qa_scores})

# Graficamos la distribución
plt.figure(figsize=(8, 4))
bars = sns.histplot(df['NormalizedScore'], bins=10, kde=True, edgecolor='#6969FF', color='#B3B3FF')


# Personalización del gráfico
# plt.title('Distribution of normalized QA scores')
plt.xlabel('Normalized score')
plt.ylabel('Number of studies')
plt.grid(linestyle='--', linewidth=0.7)
plt.tight_layout()

# Guardar y mostrar
plt.savefig("figures/qa-distribution.jpg", dpi=300)
plt.show()
